# %%
import json
import os
from glob import glob

news_dir = '../data/newsdata'

news_list = []

for news_dir_i in glob(news_dir + '/*'):
    tmp_news_list = glob(news_dir_i + '/*')
    news_list += tmp_news_list
    
news_list = [x for x in news_list if x.endswith('.json')]
news_list.sort()

# %%
news_list
# Out:
# ['../data/newsdata/news_1_1/NIRW2000000001.json',
#  '../data/newsdata/news_1_1/NIRW2000000002.json',
#  '../data/newsdata/news_1_1/NLRW2000000001.json',
#  '../data/newsdata/news_1_1/NLRW2000000002.json',
#  '../data/newsdata/news_1_1/NLRW2000000003.json',
#  '../data/newsdata/news_1_1/NLRW2000000004.json',
#  '../data/newsdata/news_1_1/NLRW2000000005.json',
#  '../data/newsdata/news_1_1/NLRW2000000006.json',
#  '../data/newsdata/news_1_1/NLRW2000000007.json',
#  '../data/newsdata/news_1_1/NLRW2000000008.json',
#  '../data/newsdata/news_1_1/NLRW2000000009.json',
#  '../data/newsdata/news_1_1/NLRW2000000010.json',
#  '../data/newsdata/news_1_1/NLRW2000000011.json',
#  '../data/newsdata/news_1_1/NLRW2000000012.json',
#  '../data/newsdata/news_1_1/NLRW2000000013.json',
#  '../data/newsdata/news_1_1/NLRW2000000014.json',
#  '../data/newsdata/news_1_1/NLRW2000000015.json',
#  '../data/newsdata/news_1_1/NLRW2000000016.json',
#  '../data/newsdata/news_1_1/NLRW2000000017.json',
#  '../data/newsdata/news_1_1/NLRW2000000018.json',
#  '../data/newsdata/news_1_1/NLRW2000000019.json',
#  '../data/newsdata/news_1_1/NLRW2000000020.json',
#  '../data/newsdata/news_1_1/NLRW2000000021.json',
#  '../data/newsdata/news_1_1/NLRW2000000022.json',
#  '../data/newsdata/news_1_1/NLRW2000000023.json',
#  '../data/newsdata/news_1_1/NLRW2000000024.json',
#  '../data/newsdata/news_1_1/NLRW2000000025.json',
#  '../data/newsdata/news_1_1/NPRW2000000001.json',
#  '../data/newsdata/news_1_1/NPRW2000000002.json',
#  '../data/newsdata/news_1_1/NPRW2000000003.json',
#  '../data/newsdata/news_1_1/NPRW2000000004.json',
#  '../data/newsdata/news_1_1/NPRW2000000005.json',
#  '../data/newsdata/news_1_1/NWRW2000000001.json',
#  '../data/newsdata/news_1_1/NWRW2000000002.json',
#  '../data/newsdata/news_1_1/NWRW2000000003.json',
#  '../data/newsdata/news_2_0/NIRW1900000001.json',
#  '../data/newsdata/news_2_0/NIRW1900000002.json',
#  '../data/newsdata/news_2_0/NIRW1900000003.json',
#  '../data/newsdata/news_2_0/NIRW1900000004.json',
#  '../data/newsdata/news_2_0/NIRW1900000005.json',
#  '../data/newsdata/news_2_0/NIRW1900000006.json',
#  '../data/newsdata/news_2_0/NIRW1900000007.json',
#  '../data/newsdata/news_2_0/NIRW1900000008.json',
#  '../data/newsdata/news_2_0/NIRW1900000009.json',
#  '../data/newsdata/news_2_0/NIRW1900000010.json',
#  '../data/newsdata/news_2_0/NIRW1900000011.json',
#  '../data/newsdata/news_2_0/NIRW1900000012.json',
#  '../data/newsdata/news_2_0/NIRW1900000013.json',
#  '../data/newsdata/news_2_0/NIRW1900000014.json',
#  '../data/newsdata/news_2_0/NIRW1900000015.json',
#  '../data/newsdata/news_2_0/NIRW1900000016.json',
#  '../data/newsdata/news_2_0/NIRW1900000017.json',
#  '../data/newsdata/news_2_0/NIRW1900000018.json',
#  '../data/newsdata/news_2_0/NIRW1900000019.json',
#  '../data/newsdata/news_2_0/NIRW1900000020.json',
#  '../data/newsdata/news_2_0/NIRW1900000021.json',
#  '../data/newsdata/news_2_0/NIRW1900000022.json',
#  '../data/newsdata/news_2_0/NIRW1900000023.json',
#  '../data/newsdata/news_2_0/NIRW1900000024.json',
#  '../data/newsdata/news_2_0/NIRW1900000025.json',
#  '../data/newsdata/news_2_0/NIRW1900000026.json',
#  '../data/newsdata/news_2_0/NIRW1900000027.json',
#  '../data/newsdata/news_2_0/NIRW1900000028.json',
#  '../data/newsdata/news_2_0/NIRW1900000029.json',
#  '../data/newsdata/news_2_0/NIRW1900000030.json',
#  '../data/newsdata/news_2_0/NLRW1900000001.json',
#  '../data/newsdata/news_2_0/NLRW1900000002.json',
#  '../data/newsdata/news_2_0/NLRW1900000003.json',
#  '../data/newsdata/news_2_0/NLRW1900000004.json',
#  '../data/newsdata/news_2_0/NLRW1900000005.json',
#  '../data/newsdata/news_2_0/NLRW1900000006.json',
#  '../data/newsdata/news_2_0/NLRW1900000007.json',
#  '../data/newsdata/news_2_0/NLRW1900000008.json',
#  '../data/newsdata/news_2_0/NLRW1900000009.json',
#  '../data/newsdata/news_2_0/NLRW1900000010.json',
#  '../data/newsdata/news_2_0/NLRW1900000011.json',
#  '../data/newsdata/news_2_0/NLRW1900000012.json',
#  '../data/newsdata/news_2_0/NLRW1900000013.json',
#  '../data/newsdata/news_2_0/NLRW1900000014.json',
#  '../data/newsdata/news_2_0/NLRW1900000015.json',
#  '../data/newsdata/news_2_0/NLRW1900000016.json',
#  '../data/newsdata/news_2_0/NLRW1900000017.json',
#  '../data/newsdata/news_2_0/NLRW1900000018.json',
#  '../data/newsdata/news_2_0/NLRW1900000019.json',
#  '../data/newsdata/news_2_0/NLRW1900000020.json',
#  '../data/newsdata/news_2_0/NLRW1900000021.json',
#  '../data/newsdata/news_2_0/NLRW1900000022.json',
#  '../data/newsdata/news_2_0/NLRW1900000023.json',
#  '../data/newsdata/news_2_0/NLRW1900000024.json',
#  '../data/newsdata/news_2_0/NLRW1900000025.json',
#  '../data/newsdata/news_2_0/NLRW1900000026.json',
#  '../data/newsdata/news_2_0/NLRW1900000027.json',
#  '../data/newsdata/news_2_0/NLRW1900000028.json',
#  '../data/newsdata/news_2_0/NLRW1900000029.json',
#  '../data/newsdata/news_2_0/NLRW1900000030.json',
#  '../data/newsdata/news_2_0/NLRW1900000031.json',
#  '../data/newsdata/news_2_0/NLRW1900000032.json',
#  '../data/newsdata/news_2_0/NLRW1900000033.json',
#  '../data/newsdata/news_2_0/NLRW1900000034.json',
#  '../data/newsdata/news_2_0/NLRW1900000035.json',
#  '../data/newsdata/news_2_0/NLRW1900000036.json',
#  '../data/newsdata/news_2_0/NLRW1900000037.json',
#  '../data/newsdata/news_2_0/NLRW1900000038.json',
#  '../data/newsdata/news_2_0/NLRW1900000039.json',
#  '../data/newsdata/news_2_0/NLRW1900000040.json',
#  '../data/newsdata/news_2_0/NLRW1900000041.json',
#  '../data/newsdata/news_2_0/NLRW1900000042.json',
#  '../data/newsdata/news_2_0/NLRW1900000043.json',
#  '../data/newsdata/news_2_0/NLRW1900000044.json',
#  '../data/newsdata/news_2_0/NLRW1900000045.json',
#  '../data/newsdata/news_2_0/NLRW1900000046.json',
#  '../data/newsdata/news_2_0/NLRW1900000047.json',
#  '../data/newsdata/news_2_0/NLRW1900000048.json',
#  '../data/newsdata/news_2_0/NLRW1900000049.json',
#  '../data/newsdata/news_2_0/NLRW1900000050.json',
#  '../data/newsdata/news_2_0/NLRW1900000051.json',
#  '../data/newsdata/news_2_0/NLRW1900000052.json',
#  '../data/newsdata/news_2_0/NLRW1900000053.json',
#  '../data/newsdata/news_2_0/NLRW1900000054.json',
#  '../data/newsdata/news_2_0/NLRW1900000055.json',
#  '../data/newsdata/news_2_0/NLRW1900000056.json',
#  '../data/newsdata/news_2_0/NLRW1900000057.json',
#  '../data/newsdata/news_2_0/NLRW1900000058.json',
#  '../data/newsdata/news_2_0/NLRW1900000059.json',
#  '../data/newsdata/news_2_0/NLRW1900000060.json',
#  '../data/newsdata/news_2_0/NLRW1900000061.json',
#  '../data/newsdata/news_2_0/NLRW1900000062.json',
#  '../data/newsdata/news_2_0/NLRW1900000063.json',
#  '../data/newsdata/news_2_0/NLRW1900000064.json',
#  '../data/newsdata/news_2_0/NLRW1900000065.json',
#  '../data/newsdata/news_2_0/NLRW1900000066.json',
#  '../data/newsdata/news_2_0/NLRW1900000067.json',
#  '../data/newsdata/news_2_0/NLRW1900000068.json',
#  '../data/newsdata/news_2_0/NLRW1900000069.json',
#  '../data/newsdata/news_2_0/NLRW1900000070.json',
#  '../data/newsdata/news_2_0/NLRW1900000071.json',
#  '../data/newsdata/news_2_0/NLRW1900000072.json',
#  '../data/newsdata/news_2_0/NLRW1900000073.json',
#  '../data/newsdata/news_2_0/NLRW1900000074.json',
#  '../data/newsdata/news_2_0/NLRW1900000075.json',
#  '../data/newsdata/news_2_0/NLRW1900000076.json',
#  '../data/newsdata/news_2_0/NLRW1900000077.json',
#  '../data/newsdata/news_2_0/NLRW1900000078.json',
#  '../data/newsdata/news_2_0/NLRW1900000079.json',
#  '../data/newsdata/news_2_0/NLRW1900000080.json',
#  '../data/newsdata/news_2_0/NLRW1900000081.json',
#  '../data/newsdata/news_2_0/NLRW1900000082.json',
#  '../data/newsdata/news_2_0/NLRW1900000083.json',
#  '../data/newsdata/news_2_0/NLRW1900000084.json',
#  '../data/newsdata/news_2_0/NLRW1900000085.json',
#  '../data/newsdata/news_2_0/NLRW1900000086.json',
#  '../data/newsdata/news_2_0/NLRW1900000087.json',
#  '../data/newsdata/news_2_0/NLRW1900000088.json',
#  '../data/newsdata/news_2_0/NLRW1900000089.json',
#  '../data/newsdata/news_2_0/NLRW1900000090.json',
#  '../data/newsdata/news_2_0/NLRW1900000091.json',
#  '../data/newsdata/news_2_0/NLRW1900000092.json',
#  '../data/newsdata/news_2_0/NLRW1900000093.json',
#  '../data/newsdata/news_2_0/NLRW1900000094.json',
#  '../data/newsdata/news_2_0/NLRW1900000095.json',
#  '../data/newsdata/news_2_0/NLRW1900000096.json',
#  '../data/newsdata/news_2_0/NLRW1900000097.json',
#  '../data/newsdata/news_2_0/NLRW1900000098.json',
#  '../data/newsdata/news_2_0/NLRW1900000099.json',
#  '../data/newsdata/news_2_0/NLRW1900000100.json',
#  '../data/newsdata/news_2_0/NLRW1900000101.json',
#  '../data/newsdata/news_2_0/NLRW1900000102.json',
#  '../data/newsdata/news_2_0/NLRW1900000103.json',
#  '../data/newsdata/news_2_0/NLRW1900000104.json',
#  '../data/newsdata/news_2_0/NLRW1900000105.json',
#  '../data/newsdata/news_2_0/NLRW1900000106.json',
#  '../data/newsdata/news_2_0/NLRW1900000107.json',
#  '../data/newsdata/news_2_0/NLRW1900000108.json',
#  '../data/newsdata/news_2_0/NLRW1900000109.json',
#  '../data/newsdata/news_2_0/NLRW1900000110.json',
#  '../data/newsdata/news_2_0/NLRW1900000111.json',
#  '../data/newsdata/news_2_0/NLRW1900000112.json',
#  '../data/newsdata/news_2_0/NLRW1900000113.json',
#  '../data/newsdata/news_2_0/NLRW1900000114.json',
#  '../data/newsdata/news_2_0/NLRW1900000115.json',
#  '../data/newsdata/news_2_0/NLRW1900000116.json',
#  '../data/newsdata/news_2_0/NLRW1900000117.json',
#  '../data/newsdata/news_2_0/NLRW1900000118.json',
#  '../data/newsdata/news_2_0/NLRW1900000119.json',
#  '../data/newsdata/news_2_0/NLRW1900000120.json',
#  '../data/newsdata/news_2_0/NLRW1900000121.json',
#  '../data/newsdata/news_2_0/NLRW1900000122.json',
#  '../data/newsdata/news_2_0/NLRW1900000123.json',
#  '../data/newsdata/news_2_0/NLRW1900000124.json',
#  '../data/newsdata/news_2_0/NLRW1900000125.json',
#  '../data/newsdata/news_2_0/NLRW1900000126.json',
#  '../data/newsdata/news_2_0/NLRW1900000127.json',
#  '../data/newsdata/news_2_0/NLRW1900000128.json',
#  '../data/newsdata/news_2_0/NLRW1900000129.json',
#  '../data/newsdata/news_2_0/NLRW1900000130.json',
#  '../data/newsdata/news_2_0/NLRW1900000131.json',
#  '../data/newsdata/news_2_0/NLRW1900000132.json',
#  '../data/newsdata/news_2_0/NLRW1900000133.json',
#  '../data/newsdata/news_2_0/NLRW1900000134.json',
#  '../data/newsdata/news_2_0/NLRW1900000135.json',
#  '../data/newsdata/news_2_0/NLRW1900000136.json',
#  '../data/newsdata/news_2_0/NLRW1900000137.json',
#  '../data/newsdata/news_2_0/NLRW1900000138.json',
#  '../data/newsdata/news_2_0/NLRW1900000139.json',
#  '../data/newsdata/news_2_0/NLRW1900000140.json',
#  '../data/newsdata/news_2_0/NLRW1900000141.json',
#  '../data/newsdata/news_2_0/NLRW1900000142.json',
#  '../data/newsdata/news_2_0/NLRW1900000143.json',
#  '../data/newsdata/news_2_0/NLRW1900000144.json',
#  '../data/newsdata/news_2_0/NLRW1900000145.json',
#  '../data/newsdata/news_2_0/NLRW1900000146.json',
#  '../data/newsdata/news_2_0/NLRW1900000147.json',
#  '../data/newsdata/news_2_0/NLRW1900000148.json',
#  '../data/newsdata/news_2_0/NLRW1900000149.json',
#  '../data/newsdata/news_2_0/NLRW1900000150.json',
#  '../data/newsdata/news_2_0/NLRW1900000151.json',
#  '../data/newsdata/news_2_0/NLRW1900000152.json',
#  '../data/newsdata/news_2_0/NLRW1900000153.json',
#  '../data/newsdata/news_2_0/NLRW1900000154.json',
#  '../data/newsdata/news_2_0/NLRW1900000155.json',
#  '../data/newsdata/news_2_0/NLRW1900000156.json',
#  '../data/newsdata/news_2_0/NLRW1900000157.json',
#  '../data/newsdata/news_2_0/NLRW1900000158.json',
#  '../data/newsdata/news_2_0/NLRW1900000159.json',
#  '../data/newsdata/news_2_0/NLRW1900000160.json',
#  '../data/newsdata/news_2_0/NLRW1900000161.json',
#  '../data/newsdata/news_2_0/NPRW1900000001.json',
#  '../data/newsdata/news_2_0/NPRW1900000002.json',
#  '../data/newsdata/news_2_0/NPRW1900000003.json',
#  '../data/newsdata/news_2_0/NPRW1900000004.json',
#  '../data/newsdata/news_2_0/NPRW1900000005.json',
#  '../data/newsdata/news_2_0/NPRW1900000006.json',
#  '../data/newsdata/news_2_0/NPRW1900000007.json',
#  '../data/newsdata/news_2_0/NPRW1900000008.json',
#  '../data/newsdata/news_2_0/NPRW1900000009.json',
#  '../data/newsdata/news_2_0/NPRW1900000010.json',
#  '../data/newsdata/news_2_0/NPRW1900000011.json',
#  '../data/newsdata/news_2_0/NPRW1900000012.json',
#  '../data/newsdata/news_2_0/NPRW1900000013.json',
#  '../data/newsdata/news_2_0/NPRW1900000014.json',
#  '../data/newsdata/news_2_0/NPRW1900000015.json',
#  '../data/newsdata/news_2_0/NPRW1900000016.json',
#  '../data/newsdata/news_2_0/NPRW1900000017.json',
#  '../data/newsdata/news_2_0/NPRW1900000018.json',
#  '../data/newsdata/news_2_0/NPRW1900000019.json',
#  '../data/newsdata/news_2_0/NPRW1900000020.json',
#  '../data/newsdata/news_2_0/NPRW1900000021.json',
#  '../data/newsdata/news_2_0/NPRW1900000022.json',
#  '../data/newsdata/news_2_0/NPRW1900000023.json',
#  '../data/newsdata/news_2_0/NPRW1900000024.json',
#  '../data/newsdata/news_2_0/NPRW1900000025.json',
#  '../data/newsdata/news_2_0/NPRW1900000026.json',
#  '../data/newsdata/news_2_0/NPRW1900000027.json',
#  '../data/newsdata/news_2_0/NPRW1900000028.json',
#  '../data/newsdata/news_2_0/NPRW1900000029.json',
#  '../data/newsdata/news_2_0/NPRW1900000030.json',
#  '../data/newsdata/news_2_0/NPRW1900000031.json',
#  '../data/newsdata/news_2_0/NPRW1900000032.json',
#  '../data/newsdata/news_2_0/NPRW1900000033.json',
#  '../data/newsdata/news_2_0/NPRW1900000034.json',
#  '../data/newsdata/news_2_0/NPRW1900000035.json',
#  '../data/newsdata/news_2_0/NPRW1900000036.json',
#  '../data/newsdata/news_2_0/NPRW1900000037.json',
#  '../data/newsdata/news_2_0/NPRW1900000038.json',
#  '../data/newsdata/news_2_0/NPRW1900000039.json',
#  '../data/newsdata/news_2_0/NPRW1900000040.json',
#  '../data/newsdata/news_2_0/NPRW1900000041.json',
#  '../data/newsdata/news_2_0/NPRW1900000042.json',
#  '../data/newsdata/news_2_0/NPRW1900000043.json',
#  '../data/newsdata/news_2_0/NPRW1900000044.json',
#  '../data/newsdata/news_2_0/NPRW1900000045.json',
#  '../data/newsdata/news_2_0/NPRW1900000046.json',
#  '../data/newsdata/news_2_0/NPRW1900000047.json',
#  '../data/newsdata/news_2_0/NPRW1900000048.json',
#  '../data/newsdata/news_2_0/NPRW1900000049.json',
#  '../data/newsdata/news_2_0/NPRW1900000050.json',
#  '../data/newsdata/news_2_0/NPRW1900000051.json',
#  '../data/newsdata/news_2_0/NPRW1900000052.json',
#  '../data/newsdata/news_2_0/NPRW1900000053.json',
#  '../data/newsdata/news_2_0/NPRW1900000054.json',
#  '../data/newsdata/news_2_0/NPRW1900000055.json',
#  '../data/newsdata/news_2_0/NPRW1900000056.json',
#  '../data/newsdata/news_2_0/NPRW1900000057.json',
#  '../data/newsdata/news_2_0/NPRW1900000058.json',
#  '../data/newsdata/news_2_0/NPRW1900000059.json',
#  '../data/newsdata/news_2_0/NPRW1900000060.json',
#  '../data/newsdata/news_2_0/NPRW1900000061.json',
#  '../data/newsdata/news_2_0/NPRW1900000062.json',
#  '../data/newsdata/news_2_0/NPRW1900000063.json',
#  '../data/newsdata/news_2_0/NPRW1900000064.json',
#  '../data/newsdata/news_2_0/NPRW1900000065.json',
#  '../data/newsdata/news_2_0/NPRW1900000066.json',
#  '../data/newsdata/news_2_0/NPRW1900000067.json',
#  '../data/newsdata/news_2_0/NPRW1900000068.json',
#  '../data/newsdata/news_2_0/NPRW1900000069.json',
#  '../data/newsdata/news_2_0/NPRW1900000070.json',
#  '../data/newsdata/news_2_0/NWRW1800000001.json',
#  '../data/newsdata/news_2_0/NWRW1800000002.json',
#  '../data/newsdata/news_2_0/NWRW1800000004.json',
#  '../data/newsdata/news_2_0/NWRW1800000005.json',
#  '../data/newsdata/news_2_0/NWRW1800000006.json',
#  '../data/newsdata/news_2_0/NWRW1800000008.json',
#  '../data/newsdata/news_2_0/NWRW1800000009.json',
#  '../data/newsdata/news_2_0/NWRW1800000010.json',
#  '../data/newsdata/news_2_0/NWRW1800000012.json',
#  '../data/newsdata/news_2_0/NWRW1800000013.json',
#  '../data/newsdata/news_2_0/NWRW1800000014.json',
#  '../data/newsdata/news_2_0/NWRW1800000016.json',
#  '../data/newsdata/news_2_0/NWRW1800000017.json',
#  '../data/newsdata/news_2_0/NWRW1800000018.json',
#  '../data/newsdata/news_2_0/NWRW1800000020.json',
#  '../data/newsdata/news_2_0/NWRW1800000021.json',
#  '../data/newsdata/news_2_0/NWRW1800000022.json',
#  '../data/newsdata/news_2_0/NWRW1800000024.json',
#  '../data/newsdata/news_2_0/NWRW1800000025.json',
#  '../data/newsdata/news_2_0/NWRW1800000026.json',
#  '../data/newsdata/news_2_0/NWRW1800000028.json',
#  '../data/newsdata/news_2_0/NWRW1800000029.json',
#  '../data/newsdata/news_2_0/NWRW1800000030.json',
#  '../data/newsdata/news_2_0/NWRW1800000032.json',
#  '../data/newsdata/news_2_0/NWRW1800000033.json',
#  '../data/newsdata/news_2_0/NWRW1800000034.json',
#  '../data/newsdata/news_2_0/NWRW1800000036.json',
#  '../data/newsdata/news_2_0/NWRW1800000037.json',
#  '../data/newsdata/news_2_0/NWRW1800000038.json',
#  '../data/newsdata/news_2_0/NWRW1800000040.json',
#  '../data/newsdata/news_2_0/NWRW1800000041.json',
#  '../data/newsdata/news_2_0/NWRW1800000042.json',
#  '../data/newsdata/news_2_0/NWRW1800000044.json',
#  '../data/newsdata/news_2_0/NWRW1800000045.json',
#  '../data/newsdata/news_2_0/NWRW1800000046.json',
#  '../data/newsdata/news_2_0/NWRW1800000048.json',
#  '../data/newsdata/news_2_0/NWRW1800000049.json',
#  '../data/newsdata/news_2_0/NWRW1800000050.json',
#  '../data/newsdata/news_2_0/NWRW1800000052.json',
#  '../data/newsdata/news_2_0/NWRW1800000053.json',
#  '../data/newsdata/news_2_0/NWRW1800000054.json',
#  '../data/newsdata/news_2_0/NWRW1800000056.json',
#  '../data/newsdata/news_2_0/NWRW1900000001.json',
#  '../data/newsdata/news_2_0/NWRW1900000002.json',
#  '../data/newsdata/news_2_0/NWRW1900000003.json',
#  '../data/newsdata/news_2_0/NWRW1900000004.json',
#  '../data/newsdata/news_2_0/NWRW1900000005.json',
#  '../data/newsdata/news_2_0/NWRW1900000006.json',
#  '../data/newsdata/news_2_0/NWRW1900000007.json',
#  '../data/newsdata/news_2_0/NWRW1900000008.json',
#  '../data/newsdata/news_2_0/NWRW1900000009.json',
#  '../data/newsdata/news_2_0/NWRW1900000010.json',
#  '../data/newsdata/news_2_0/NWRW1900000011.json',
#  '../data/newsdata/news_2_0/NWRW1900000012.json',
#  '../data/newsdata/news_2_0/NWRW1900000013.json',
#  '../data/newsdata/news_2_0/NWRW1900000014.json',
#  '../data/newsdata/news_2_0/NWRW1900000015.json',
#  '../data/newsdata/news_2_0/NWRW1900000016.json',
#  '../data/newsdata/news_2_0/NWRW1900000017.json',
#  '../data/newsdata/news_2_0/NWRW1900000018.json',
#  '../data/newsdata/news_2_0/NWRW1900000019.json',
#  '../data/newsdata/news_2_0/NWRW1900000020.json',
#  '../data/newsdata/news_2_0/NWRW1900000021.json',
#  '../data/newsdata/news_2_0/NWRW1900000022.json',
#  '../data/newsdata/news_2_0/NWRW1900000023.json',
#  '../data/newsdata/news_2_0/NWRW1900000024.json',
#  '../data/newsdata/news_2_0/NWRW1900000025.json',
#  '../data/newsdata/news_2_0/NWRW1900000026.json',
#  '../data/newsdata/news_2_0/NWRW1900000027.json',
#  '../data/newsdata/news_2_0/NWRW1900000028.json',
#  '../data/newsdata/news_2_0/NWRW1900000029.json',
#  '../data/newsdata/news_2_0/NWRW1900000030.json',
#  '../data/newsdata/news_2_0/NWRW1900000031.json',
#  '../data/newsdata/news_2_0/NWRW1900000032.json',
#  '../data/newsdata/news_2_0/NWRW1900000033.json',
#  '../data/newsdata/news_2_0/NWRW1900000034.json',
#  '../data/newsdata/news_2_0/NWRW1900000035.json',
#  '../data/newsdata/news_2_0/NWRW1900000036.json',
#  '../data/newsdata/news_2_0/NWRW1900000037.json',
#  '../data/newsdata/news_2_0/NWRW1900000038.json',
#  '../data/newsdata/news_2_0/NWRW1900000039.json',
#  '../data/newsdata/news_2_0/NWRW1900000040.json',
#  '../data/newsdata/news_2_0/NWRW1900000041.json',
#  '../data/newsdata/news_2_0/NWRW1900000042.json',
#  '../data/newsdata/news_2_0/NWRW1900000043.json',
#  '../data/newsdata/news_2_0/NWRW1900000044.json',
#  '../data/newsdata/news_2_0/NWRW1900000045.json',
#  '../data/newsdata/news_2_0/NWRW1900000046.json',
#  '../data/newsdata/news_2_0/NWRW1900000047.json',
#  '../data/newsdata/news_2_0/NWRW1900000048.json',
#  '../data/newsdata/news_2_0/NWRW1900000049.json',
#  '../data/newsdata/news_2_0/NWRW1900000050.json',
#  '../data/newsdata/news_2_0/NWRW1900000051.json',
#  '../data/newsdata/news_2_0/NWRW1900000052.json',
#  '../data/newsdata/news_2_0/NWRW1900000053.json',
#  '../data/newsdata/news_2_0/NWRW1900000054.json',
#  '../data/newsdata/news_2_0/NWRW1900000055.json',
#  '../data/newsdata/news_2_0/NWRW1900000056.json',
#  '../data/newsdata/news_2_0/NWRW1900000057.json',
#  '../data/newsdata/news_2_0/NWRW1900000058.json',
#  '../data/newsdata/news_2_0/NWRW1900000059.json',
#  '../data/newsdata/news_2_0/NWRW1900000060.json',
#  '../data/newsdata/news_2_0/NZRW1900000001.json']

# %%
import re
from kss import split_sentences

def preprocess(text):
    # 한 개의 평서문만 허용
    if text.count('.') != 1:
        return ''
    if '·' in text:
        return ''
    # \xa0
    text = re.sub('\xa0', ' ', text)

    # 괄호 안의 텍스트 제거
    text = re.sub(r'\([^)]*\)','', text)
    # <> 안의 텍스트 제거
    text = re.sub('<.+?>', '', text)
    # 큰따옴표 제거
    text = re.sub('"', '', text)
    # 다른 형태의 따옴표 처리
    text = re.sub(r'[‘’]', '', text)
    text = re.sub(r'[“”]', '', text)
    
    # 영어, 한국어를 제외한 다른 언어 제외
    if re.sub("[가-힣ㄱ-ㅎㅏ-ㅣa-zA-Z0-9.\W]", '', text):
        return ''
    
    # 너무 적은 개수의 토큰으로 이루어진 경우 제외(예: 어린 시절.)
    if len(text.split()) <= 5:
        return ''
    
    return text      

def news2sentlist(news_file):
    ret_list = []
    with open(news_file, 'r') as f:
        json_data = json.load(f)
    
    for i in range(len(json_data['document'])):
        tmp_data = json_data['document'][i]['paragraph']
    
        for j in range(len(tmp_data)):
            if j == 0: continue
            if len(tmp_data[j]['form']) <= 70:
                ret_list.append(tmp_data[j]['form'])
                
    ret_list = [preprocess(x) for x in ret_list if preprocess(x)]
    
    return ret_list

# %%
default_dir = '../data/newsdata/news_1_1/'
len(news2sentlist(default_dir + 'NPRW2000000001.json'))
# Out:
# 19486

# %%
domain_sent = news2sentlist(default_dir + 'NPRW2000000001.json')

# %%
import pandas as pd

domain_df = pd.DataFrame(domain_sent)
domain_df.head()
# Out:
#                                                    0
# 0  삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.
# 1  삼성전자 관계자는 지난해부터 중저가 모델에 멀티 카메라 등 프리미엄 기능을 먼저 넣...
# 2  SBS 신개념 음악 예능 더 팬이 단 한 회도 빠짐없이 2049 타깃 시청률 1위를...
# 3  한편 최종 TOP5는 현장 관객 점수와 앱 투표 결과를 합산해 결정되며, 그 결과는...
# 4    당권 도전을 기정사실화한 오 전 시장도 21일 영남권을 시작으로 지방 순회에 나선다.

# %%
domain_df.to_csv('../data/specific_domain_sentences.csv', index=False)

# %%
domain_sent[:5]
# Out:
# ['삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.',
#  '삼성전자 관계자는 지난해부터 중저가 모델에 멀티 카메라 등 프리미엄 기능을 먼저 넣고 있다고 말했다.',
#  'SBS 신개념 음악 예능 더 팬이 단 한 회도 빠짐없이 2049 타깃 시청률 1위를 기록하고 있다.',
#  '한편 최종 TOP5는 현장 관객 점수와 앱 투표 결과를 합산해 결정되며, 그 결과는 다음주 생방송 무대에서 공개된다.',
#  '당권 도전을 기정사실화한 오 전 시장도 21일 영남권을 시작으로 지방 순회에 나선다.']

# %% [markdown]
# ## entity 추출

# %%
from itertools import permutations
from pororo import Pororo

ner = Pororo(task='ner', lang='ko')

# %%
import requests

r = requests.get('https://raw.githubusercontent.com/datawhales/Korean_RE/main/data/relation/relid2label.json')
relid2label = json.loads(r.text)

# %%
list(relid2label.items())[:5]
# Out:
# [('P17', '다음 국가의 것임(country)'),
#  ('P131', '다음 행정구역에 위치함(located in)'),
#  ('P530', '수교국(diplomatic relation)'),
#  ('P150', '하위 행정구역'),
#  ('P47', '경계를 접하고 있음(shares border with)')]

# %%
relation_list = list(relid2label.keys())
relation_list[:5]
# Out:
# ['P17', 'P131', 'P530', 'P150', 'P47']

# %%
def idx2relid(idx_list):
    label_out = []
    
    for idx in idx_list:
        label = relation_list[idx]
        label_out.append(label)
        
    return label_out

# %%
def ner_list(sentence):
    ner_result = ner(sentence)
    ner_result = [(item[0], item[1], len(item[0])) for item in ner_result]
    
    modified_list = []
    tmp_cnt = 0

    for item in ner_result:
        modified_list.append((item[0], item[1], [tmp_cnt, tmp_cnt + item[2]]))
        tmp_cnt += item[2]
    
    true_list = {'PERSON': True,'ORGANIZATION': True, 'COUNTRY': True, 'LOCATION': True, 'EVENT': True,
                 'THEORY': True, 'ARTIFACT': True, 'ANIMAL': True, 'TERM': True, 'STUDY_FIELD': True,
                 'MATERIAL': True, 'CITY': True, 'DISEASE': True}
    ent_list = [item for item in modified_list if item[1] in true_list]

    return ent_list

# %%
for i in range(len(domain_sent)):
    print(ner_list(domain_sent[i]))
    if i == 10: break
# Out:
# [('삼성전자', 'ORGANIZATION', [0, 4]), ('인도', 'COUNTRY', [6, 8]), ('중국', 'COUNTRY', [10, 12]), ('스마트폰', 'TERM', [34, 38])]
# [('삼성전자', 'ORGANIZATION', [0, 4]), ('멀티 카메라', 'TERM', [24, 30])]
# [('SBS', 'ORGANIZATION', [0, 3]), ('더 팬', 'ARTIFACT', [14, 17])]
# []
# [('오', 'PERSON', [14, 15]), ('영남권', 'LOCATION', [26, 29])]
# [('목포', 'LOCATION', [0, 2]), ('손혜원', 'PERSON', [14, 17]), ('더불어민주당', 'ORGANIZATION', [18, 24])]
# [('손', 'PERSON', [0, 1])]
# [('손', 'PERSON', [0, 1]), ('국회', 'ORGANIZATION', [18, 20])]
# [('박', 'PERSON', [0, 1])]
# [('북미정상회담', 'EVENT', [3, 9])]
# [('스타벅스커피코리아', 'ORGANIZATION', [0, 9])]

# %%
import random

def get_all_entity_pairs(sentence):
    
    ent_list = ner_list(sentence)
    
#     if len(ent_list) >= 5:
        
#         return random.sample(list(permutations(ent_list, 2)), 3)
    
#     elif len(ent_list) <= 2:
#         return list(permutations(ent_list, 2))
    
#     return random.sample(list(permutations(ent_list, 2)), 3)
    return list(permutations(ent_list, 2))
    
def get_all_inputs_csv_form(sentence):
    pairs = get_all_entity_pairs(sentence)
    return [[sentence, sentence[ent_subj[2][0]:ent_subj[2][1]], ent_subj[2][0], 
             ent_subj[2][1], ent_subj[1], sentence[ent_obj[2][0]:ent_obj[2][1]],
             ent_obj[2][0], ent_obj[2][1], ent_obj[1]] for ent_subj, ent_obj in pairs]

# %%
get_all_entity_pairs(domain_sent[0])
# Out:
# [(('삼성전자', 'ORGANIZATION', [0, 4]), ('인도', 'COUNTRY', [6, 8])),
#  (('삼성전자', 'ORGANIZATION', [0, 4]), ('중국', 'COUNTRY', [10, 12])),
#  (('삼성전자', 'ORGANIZATION', [0, 4]), ('스마트폰', 'TERM', [34, 38])),
#  (('인도', 'COUNTRY', [6, 8]), ('삼성전자', 'ORGANIZATION', [0, 4])),
#  (('인도', 'COUNTRY', [6, 8]), ('중국', 'COUNTRY', [10, 12])),
#  (('인도', 'COUNTRY', [6, 8]), ('스마트폰', 'TERM', [34, 38])),
#  (('중국', 'COUNTRY', [10, 12]), ('삼성전자', 'ORGANIZATION', [0, 4])),
#  (('중국', 'COUNTRY', [10, 12]), ('인도', 'COUNTRY', [6, 8])),
#  (('중국', 'COUNTRY', [10, 12]), ('스마트폰', 'TERM', [34, 38])),
#  (('스마트폰', 'TERM', [34, 38]), ('삼성전자', 'ORGANIZATION', [0, 4])),
#  (('스마트폰', 'TERM', [34, 38]), ('인도', 'COUNTRY', [6, 8])),
#  (('스마트폰', 'TERM', [34, 38]), ('중국', 'COUNTRY', [10, 12]))]

# %%
get_all_inputs_csv_form(domain_sent[0])
# Out:
# [['삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.',
#   '삼성전자',
#   0,
#   4,
#   'ORGANIZATION',
#   '인도',
#   6,
#   8,
#   'COUNTRY'],
#  ['삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.',
#   '삼성전자',
#   0,
#   4,
#   'ORGANIZATION',
#   '중국',
#   10,
#   12,
#   'COUNTRY'],
#  ['삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.',
#   '삼성전자',
#   0,
#   4,
#   'ORGANIZATION',
#   '스마트폰',
#   34,
#   38,
#   'TERM'],
#  ['삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.',
#   '인도',
#   6,
#   8,
#   'COUNTRY',
#   '삼성전자',
#   0,
#   4,
#   'ORGANIZATION'],
#  ['삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.',
#   '인도',
#   6,
#   8,
#   'COUNTRY',
#   '중국',
#   10,
#   12,
#   'COUNTRY'],
#  ['삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.',
#   '인도',
#   6,
#   8,
#   'COUNTRY',
#   '스마트폰',
#   34,
#   38,
#   'TERM'],
#  ['삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.',
#   '중국',
#   10,
#   12,
#   'COUNTRY',
#   '삼성전자',
#   0,
#   4,
#   'ORGANIZATION'],
#  ['삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.',
#   '중국',
#   10,
#   12,
#   'COUNTRY',
#   '인도',
#   6,
#   8,
#   'COUNTRY'],
#  ['삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.',
#   '중국',
#   10,
#   12,
#   'COUNTRY',
#   '스마트폰',
#   34,
#   38,
#   'TERM'],
#  ['삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.',
#   '스마트폰',
#   34,
#   38,
#   'TERM',
#   '삼성전자',
#   0,
#   4,
#   'ORGANIZATION'],
#  ['삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.',
#   '스마트폰',
#   34,
#   38,
#   'TERM',
#   '인도',
#   6,
#   8,
#   'COUNTRY'],
#  ['삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.',
#   '스마트폰',
#   34,
#   38,
#   'TERM',
#   '중국',
#   10,
#   12,
#   'COUNTRY']]

# %%
from tqdm import tqdm

def get_news_test_data(sentences):
    ret_df = pd.DataFrame(columns=['sentence', 'subj_name', 'subj_start_pos', 'subj_end_pos',
                         'subj_type', 'obj_name', 'obj_start_pos', 'obj_end_pos', 'obj_type'])
    for i, sent in enumerate(tqdm(sentences)):
        tmp_df = pd.DataFrame(get_all_inputs_csv_form(sent),
                    columns=['sentence', 'subj_name', 'subj_start_pos', 'subj_end_pos',
                         'subj_type', 'obj_name', 'obj_start_pos', 'obj_end_pos', 'obj_type'])
        ret_df = pd.concat([ret_df, tmp_df], ignore_index=True)
#         if i == 10: break
    return ret_df

# %%
domain_test_df = get_news_test_data(domain_sent)
# Out:
# 100%|██████████| 19486/19486 [40:45<00:00,  7.97it/s]

# %%
domain_test_df.head()
# Out:
#                                             sentence subj_name subj_start_pos  \
# 0  삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.      삼성전자              0
# 1  삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.      삼성전자              0
# 2  삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.      삼성전자              0
# 3  삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.        인도              6
# 4  삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.        인도              6
#
#   subj_end_pos     subj_type obj_name obj_start_pos obj_end_pos      obj_type
# 0            4  ORGANIZATION       인도             6           8       COUNTRY
# 1            4  ORGANIZATION       중국            10          12       COUNTRY
# 2            4  ORGANIZATION     스마트폰            34          38          TERM
# 3            8       COUNTRY     삼성전자             0           4  ORGANIZATION
# 4            8       COUNTRY       중국            10          12       COUNTRY

# %%
domain_test_df.to_csv('../data/news_processed/specific_domain_test.csv', index=False)

# %%
import pandas as pd

new = pd.read_csv('../data/news_processed/specific_domain_test.csv')
new.head()
# Out:
#                                             sentence subj_name  \
# 0  삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.      삼성전자
# 1  삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.      삼성전자
# 2  삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.      삼성전자
# 3  삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.        인도
# 4  삼성전자가 인도, 중국 시장을 겨냥해 혁신기술을 넣은 중저가 스마트폰을 연이어 선보인다.        인도
#
#    subj_start_pos  subj_end_pos     subj_type obj_name  obj_start_pos  \
# 0               0             4  ORGANIZATION       인도              6
# 1               0             4  ORGANIZATION       중국             10
# 2               0             4  ORGANIZATION     스마트폰             34
# 3               6             8       COUNTRY     삼성전자              0
# 4               6             8       COUNTRY       중국             10
#
#    obj_end_pos      obj_type
# 0            8       COUNTRY
# 1           12       COUNTRY
# 2           38          TERM
# 3            4  ORGANIZATION
# 4           12       COUNTRY

# %%
new.tail()
# Out:
#                                                 sentence subj_name  \
# 70259  '더 뱅커' 김상중이 강단 있는 카리스마로 서이숙의 채용 비리 사건을 해결하고 비리...        꼬리
# 70260  '더 뱅커' 김상중이 강단 있는 카리스마로 서이숙의 채용 비리 사건을 해결하고 비리...        꼬리
# 70261  '더 뱅커' 김상중이 강단 있는 카리스마로 서이숙의 채용 비리 사건을 해결하고 비리...        꼬리
# 70262  치료 대안이 마땅치 않은 말기암 환자들에게 희망을 줄 수 있는 혁신적인 항암바이러스...       말기암
# 70263  치료 대안이 마땅치 않은 말기암 환자들에게 희망을 줄 수 있는 혁신적인 항암바이러스...    항암바이러스
#
#        subj_start_pos  subj_end_pos subj_type obj_name  obj_start_pos  \
# 70259              56            58    ANIMAL      김상중              7
# 70260              56            58    ANIMAL      서이숙             24
# 70261              56            58    ANIMAL      유동근             51
# 70262              14            17      TERM   항암바이러스             40
# 70263              40            46      TERM      말기암             14
#
#        obj_end_pos obj_type
# 70259           10   PERSON
# 70260           27   PERSON
# 70261           54   PERSON
# 70262           46     TERM
# 70263           17     TERM

# %%
new.sample(5)
# Out:
#                                                 sentence  subj_name  \
# 24727    현재 수감 중인 장대호는 일산동부경찰서를 나와 수사팀이 꾸려진 고양경찰서로 이동한다.    일산동부경찰서
# 32480  8일 서울 강남구 임피리얼팰리스호텔에서 tvN 토일드라마 '호텔 델루나' 제작발표회...        tvN
# 26242                퍼퓸에서 하재숙과 조한철이 법원 앞에서 만나는 모습이 그려졌다.         퍼퓸
# 13698  에버랜드는 이와 함께 공식 페이스북 영상에 축하 맷글을 단 회원 10명을 선정해 1...       페이스북
# 62804             뮤지컬 웃는 남자가 국내 창작뮤지컬 최초로 영화관에서 정식 개봉한다.  뮤지컬 웃는 남자
#
#        subj_start_pos  subj_end_pos     subj_type obj_name  obj_start_pos  \
# 24727              14            21  ORGANIZATION    고양경찰서             35
# 32480              22            25  ORGANIZATION       서울              3
# 26242               0             2      ARTIFACT       법원             15
# 13698              15            19  ORGANIZATION     에버랜드              0
# 62804               0             9      ARTIFACT    창작뮤지컬             14
#
#        obj_end_pos      obj_type
# 24727           40  ORGANIZATION
# 32480            5          CITY
# 26242           17  ORGANIZATION
# 13698            4  ORGANIZATION
# 62804           19   STUDY_FIELD

# %%
len(new)
# Out:
# 70264
