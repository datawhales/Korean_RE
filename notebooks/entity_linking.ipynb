# %% [markdown]
# ## 전처리된 wikipedia corpus 불러오기

# %%
import json

with open("../data/wikipedia/processed_sentences.json", 'r') as f:
    sentences = json.load(f)

# %%
sentences.keys()
# Out:
# dict_keys(['data'])

# %%
len(sentences['data'])
# Out:
# 3862545

# %%
sentences['data'][:10]
# Out:
# [{'sentence': '제임스 얼 카터 주니어는 민주당 출신 미국 39대 대통령 이다.'},
#  {'sentence': '지미 카터는 조지아주 섬터 카운티 플레인스 마을에서 태어났다.'},
#  {'sentence': '그의 별명이 땅콩 농부 로 알려졌다.'},
#  {'sentence': '1962년 조지아 주 상원 의원 선거에서 낙선하나 그 선거가 부정선거 였음을 입증하게 되어 당선되고, 1966년 조지아 주지사 선거에 낙선하지만, 1970년 조지아 주지사를 역임했다.'},
#  {'sentence': '대통령이 되기 전 조지아주 상원의원을 두번 연임했으며, 1971년부터 1975년까지 조지아 지사로 근무했다.'},
#  {'sentence': '조지아 주지사로 지내면서, 미국에 사는 흑인 등용법을 내세웠다.'},
#  {'sentence': '1976년 미합중국 제39대 대통령 선거에 민주당 후보로 출마하여 도덕주의 정책으로 내세워서, 많은 지지를 받고 제럴드 포드 대통령을 누르고 당선되었다.'},
#  {'sentence': '카터 대통령은 에너지 개발을 촉구했으나 공화당의 반대로 무산되었다.'},
#  {'sentence': '카터는 이집트와 이스라엘을 조정하여 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.'},
#  {'sentence': '이것은 공화당과 미국의 유대인 단체의 반발을 일으켰다.'}]

# %%
def get_sent(idx, json_data=sentences):
    return json_data['data'][idx]['sentence']

# %%
print(get_sent(0))
print(get_sent(1))
# Out:
# 제임스 얼 카터 주니어는 민주당 출신 미국 39대 대통령 이다.
# 지미 카터는 조지아주 섬터 카운티 플레인스 마을에서 태어났다.

# %% [markdown]
# ## Pororo를 사용한 NER 수행 예시

# %%
from pororo import Pororo
ner = Pororo(task='ner', lang='ko')

# %%
ner
# Out:
# [TASK]: NER
# [LANG]: KO
# [MODEL]: charbert.base.ko.ner

# %%
get_sent(0)
# Out:
# '제임스 얼 카터 주니어는 민주당 출신 미국 39대 대통령 이다.'

# %%
ner(get_sent(0))
# Out:
# [('제임스 얼 카터', 'PERSON'),
#  (' ', 'O'),
#  ('주니어', 'CIVILIZATION'),
#  ('는', 'O'),
#  (' ', 'O'),
#  ('민주당', 'ORGANIZATION'),
#  (' ', 'O'),
#  ('출신', 'O'),
#  (' ', 'O'),
#  ('미국', 'COUNTRY'),
#  (' ', 'O'),
#  ('39대', 'QUANTITY'),
#  (' ', 'O'),
#  ('대통령', 'CIVILIZATION'),
#  (' ', 'O'),
#  ('이다.', 'O')]

# %%
ner(get_sent(1))
# Out:
# [('지미 카터', 'PERSON'),
#  ('는', 'O'),
#  (' ', 'O'),
#  ('조지아주', 'LOCATION'),
#  (' ', 'O'),
#  ('섬터 카운티', 'LOCATION'),
#  (' ', 'O'),
#  ('플레인스 마을', 'LOCATION'),
#  ('에서', 'O'),
#  (' ', 'O'),
#  ('태어났다.', 'O')]

# %%
for i in range(5):
    print(ner(get_sent(i)))
    print('\n')
# Out:
# [('제임스 얼 카터', 'PERSON'), (' ', 'O'), ('주니어', 'CIVILIZATION'), ('는', 'O'), (' ', 'O'), ('민주당', 'ORGANIZATION'), (' ', 'O'), ('출신', 'O'), (' ', 'O'), ('미국', 'COUNTRY'), (' ', 'O'), ('39대', 'QUANTITY'), (' ', 'O'), ('대통령', 'CIVILIZATION'), (' ', 'O'), ('이다.', 'O')]
#
#
# [('지미 카터', 'PERSON'), ('는', 'O'), (' ', 'O'), ('조지아주', 'LOCATION'), (' ', 'O'), ('섬터 카운티', 'LOCATION'), (' ', 'O'), ('플레인스 마을', 'LOCATION'), ('에서', 'O'), (' ', 'O'), ('태어났다.', 'O')]
#
#
# [('그의', 'O'), (' ', 'O'), ('별명이', 'O'), (' ', 'O'), ('땅콩', 'PLANT'), (' ', 'O'), ('농부', 'OCCUPATION'), (' ', 'O'), ('로', 'O'), (' ', 'O'), ('알려졌다.', 'O')]
#
#
# [('1962년', 'DATE'), (' ', 'O'), ('조지아 주 상원 의원 선거', 'EVENT'), ('에서', 'O'), (' ', 'O'), ('낙선하나', 'O'), (' ', 'O'), ('그', 'O'), (' ', 'O'), ('선거가', 'O'), (' ', 'O'), ('부정선거', 'O'), (' ', 'O'), ('였음을', 'O'), (' ', 'O'), ('입증하게', 'O'), (' ', 'O'), ('되어', 'O'), (' ', 'O'), ('당선되고,', 'O'), (' ', 'O'), ('1966년', 'DATE'), (' ', 'O'), ('조지아 주지사 선거', 'EVENT'), ('에', 'O'), (' ', 'O'), ('낙선하지만,', 'O'), (' ', 'O'), ('1970년', 'DATE'), (' ', 'O'), ('조지아', 'COUNTRY'), (' ', 'O'), ('주지사', 'CIVILIZATION'), ('를', 'O'), (' ', 'O'), ('역임했다.', 'O')]
#
#
# [('대통령', 'CIVILIZATION'), ('이', 'O'), (' ', 'O'), ('되기', 'O'), (' ', 'O'), ('전', 'O'), (' ', 'O'), ('조지아주', 'LOCATION'), (' ', 'O'), ('상원', 'ORGANIZATION'), ('의원', 'OCCUPATION'), ('을', 'O'), (' ', 'O'), ('두번', 'QUANTITY'), (' ', 'O'), ('연임했으며,', 'O'), (' ', 'O'), ('1971년부터 1975년까지', 'DATE'), (' ', 'O'), ('조지아', 'COUNTRY'), (' ', 'O'), ('지사', 'CIVILIZATION'), ('로', 'O'), (' ', 'O'), ('근무했다.', 'O')]

# %% [markdown]
# ## Entity type 종류 확인

# %%
len(sentences['data'])
# Out:
# 3862545

# %%
import copy

tmp = copy.deepcopy(sentences['data'][0])
tmp
# Out:
# {'sentence': '제임스 얼 카터 주니어는 민주당 출신 미국 39대 대통령 이다.'}

# %%
ner(tmp['sentence'])
# Out:
# [('제임스 얼 카터', 'PERSON'),
#  (' ', 'O'),
#  ('주니어', 'CIVILIZATION'),
#  ('는', 'O'),
#  (' ', 'O'),
#  ('민주당', 'ORGANIZATION'),
#  (' ', 'O'),
#  ('출신', 'O'),
#  (' ', 'O'),
#  ('미국', 'COUNTRY'),
#  (' ', 'O'),
#  ('39대', 'QUANTITY'),
#  (' ', 'O'),
#  ('대통령', 'CIVILIZATION'),
#  (' ', 'O'),
#  ('이다.', 'O')]

# %%
len(ner(tmp['sentence']))
# Out:
# 16

# %%
from tqdm import tqdm

type_dict = {}

for idx in tqdm(range(3000)):
    ner_result = ner(get_sent(idx))
    for item in ner_result:
        if item[1] not in type_dict:
            type_dict[item[1]] = True
# Out:
# 100%|██████████| 3000/3000 [03:05<00:00, 16.14it/s]

# %%
type_dict
# Out:
# {'PERSON': True,
#  'O': True,
#  'CIVILIZATION': True,
#  'ORGANIZATION': True,
#  'COUNTRY': True,
#  'QUANTITY': True,
#  'LOCATION': True,
#  'PLANT': True,
#  'OCCUPATION': True,
#  'DATE': True,
#  'EVENT': True,
#  'THEORY': True,
#  'ARTIFACT': True,
#  'ANIMAL': True,
#  'TERM': True,
#  'STUDY_FIELD': True,
#  'MATERIAL': True,
#  'CITY': True,
#  'TIME': True,
#  'DISEASE': True}

# %% [markdown]
# ## ent2id.json 파일 쓰기
# 개체명이 주어졌을 때 그 개체에 해당하는 위키데이터 id를 대응시키는 json 파일 저장

# %%
from glob import glob

file_list = glob('../data/wikidata/*')
file_list[:10]
# Out:
# ['../data/wikidata/wikidata_84.json',
#  '../data/wikidata/wikidata_92.json',
#  '../data/wikidata/wikidata_51.json',
#  '../data/wikidata/wikidata_10.json',
#  '../data/wikidata/wikidata_47.json',
#  '../data/wikidata/wikidata_30.json',
#  '../data/wikidata/wikidata_88.json',
#  '../data/wikidata/wikidata_67.json',
#  '../data/wikidata/wikidata_71.json',
#  '../data/wikidata/wikidata_26.json']

# %%
file_list[0][26:-5]
# Out:
# '84'

# %%
'../data/wikidata/wikidata_1.json'[26:-5]
# Out:
# '1'

# %%
file_list.sort(key=lambda x: int(x[26:-5]))
file_list[:10]
# Out:
# ['../data/wikidata/wikidata_1.json',
#  '../data/wikidata/wikidata_2.json',
#  '../data/wikidata/wikidata_3.json',
#  '../data/wikidata/wikidata_4.json',
#  '../data/wikidata/wikidata_5.json',
#  '../data/wikidata/wikidata_6.json',
#  '../data/wikidata/wikidata_7.json',
#  '../data/wikidata/wikidata_8.json',
#  '../data/wikidata/wikidata_9.json',
#  '../data/wikidata/wikidata_10.json']

# %%
from glob import glob
import json
from tqdm import tqdm

file_list = glob('../data/wikidata/*')
file_list.sort(key=lambda x: int(x[26:-5]))

result_dict = {}
for filename in tqdm(file_list):
    with open(filename, 'r') as f:
        json_data = json.load(f)
        for ent in json_data['entities']:
            try: result_dict[ent['labels']['ko']] = ent['id']
            except: pass
            
            try:
                for alias in ent['aliases']['ko']:
                    result_dict[alias] = ent['id']
            except: pass
# Out:
# 100%|██████████| 92/92 [20:51<00:00, 13.60s/it]

# %%
result_dict
# Out:
# {'벨기에': 'Q31',
#  '벨기에 왕국': 'Q31',
#  '벨기에왕국': 'Q31',
#  '행복': 'Q5652293',
#  '조지 워싱턴': 'Q586680',
#  '잭 바우어': 'Q24',
#  '더글러스 애덤스': 'Q42',
#  '더글라스 애덤스': 'Q42',
#  '더글러스 노엘 애덤스': 'Q42',
#  '위키데이터': 'Q2013',
#  '위키데이타': 'Q2013',
#  '포르투갈': 'Q45',
#  '남극': 'Q51',
#  '음경': 'Q8124',
#  '컴퓨터': 'Q68',
#  '콤퓨타': 'Q68',
#  '전자계산기': 'Q31087',
#  '계산기': 'Q31087',
#  '인터넷': 'Q5368234',
#  '인터네트': 'Q75',
#  '누리망': 'Q75',
#  '세계망': 'Q75',
#  '지구망': 'Q75',
#  '뉴모노울트라마이크로스코픽실리코볼케이노코니오시스': 'Q102',
#  'Supercalifragilisticexpialidocious': 'Q103',
#  '11월': 'Q125',
#  '사자': 'Q29383673',
#  '개': 'Q16102273',
#  '멍멍이': 'Q144',
#  '새끼 고양이': 'Q147',
#  '중화인민공화국': 'Q148',
#  '중국': 'Q69512774',
#  '중화': 'Q10872642',
#  '브라질': 'Q2923981',
#  '요크셔': 'Q1363458',
#  '피자': 'Q398355',
#  '파스타': 'Q496290',
#  '독일': 'Q183',
#  '도이칠란트': 'Q183',
#  '독일연방공화국': 'Q713750',
#  '조지 W. 부시': 'Q207',
#  '부시': 'Q247949',
#  '조지 워커 부시': 'Q207',
#  '직각': 'Q16190108',
#  '몰타': 'Q1518045',
#  '투르': 'Q65303983',
#  '디에고 벨라스케스': 'Q297',
#  '칠레': 'Q298',
#  '독재': 'Q317',
#  '영어 위키백과': 'Q328',
#  '영위백': 'Q328',
#  '영어위백': 'Q328',
#  '영어 위백': 'Q328',
#  '위키백과 영어판': 'Q328',
#  '영어판 위키백과': 'Q328',
#  '제2차 세계 대전': 'Q362',
#  '2차 대전': 'Q362',
#  '제2차 세계대전': 'Q362',
#  '2차 세계 대전': 'Q362',
#  '2차 세계대전': 'Q362',
#  '2차대전': 'Q362',
#  '월드 워2': 'Q362',
#  '월드워2': 'Q362',
#  '이차 세계대전': 'Q362',
#  '이차 세계 대전': 'Q362',
#  '이차 대전': 'Q362',
#  '이차대전': 'Q362',
#  '아우구스토 피노체트': 'Q368',
#  '바레인': 'Q398',
#  '우주생물학': 'Q411',
#  '파이어니어 금속판': 'Q412',
#  '동물학': 'Q431',
#  '나는 베를린 사람입니다': 'Q443',
#  '백과전서': 'Q447',
#  '론알프': 'Q463',
#  '항문': 'Q497',
#  '샤를 보들레르': 'Q501',
#  '꽃': 'Q18212824',
#  '리옹 미술관': 'Q511',
#  '해부학': 'Q514',
#  '베수비오산': 'Q524',
#  '태양계': 'Q544',
#  '샹젤리제 거리': 'Q550',
#  '수소': 'Q500623',
#  'H': 'Q9914',
#  '오슬로': 'Q585',
#  '크리스티아니아': 'Q585',
#  '본': 'Q16121',
#  '만성절': 'Q587',
#  '언터처블: 1%의 우정': 'Q595',
#  '리스본': 'Q597',
#  '니콜라우스 코페르니쿠스': 'Q619',
#  '닐 영': 'Q633',
#  '행성': 'Q65328355',
#  '포강': 'Q643',
#  '렌': 'Q436603',
#  '릴': 'Q61423639',
#  '북쪽': 'Q659',
#  '북': 'Q18213125',
#  '산문': 'Q676',
#  '바누아투': 'Q686',
#  '염소': 'Q2934',
#  'Cl': 'Q688',
#  '자위트홀란트주': 'Q694',
#  '타이타늄': 'Q716',
#  '티타늄': 'Q716',
#  '티탄': 'Q2565',
#  'Ti': 'Q37574900',
#  '바나듐': 'Q722',
#  'V': 'Q87576234',
#  '프란세지냐': 'Q732',
#  '피에르 코르네유': 'Q747',
#  '흐로닝언': 'Q892499',
#  '균계': 'Q764',
#  '매사추세츠주': 'Q771',
#  '이스라엘': 'Q234180',
#  '로잔': 'Q807',
#  '가브리엘 곤살레스 비델라': 'Q815',
#  '라오스': 'Q61091190',
#  '제임스 본드': 'Q6129980',
#  '안드레이 타르콥스키': 'Q853',
#  '안드레이 타르코프스키': 'Q853',
#  '플라톤': 'Q859',
#  '타지키스탄': 'Q863',
#  '타지크': 'Q863',
#  '태국': 'Q869',
#  '타이': 'Q869',
#  '타이 왕국': 'Q869',
#  '메릴 스트립': 'Q873',
#  '아랍에미리트': 'Q878',
#  'UAE': 'Q878',
#  '백금': 'Q880',
#  '노보시비르스크': 'Q883',
#  '니즈니노브고로드': 'Q891',
#  '옴스크': 'Q898',
#  '수에즈 운하': 'Q899',
#  '과학자': 'Q901',
#  '에트라 에일 산': 'Q903',
#  '고든 프리맨': 'Q907',
#  '말리': 'Q1189617',
#  '앙골라': 'Q916',
#  '브라치섬': 'Q922',
#  '노랑': 'Q21144753',
#  '도날트 투스크': 'Q946',
#  '휴지 거는 방향': 'Q951',
#  '목록의 목록': 'Q957',
#  '오비강': 'Q973',
#  '밈': 'Q3245060',
#  '안드레이 사하로프': 'Q997',
#  '시에라리온': 'Q1044',
#  '수단': 'Q324708',
#  '이탈로 발보': 'Q1056',
#  '물질대사': 'Q1057',
#  '대사': 'Q1071149',
#  '나렌드라 모디': 'Q1058',
#  '지리학': 'Q1071',
#  '지리': 'Q15933',
#  '지리학자': 'Q1071',
#  '스타 트렉': 'Q20922',
#  '림뷔르흐주': 'Q1095',
#  '안티모니': 'Q1099',
#  '안티몬': 'Q1099',
#  'Sb': 'Q1099',
#  '운비닐륨': 'Q1146',
#  'Ubn': 'Q1146',
#  '인디라 간디': 'Q1149',
#  '엑토르 베를리오즈': 'Q1151',
#  '푸에르토리코': 'Q1457040',
#  '자를란트주': 'Q1201',
#  '일리노이주': 'Q1204',
#  '오스카르 루이지 스칼파로': 'Q1228',
#  '더브늄': 'Q1232',
#  '반기문': 'Q1253',
#  '반 기문': 'Q1253',
#  '코피 아난': 'Q1254',
#  '마이트너륨': 'Q1258',
#  '잼': 'Q39074381',
#  '레너드 코언': 'Q1276',
#  '분류:최상위 분류': 'Q1281',
#  '시카고': 'Q656285',
#  '니호늄': 'Q1301',
#  '우눈트륨': 'Q1301',
#  '오사마 빈라덴': 'Q1317',
#  '오사마': 'Q65275352',
#  '프리드리히 하이에크': 'Q1325',
#  '거미강': 'Q1358',
#  '트리푸라주': 'Q1363',
#  '위터젠': 'Q1404',
#  '오토': 'Q645699',
#  '티투스': 'Q1421',
#  '하키': 'Q1622659',
#  '필드하키': 'Q1455',
#  '루아르강': 'Q376133',
#  '해커': 'Q31178608',
#  '멕시코시티': 'Q1489',
#  '미시시피주': 'Q1494',
#  '미시시피 주': 'Q1494',
#  '우타라칸드주': 'Q1499',
#  '리하르트 바그너': 'Q1511',
#  '나그푸르': 'Q1513',
#  '리옹 대성당': 'Q1521',
#  '뉴멕시코주': 'Q1522',
#  '뉴멕시코 주': 'Q1522',
#  '회전교차로': 'Q1525',
#  '람세스 1세': 'Q1526',
#  '카라카스': 'Q1533',
#  '어베스트!': 'Q1574',
#  'avast!': 'Q1574',
#  '발렌수엘라': 'Q65249630',
#  '안티폴로': 'Q1636',
#  '엘베강': 'Q1644',
#  '네카어강': 'Q1673',
#  '북해': 'Q1693',
#  '타바코': 'Q1706',
#  '킬': 'Q31180244',
#  '포츠담': 'Q1711',
#  '뒤셀도르프': 'Q1718',
#  '비스바덴': 'Q1721',
#  '자르브뤼켄': 'Q1724',
#  '사마라현': 'Q1746',
#  '칼리닌그라드주': 'Q1749',
#  '토마시 마예프스키': 'Q1755',
#  '헬싱키': 'Q1757',
#  '무르만스크주': 'Q1759',
#  '애슈턴 이턴': 'Q1789',
#  '고르디아누스 3세': 'Q1812',
#  '가돌리늄': 'Q1832',
#  'Gd': 'Q1832',
#  '영어': 'Q3062484',
#  '방카벨리퉁주': 'Q1866',
#  '븡쿨루주': 'Q1890',
#  '올리비에 지루': 'Q1911',
#  '얀 음빌라': 'Q1925',
#  '시드네 고부': 'Q1934',
#  '지브릴 시세': 'Q1936',
#  '바카리 사냐': 'Q1938',
#  '목성의 위성': 'Q1946',
#  '헤르만 마이어': 'Q1956',
#  '2002년': 'Q1987',
#  '2009년': 'Q3231462',
#  '뉴펀들랜드래브라도주': 'Q2003',
#  '2005년': 'Q2019',
#  '룩셈부르크 구': 'Q2032',
#  '1907년': 'Q2048',
#  '1906년': 'Q2049',
#  'ACF 피오렌티나': 'Q2052',
#  '1909년': 'Q2057',
#  '1993년': 'Q2065',
#  '1996년': 'Q2070',
#  '코미 공화국': 'Q2073',
#  '1912년': 'Q2077',
#  '1999년': 'Q2091',
#  '에드먼턴': 'Q440114',
#  '뒤스부르크': 'Q2100',
#  '자크 시라크': 'Q2105',
#  '아리카이파리나코타주': 'Q2109',
#  '타라파카주': 'Q2114',
#  '만하임': 'Q2119',
#  '빅토리아': 'Q784496',
#  '토트마': 'Q2137',
#  '손오공': 'Q11773777',
#  'XXX': 'Q2149',
#  '1월 2일': 'Q906001',
#  '1922년': 'Q2165',
#  '나리얀마르': 'Q2174',
#  '조르주 퐁피두': 'Q2185',
#  '콜루슈': 'Q2190',
#  'GIF': 'Q2192',
#  '이리가': 'Q2205',
#  '나가': 'Q1036566',
#  '알토오스피시오': 'Q2217',
#  '1월 9일': 'Q838914',
#  '1월 10일': 'Q839368',
#  '1월 13일': 'Q839041',
#  '1월 17일': 'Q838983',
#  '시엔': 'Q61424088',
#  '1월 23일': 'Q839105',
#  '사우론': 'Q2281',
#  '양성자': 'Q2294',
#  '12월 8일': 'Q840464',
#  '2월 5일': 'Q838979',
#  '2월 12일': 'Q839357',
#  '12인의 성난 사람들': 'Q522135',
#  '2월 28일': 'Q839059',
#  '3월 4일': 'Q838975',
#  '3월 10일': 'Q839021',
#  '야로슬라블': 'Q2423',
#  '3월 19일': 'Q838995',
#  '3월 22일': 'Q839162',
#  '사나': 'Q11268133',
#  '1970년': 'Q2474',
#  '1971년': 'Q2475',
#  '1973년': 'Q2477',
#  '30년 전쟁': 'Q2487',
#  '최후의 종교전쟁': 'Q2487',
#  '루트비히 에르하르트': 'Q2496',
#  '4월 13일': 'Q839173',
#  '헬무트 콜': 'Q2518',
#  '5월 15일': 'Q839538',
#  '리하르트 폰 바이츠제커': 'Q2567',
#  '5월 16일': 'Q839633',
#  '빌리 슈토프': 'Q2610',
#  '6월 5일': 'Q839907',
#  '12월 22일': 'Q840480',
#  '10 히기에이아': 'Q2640',
#  '1968년': 'Q2644',
#  '1965년': 'Q2650',
#  '산술 부호화': 'Q2651',
#  '6월 25일': 'Q839885',
#  '6월 23일': 'Q839700',
#  'US 팔레르모': 'Q2674',
#  '빌헬름 2세': 'Q57263',
#  '파르마': 'Q2683',
#  '7월 1일': 'Q839711',
#  '역기점': 'P6259',
#  '7월 31일': 'Q2715',
#  '시에나': 'Q4733472',
#  'AC 시에나': 'Q2756',
#  '8월 15일': 'Q835516',
#  '8월 8일': 'Q840029',
#  '12월 27일': 'Q840878',
#  '브랸스크주': 'Q2810',
#  '8월 23일': 'Q840342',
#  '9월 10일': 'Q840113',
#  '9월 2일': 'Q840347',
#  '9월 1일': 'Q840137',
#  '9월 3일': 'Q840404',
#  '9월 28일': 'Q840059',
#  '9월 27일': 'Q840076',
#  '9월 22일': 'Q840122',
#  '12월 30일': 'Q841067',
#  '10월 11일': 'Q836346',
#  '10월 6일': 'Q840129',
#  '10월 5일': 'Q840255',
#  '아순시온': 'Q2933',
#  '송아지': 'Q2935',
#  '10월 28일': 'Q840432',
#  '자유': 'Q724340',
#  '11월 13일': 'Q840090',
#  '11월 1일': 'Q840273',
#  '파라마리보': 'Q3001',
#  '11월 29일': 'Q840521',
#  '11월 20일': 'Q840455',
#  '11월 22일': 'Q840493',
#  '11월 16일': 'Q840329',
#  '카술레': 'Q3039',
#  '엔주': 'Q3093',
#  '부슈뒤론주': 'Q3240',
#  '우제돔섬': 'Q3255',
#  '목성 탐사': 'Q3276',
#  '아이더강': 'Q3314',
#  '벨고로드': 'Q3323',
#  '루르드': 'Q573999',
#  '벨고로드주': 'Q3329',
#  '트리톤': 'Q2740033',
#  '안네 소피 무터': 'Q3374',
#  '외르에루아르주': 'Q3377',
#  '분류:R.E.M.의 음반': 'Q3493',
#  '콩고강': 'Q3503',
#  '포텐차': 'Q3543',
#  '시베니크': 'Q3549',
#  '몬테페란테': 'Q3563',
#  '세네갈강': 'Q3569',
#  '분류:슬로베니아의 유로비전 송 콘테스트 참가': 'Q3571',
#  '동자와주': 'Q3586',
#  '안다코요': 'Q3602',
#  '칠레령 남극 지역': 'Q3626',
#  '크라스노다르 지방': 'Q3680',
#  '칼데라': 'Q159954',
#  '카라우에': 'Q3736',
#  '카사블랑카': 'Q132689',
#  '카우케네스': 'Q3749',
#  '게라': 'Q65234980',
#  '프라이아': 'Q3751',
#  '마이코프': 'Q3752',
#  '아크라': 'Q3761',
#  '프랑스령 기아나': 'Q3769',
#  '프랑스령 기아나 주': 'Q3769',
#  '코브케쿠라': 'Q3796',
#  '포르토노보': 'Q3799',
#  '하나우': 'Q3802',
#  '분류:스포츠에 관한 틀': 'Q3811',
#  '리브르빌': 'Q3825',
#  '킨샤사': 'Q3838',
#  '코이푸이': 'Q3843',
#  '콘찰리': 'Q3851',
#  '소행성': 'Q3863',
#  '기센': 'Q931711',
#  '코랄': 'Q724473',
#  '루사카': 'Q3881',
#  '갈리시아 지방': 'Q3908',
#  '이진법': 'Q3913',
#  '2진법': 'Q3913',
#  '이진수': 'Q12612813',
#  '2진수': 'Q3913',
#  '밤베르크': 'Q3936',
#  '아스트라한주': 'Q3941',
#  '아샤펜부르크': 'Q3942',
#  '우나': 'Q22060576',
#  '넵투누스': 'Q6995628',
#  '바이마르': 'Q258755',
#  '지도': 'P1943',
#  '파이온': 'Q4097',
#  '바덴바덴': 'Q4100',
#  '기원전 15년': 'Q4101',
#  '슈바인푸르트': 'Q4126',
#  '루이 아라공': 'Q4128',
#  '해밀턴': 'Q852673',
#  '노이슈반슈타인 성': 'Q4152',
#  '분류:대륙별 대학교': 'Q4161',
#  '분류:타지크 소비에트 사회주의 공화국': 'Q4166',
#  '파사우': 'Q4190',
#  '기원전 42년': 'Q4201',
#  '기원전 47년': 'Q4209',
#  '남아메리카 국가 연합': 'Q4230',
#  'UNASUL': 'Q4230',
#  'UNASUR': 'Q4230',
#  '남미국가연합': 'Q4230',
#  '남미 국가 연합': 'Q4230',
#  '분류:몰도바 소비에트 사회주의 공화국': 'Q4246',
#  '미셸 플라티니': 'Q4261',
#  '분류:베냉의 역사': 'Q4265',
#  '톰 델론지': 'Q4270',
#  '투자': 'Q4290',
#  '자본형성': 'Q4290',
#  '존 에이브럼스': 'Q4293',
#  '존 아브라함스': 'Q4293',
#  '존 에이브러햄스': 'Q4293',
#  '모어 화자 수순 언어 목록': 'Q4319',
#  '모어 화자 수 순 언어 목록': 'Q4319',
#  '모국어 화자 수 순 언어 목록': 'Q4319',
#  '사용자 수 순 언어 목록': 'Q4319',
#  '모국어 사용자 수 순 언어 목록': 'Q4319',
#  '언어 사용자수 순위': 'Q4319',
#  '분류:스웨덴에 관한 토막글': 'Q4352',
#  '분류:에스토니아 소비에트 사회주의 공화국': 'Q4357',
#  'DMG': 'Q4359',
#  '펄사': 'Q4360',
#  '펄스별': 'Q4360',
#  '맥동전파원': 'Q4360',
#  '2014년 동계 올림픽 아이스하키': 'Q4382',
#  '청서': 'Q4388',
#  '청설모(靑鼠毛)': 'Q4388',
#  '붉은청서': 'Q4388',
#  '청서모': 'Q4388',
#  '북방청서': 'Q4388',
#  '청설모': 'Q4388',
#  'LX': 'Q4436',
#  '에밀리 디킨슨': 'Q4441',
#  '에밀리 엘리자베스 디킨슨': 'Q4441',
#  '에밀리아 디킨슨': 'Q4441',
#  '분류:소목': 'Q4445',
#  '분류:인도네시아의 세계유산': 'Q4459',
#  '타이타닉 II': 'Q4466',
#  '분류:소련 사람': 'Q4467',
#  '애나 패리스': 'Q4491',
#  '안나 페리스': 'Q4491',
#  '안나 패리스': 'Q4491',
#  '애나 케이 패리스': 'Q4491',
#  '밋 롬니': 'Q4496',
#  '분류:1421년 태어남': 'Q4497',
#  '분류:튀니지 사람': 'Q4515',
#  '코모도 국립공원': 'Q4520',
#  '분류:이념별 정당': 'Q4559',
#  '페로 제도의 기': 'Q4575',
#  '페로 제도의 국기': 'Q4575',
#  '랑카과': 'Q4582',
#  '란카과': 'Q4582',
#  '솔로몬 제도 달러': 'Q4597',
#  '솔로몬제도달러': 'Q4597',
#  '솔로몬제도 달러': 'Q4597',
#  '서던캘리포니아 대학교': 'Q4614',
#  '남가주대학': 'Q4614',
#  '서던 캘리포니아 대학교': 'Q4614',
#  '남가주대학교': 'Q4614',
#  '남캘리포니아 대학교': 'Q4614',
#  '남가주 대학': 'Q4614',
#  '남가주 대학교': 'Q4614',
#  '남가주대': 'Q4614',
#  '쾰른어': 'Q4624',
#  '분류:필리핀의 역사': 'Q4637',
#  '클로드 드뷔시': 'Q4700',
#  '드뷔시': 'Q10264626',
#  '끌로드 드뷔시': 'Q4700',
#  '맥노트 혜성': 'Q4705',
#  '2012년 메이저 리그 베이스볼 시즌': 'Q4760',
#  '기둥': 'Q4817',
#  '주랑 열주': 'Q4817',
#  '분류:1888년 태어남': 'Q4834',
#  '틀:파리의 구': 'Q4874',
#  '분류:대중음악': 'Q4929',
#  '이헬스': 'Q4930',
#  '분류:뉴질랜드의 지리': 'Q4949',
#  '분류:뉴질랜드의 섬': 'Q4950',
#  '백조자리 NML': 'Q4957',
#  '조지아': 'Q230',
#  '죠지아': 'Q4962',
#  '분류:이탈리아의 라디오 방송국': 'Q4969',
#  'SAB밀러': 'Q4995',
#  '분류:19세기 영국': 'Q5025',
#  '틀:찬성': 'Q5056',
#  '금 희종': 'Q5071',
#  '금 해릉왕': 'Q5072',
#  '말루쿠주': 'Q5093',
#  '스테판의 다섯 은하': 'Q5114',
#  '포르투갈어': 'Q5146',
#  '포도아어': 'Q5146',
#  '포르투칼 어': 'Q5146',
#  '포르투갈 어': 'Q5146',
#  '포어': 'Q5146',
#  '포르투칼어': 'Q5146',
#  '동문동물': 'Q5182',
#  '유조동물': 'Q5191',
#  '스타브로폴': 'Q5206',
#  '1956년': 'Q5221',
#  '1210년': 'Q5250',
#  '1212년': 'Q5255',
#  '사타바하나 왕조': 'Q5257',
#  '1926년': 'Q5259',
#  '천문시계': 'Q5275',
#  '타를라크': 'Q5285',
#  '중앙 처리 장치': 'P880',
#  'CPU': 'P880',
#  'TeX': 'Q5301',
#  '스페이스 니들': 'Q5317',
#  '저항기': 'Q5321',
#  '축전기': 'Q5322',
#  '데시벨': 'Q1051158',
#  '기욤 9세': 'Q5351',
#  '1218년': 'Q5381',
#  '데이비드 보위': 'Q5383',
#  '자동차 경주': 'Q5386',
#  '올림픽': 'Q5389',
#  '그레이트 데인': 'Q5414',
#  '1231년': 'Q5417',
#  '요시카르올라': 'Q5449',
#  '1247년': 'Q5482',
#  '1254년': 'Q5500',
#  '1256년': 'Q5502',
#  '1258년': 'Q5506',
#  '1259년': 'Q5507',
#  '1274년': 'Q5527',
#  '1275년': 'Q5529',
#  '1278년': 'Q5533',
#  '1290년': 'Q5552',
#  '1298년': 'Q5563',
#  '안드레아 델 사르토': 'Q5571',
#  '알브레히트 뒤러': 'Q5580',
#  '가쓰시카 호쿠사이': 'Q5586',
#  '쿠로니아 사주': 'Q5595',
#  '네만강': 'Q5622',
#  '1305년': 'Q5624',
#  '프라 안젤리코': 'Q5664',
#  '아부 누와스': 'Q5670',
#  '알하산 이븐 하니': 'Q5670',
#  '마쓰오 바쇼': 'Q5676',
#  '남사보 지역': 'Q5693',
#  '우르': 'Q747022',
#  '벨로바르': 'Q5707',
#  '바시키르 공화국': 'Q5710',
#  '우시마 지역': 'Q5711',
#  '마리': 'Q97961606',
#  '필리프 페탱': 'Q5721',
#  '아누라다푸라': 'Q5724',
#  '1325년': 'Q5774',
#  '반다아체': 'Q5779',
#  '콘스탄티누스 개선문': 'Q5786',
#  '마사초': 'Q5811',
#  '카나리아 제도': 'Q5813',
#  '마오쩌둥': 'Q5816',
#  '모택동': 'Q5816',
#  '모룬즈': 'Q5816',
#  '모주석': 'Q5816',
#  '시안시': 'Q5826',
#  '톨레도': 'Q1776774',
#  '청색 낙오성': 'Q5848',
#  '럭비 유니온': 'Q5849',
#  '라싸시': 'Q5869',
#  '라하사': 'Q5869',
#  '거성': 'Q5875',
#  '적색왜성': 'Q5893',
#  '아헨 대성당': 'Q5908',
#  '우주 비행': 'Q5916',
#  '척 베리': 'Q5921',
#  '아이칼리의 에피소드 목록': 'Q5951',
#  '쿠르티오스 루포스': 'Q5959',
#  '잉글리시 프리미어십': 'Q5960',
#  '흑색왜성': 'Q5976',
#  '랩': 'Q12594003',
#  '라파예르비': 'Q6020',
#  '1342년': 'Q6069',
#  '이비 카마르구': 'Q6105',
#  '포틀랜드': 'Q980152',
#  '오베르하벨 군': 'Q6119',
#  '1355년': 'Q6123',
#  '1500년': 'Q6126',
#  '1356년': 'Q6130',
#  '1357년': 'Q6135',
#  '1408년': 'Q6138',
#  '1358년': 'Q6140',
#  '1359년': 'Q6143',
#  '조스트': 'Q6149',
#  '엘베엘스터 군': 'Q6152',
#  '1506년': 'Q6154',
#  '1509년': 'Q6177',
#  '1415년': 'Q6183',
#  '1516년': 'Q6212',
#  '코번트리': 'Q6225',
#  '키토스 전쟁': 'Q6254',
#  '파비아': 'Q65305006',
#  '1517년': 'Q6263',
#  '1423년': 'Q6267',
#  '1376년': 'Q6282',
#  '1425년': 'Q6283',
#  '1520년': 'Q6284',
#  '1434년': 'Q6360',
#  '광증발 효과': 'Q6361',
#  '1391년': 'Q6378',
#  '1392년': 'Q6382',
#  '수영': 'Q233385',
#  '헤엄': 'Q6388',
#  '브리브라가야르드': 'Q6393',
#  '1394년': 'Q6398',
#  '1396년': 'Q6405',
#  '바르보라 슈포타코바': 'Q6419',
#  '풀다강': 'Q6434',
#  '1448년': 'Q6439',
#  '몽펠리에': 'Q6441',
#  '1533년': 'Q6443',
#  '1451년': 'Q6455',
#  '1452년': 'Q6460',
#  'BAC 1-11': 'Q6504',
#  '피네간의 경야': 'Q6507',
#  '쇠렌 키르케고르': 'Q6512',
#  '하카스 공화국': 'Q6543',
#  '1550년': 'Q6557',
#  '분류:천문학자': 'Q6562',
#  '1470년': 'Q6569',
#  '온포도주': 'Q6584',
#  '해왕성 바깥 천체': 'Q6592',
#  '1473년': 'Q6594',
#  '고리치아': 'Q6596',
#  '명왕성족': 'Q6599',
#  '1564년': 'Q6632',
#  '포카라': 'Q6640',
#  '1569년': 'Q6653',
#  '크로아티아어': 'Q6654',
#  'UTC+01:30': 'Q6706',
#  '그로세토': 'Q6716',
#  '1603년': 'Q6735',
#  '1587년': 'Q6744',
#  '1606년': 'Q6747',
#  '1607년': 'Q6756',
#  '1608년': 'Q6758',
#  'AS 리보르노 칼초': 'Q6767',
#  '1593년': 'Q6772',
#  '1615년': 'Q6784',
#  '1596년': 'Q6785',
#  '바닥 쿼크': 'Q6786',
#  '울란우데': 'Q6816',
#  '1628년': 'Q6840',
#  'B형 간염 바이러스': 'Q6844',
#  '1709년': 'Q6857',
#  '1632년': 'Q6865',
#  '국제천문연맹': 'Q6867',
#  'IAU': 'Q6867',
#  '1712년': 'Q6871',
#  '1805년': 'Q6898',
#  '1640년': 'Q6901',
#  'UTC+06': 'Q6906',
#  '1642년': 'Q6912',
#  '1808년': 'Q6914',
#  'UTC+06:30': 'Q6923',
#  '1646년': 'Q6930',
#  '1813년': 'Q6937',
#  '1652년': 'Q6962',
#  '1732년': 'Q6966',
#  'UTC+07:30': 'Q6971',
#  '1821년': 'Q6976',
#  '1656년': 'Q6982',
#  '프라이징': 'Q6998',
#  '비터펠드 울펜': 'Q7007',
#  '18세기': 'Q7015',
#  '15세기': 'Q7018',
#  '루가노': 'Q7024',
#  '오버우어젤': 'Q7044',
#  'UTC+09:30': 'Q7048',
#  '쾌락주의': 'Q7064',
#  'UTC+14': 'Q7130',
#  '생태학': 'Q7150',
#  '유전학': 'Q7162',
#  '진나라': 'Q62454',
#  '마리 퀴리': 'Q7186',
#  '지로나주': 'Q7194',
#  '시몬 드 보부아르': 'Q7197',
#  '자영': 'Q69507879',
#  '전한 소제': 'Q12615372',
#  '소포클레스': 'Q7235',
#  '전한 애제': 'Q7237',
#  '생물': 'Q7239',
#  '아그네스 포켈스': 'Q7249',
#  '한 경시제': 'Q7262',
#  '공화제': 'Q7270',
#  '공화정': 'Q7270',
#  '공화국': 'Q423',
#  '민국': 'Q10907825',
#  '입헌공화정체': 'Q7270',
#  '후한 장제': 'Q7277',
#  '후한 소제': 'Q7288',
#  '나치 독일': 'Q7318',
#  '국가사회주의 독일 노동자당': 'Q7320',
#  '나찌당': 'Q7320',
#  '나치당': 'Q7320',
#  '오토 프랑크': 'Q7336',
#  '마르고트 프랑크': 'Q7339',
#  '존 콜트레인': 'Q7346',
#  '인더스강': 'Q7348',
#  '서진 혜제': 'Q7357',
#  '근육': 'Q7365',
#  '양': 'Q24856195',
#  '동진 원제': 'Q7392',
#  '동진 성제': 'Q7394',
#  '동진 목제': 'Q7396',
#  '서하 헌종': 'Q7458',
#  '텐더로인': 'Q7464',
#  '도로시 호지킨': 'Q7487',
#  '우구데이 칸': 'Q7519',
#  '세바스토폴': 'Q614147',
#  '볼히니아': 'Q7530',
#  '잉마르 베리만': 'Q7546',
#  '루츠크': 'Q7550',
#  '어머니': 'P25',
#  '눈': 'Q1478870',
#  '1741년': 'Q7573',
#  '1831년': 'Q7579',
#  '1743년': 'Q7580',
#  '1832년': 'Q7584',
#  '1666년': 'Q7585',
#  '1667년': 'Q7588',
#  '1746년': 'Q7589',
#  '1748년': 'Q7600',
#  '1749년': 'Q7607',
#  '1671년': 'Q7610',
#  '1750년': 'Q7611',
#  '1752년': 'Q7618',
#  '1674년': 'Q7620',
#  '1753년': 'Q7621',
#  '1679년': 'Q7638',
#  '1846년': 'Q7640',
#  '1765년': 'Q7665',
#  '1770년': 'Q7683',
#  '1692년': 'Q7685',
#  '1773년': 'Q7692',
#  '수구': 'Q7707',
#  '1699년': 'Q7710',
#  '그라치아 델레다': 'Q7728',
#  '1788년': 'Q7765',
#  '1876년': 'Q7766',
#  '비로비잔': 'Q7769',
#  '1789년': 'Q7772',
#  '프랑스의 역사': 'Q7778',
#  '하바롭스크 지방': 'Q7788',
#  '석유 수출국 기구': 'Q7795',
#  '석유수출국기구': 'Q7795',
#  '국제법원': 'Q85974065',
#  'ICJ': 'Q7801',
#  '국제사법재판소': 'Q7801',
#  '1880년': 'Q7806',
#  '호머 심슨': 'Q7810',
#  '세계 인권 선언': 'Q7813',
#  '1795년': 'Q7815',
#  '수다크': 'Q7830',
#  '1895년': 'Q7844',
#  '1897년': 'Q7847',
#  '랠리': 'Q7856',
#  '샤워': 'Q7863',
#  '불가리아어': 'Q7918',
#  '교육학': 'Q7922',
#  '뒤셀도르프 현': 'Q7926',
#  '진리': 'Q7949',
#  '마가단주': 'Q7971',
#  '마우스': 'Q225839',
#  '컴퓨터 마우스': 'Q7987',
#  '이반 4세': 'Q7996',
#  '인도 그랑프리': 'Q8025',
#  '페어리': 'Q30318131',
#  '인디애나폴리스 500': 'Q8032',
#  '루이 앙투안 드 파르다이앙 드 공드렝': 'Q8056',
#  '루이-앙투안 드 파르다이앙 드 공드렝': 'Q8056',
#  '닌텐도': 'Q8093',
#  'Nintendo': 'Q8093',
#  '닌텐도주식회사': 'Q8093',
#  '닌텐도가부시키가이샤': 'Q8093',
#  '바람': 'Q2914621',
#  '팔렘방': 'Q8131',
#  '조세': 'Q61428333',
#  '세': 'Q201',
#  '세금': 'Q8161',
#  '프라이부르크 현': 'Q8167',
#  '튀빙겐 현': 'Q8170',
#  '팡칼피낭': 'Q8179',
#  '이와바': 'Q8194',
#  '키릴 문자': 'Q8209',
#  '비랏나가르': 'Q8247',
#  '분류:문학': 'Q8259',
#  '겐지 이야기': 'Q8269',
#  '다발성 경화증': 'Q8277',
#  '중증 근무력증': 'Q8285',
#  '아칸소강': 'Q8319',
#  '여우': 'Q8331',
#  '재즈': 'Q3163324',
#  '장 1세': 'Q298901',
#  '콘스탄티누스 1세': 'Q8413',
#  '혼인': 'Q16178901',
#  '스페인어 위키백과': 'Q8449',
#  '인권': 'Q69507881',
#  '인권적 접근': 'Q8458',
#  '고속도로 1호선': 'Q8477',
#  'A01': 'Q8477',
#  '표트르 1세': 'Q8479',
#  '로가르 주': 'Q8480',
#  '1992년 하계 올림픽': 'Q8488',
#  '산': 'Q62735767',
#  '헬만드강': 'Q8510',
#  '2004년 하계 올림픽': 'Q8558',
#  '원 태정제': 'Q8560',
#  '2012년 하계 올림픽': 'Q8577',
#  '슈뢰딩거의 고양이': 'Q8588',
#  '라스페치아': 'Q8611',
#  '베스트팔렌': 'Q8614',
#  '원 천순제': 'Q8653',
#  '목동자리': 'Q8667',
#  '중동 전쟁': 'Q8669',
#  '제69회 골든 글로브상': 'Q8671',
#  '용자리': 'Q8675',
#  '글래스고 공항': 'Q8721',
#  '아르키메데스': 'Q8739',
#  '데포르티보 라코루냐': 'Q8760',
#  'RCD 에스파뇰': 'Q8780',
#  '보잉 747-8': 'Q8791',
#  'HTML': 'Q8811',
#  'HyperText Markup Language': 'Q8811',
#  '오귀스탱 루이 코시': 'Q8814',
#  '팔마데마요르카': 'Q8826',
#  '라스피냐스': 'Q8854',
#  '오리온자리': 'Q8860',
#  '유럽 중앙은행': 'Q8901',
#  'ECB': 'Q297207',
#  '유럽 중앙은행(ECB)': 'Q8901',
#  '유럽중앙은행(ECB)': 'Q8901',
#  '유럽 평의회': 'Q8908',
#  '유럽 경제 지역': 'Q8932',
#  '이수데르 조리그투 칸': 'Q8985',
#  '샤프하우젠': 'Q9009',
#  '만달루용': 'Q9085',
#  '벨라루스어': 'Q9091',
#  '윌프레드 번게이': 'Q9096',
#  '모나코 그랑프리': 'Q9102',
#  '닉 윌리스': 'Q9112',
#  '케네니사 베켈레': 'Q9119',
#  '실레시 시히네': 'Q9132',
#  '간다키 구': 'Q9133',
#  '리처드 마텔롱': 'Q9146',
#  '데이비드 올리버': 'Q9162',
#  '룸비니 구': 'Q9172',
#  '종교': 'P140',
#  '미국 그랑프리 웨스트': 'Q9220',
#  '헝가리 그랑프리': 'Q9233',
#  '샐러드': 'Q9266',
#  '투르크멘어': 'Q9267',
#  '반다르스리브가완': 'Q9279',
#  '멀런 칸': 'Q9293',
#  '갈리시아어': 'Q9307',
#  '투멘 자사그트 칸': 'Q9335',
#  '플라망 지역': 'Q9337',
#  '파르미자니노': 'Q9348',
#  '지롤라모 프란체스코 마리아 마졸라': 'Q9348',
#  '두샨베': 'Q9365',
#  '구글 검색': 'Q9366',
#  '사마천': 'Q9372',
#  '콩팥': 'Q9377',
#  '신장': 'Q20444525',
#  '래빗': 'Q9394',
#  '토끼': 'Q65090699',
#  '도이체 텔레콤': 'Q9396',
#  '팀북투': 'Q16653473',
#  '아널드 파머': 'Q9434',
#  '무함마드': 'Q230604',
#  '몬칼리에리': 'Q9474',
#  '다람쥐과': 'Q9482',
#  '확률': 'Q9492',
#  '압둘 칼람': 'Q9513',
#  '살만 칸': 'Q471472',
#  '마르틴 루터': 'Q9554',
#  '리처드 닉슨': 'Q9588',
#  '1940년 동계 올림픽': 'Q9607',
#  '정맥': 'Q9609',
#  '1944년 동계 올림픽': 'Q9613',
#  '테임 임팔라': 'Q9619',
#  '신경': 'Q17099363',
#  '1956년 동계 올림픽': 'Q9632',
#  '1960년 동계 올림픽': 'Q9634',
#  '입': 'Q9635',
#  '1968년 동계 올림픽': 'Q9642',
#  '관절': 'Q9644',
#  '동맥': 'Q9655',
#  '미하엘 슈마허': 'Q9671',
#  '2006년 동계 올림픽': 'Q9672',
#  '켈리 스미스': 'Q9675',
#  '뉴욕 타임스': 'Q9684',
#  '베를린 테겔 국제공항': 'Q9688',
#  '스히폴 국제공항': 'Q9694',
#  '누메아': 'Q9733',
#  'U': 'Q87544646',
#  '당 대종': 'Q9753',
#  '당 순종': 'Q9760',
#  'F': 'Q87523917',
#  'J': 'Q87570644',
#  '시타르트헬레인': 'Q9781',
#  '헤넙': 'Q9800',
#  '동겐': 'Q9829',
#  '알파': 'Q64711772',
#  '썬키스트': 'Q9929',
#  '환타': 'Q5367266',
#  '홀란츠크론': 'Q9936',
#  'N': 'Q87523845',
#  'S': 'Q87571129',
#  'W': 'Q87576236',
#  '더블유': 'Q22774205',
#  '정통제': 'Q9983',
#  'Â': 'Q87496839',
#  '홍치제': 'Q9994',
#  '네덜란드어 위키백과': 'Q10000',
#  '정덕제': 'Q10007',
#  'Ã': 'Q87496840',
#  '캄펀': 'Q10014',
#  '잎거미과': 'Q10049',
#  '제이스트': 'Q10056',
#  '태창제': 'Q10065',
#  '힌두인': 'Q10090',
#  '애널리스 코버거': 'Q10095',
#  '탕에랑': 'Q10127',
#  '리사 레이먼드': 'Q10129',
#  '클링온어': 'Q10134',
#  '유로비전 송 콘테스트 2012': 'Q10161',
#  '프랑크푸르터 알게마이네 차이퉁': 'Q10184',
#  '통': 'Q19941361',
#  '알루나조지': 'Q10353',
#  '치마히': 'Q10394',
#  '파리자리': 'Q10435',
#  '봉황자리': 'Q10441',
#  '카멜레온자리': 'Q10457',
#  'FC 바르셀로나 B': 'Q10467',
#  '공기펌프자리': 'Q10481',
#  '알랭 프로스트': 'Q10494',
#  '니더바이에른 현': 'Q10559',
#  '오버바이에른 현': 'Q10562',
#  '이리자리': 'Q10571',
#  '시계자리': 'Q10574',
#  '톰 클레벌리': 'Q10577',
#  '분류:용자리': 'Q10596',
#  '케부멘': 'Q10617',
#  '분류:처녀자리': 'Q10638',
#  '풋볼 매니저': 'Q10640',
#  '메가 드라이브': 'Q10676',
#  '벨파스트': 'Q757178',
#  '주기율표': 'Q2685995',
#  '스티브 벨렉': 'Q10727',
#  '다니엘 푸딜': 'Q10732',
#  '스페인의 광역자치주': 'Q10742',
#  '나체': 'Q10791',
#  '알몸': 'Q10791',
#  '아우토반 37호선': 'Q10803',
#  'BAB 37': 'Q10803',
#  'A 37': 'Q10803',
#  '콕링': 'Q10807',
#  '몬테카스트릴리': 'Q10830',
#  '아우토반 73호선': 'Q10844',
#  'BAB 73': 'Q10844',
#  'A 73': 'Q10844',
#  '아우토반 73': 'Q10844',
#  '아우토반 93호선': 'Q10848',
#  'BAB 93': 'Q10848',
#  'A 93': 'Q10848',
#  '레이철 양키': 'Q10883',
#  '산베난초': 'Q10901',
#  '에브로강': 'Q10965',
#  '기술': 'Q205961',
#  '인디펜던트': 'Q11149',
#  '경계 경로 프로토콜': 'Q11155',
#  '동적 호스트 구성 프로토콜': 'Q11166',
#  '율리우스력': 'Q11184',
#  '세계 인구': 'Q11188',
#  '메시에 3': 'Q11202',
#  '프톨레마이오스 성단': 'Q11234',
#  '세계 무역 센터': 'Q20861677',
#  '로어맨해튼': 'Q11253',
#  '메시에 9': 'Q11258',
#  '풀헨시오 바티스타': 'Q11270',
#  '마이크로소프트 엑셀': 'Q11272',
#  ...}

# %%
len(result_dict)
# Out:
# 1598195

# %%
result_dict['제임스 얼 카터']
# Out:
# 'Q23685'

# %%
with open('../data/processed_data/ent2id.json', 'w', encoding='utf-8') as f:
    json.dump(result_dict, f, indent=4)

# %% [markdown]
# ## entid2rel.json 파일 쓰기
# 개체 id가 주어졌을 때 그 개체가 가지는 모든 관계 정보를 대응시키는 json 파일 저장

# %%
from glob import glob
import json
from tqdm import tqdm

file_list = glob('../data/wikidata/*')
file_list.sort(key=lambda x: int(x[26:-5]))

result_dict = {}

for filename in tqdm(file_list):
    with open(filename, 'r') as f:
        json_data = json.load(f)
        
        for ent in json_data['entities']:
            tmp_rel_dict = {}
            
            for key in ent['relations']:                    
                for ent_id in ent['relations'][key]:
                    tmp_rel_dict[ent_id] = key
                    
            result_dict[ent['id']] = tmp_rel_dict
# Out:
# 100%|██████████| 92/92 [12:57:36<00:00, 507.13s/it]

# %%
len(result_dict)
# Out:
# 92000000

# %%
result_dict

# %%
result_dict['Q31']
# Out:
# {'Q1088364': 'P1344',
#  'Q3247091': 'P1151',
#  'Q1308013': 'P1546',
#  'Q7112200': 'P5125',
#  'Q4916': 'P38',
#  'Q232415': 'P38',
#  'Q7021332': 'P1792',
#  'Q1061257': 'P2852',
#  'Q25648793': 'P2852',
#  'Q25648794': 'P2852',
#  'Q25648798': 'P2852',
#  'Q1378312': 'P2853',
#  'Q2335536': 'P2853',
#  'Q1115035': 'P2633',
#  'Q213107': 'P1313',
#  'Q128267': 'P417',
#  'Q31': 'P17',
#  'Q25929919': 'P2959',
#  'Q42311082': 'P2959',
#  'Q52884026': 'P2959',
#  'Q41614': 'P122',
#  'Q3330103': 'P122',
#  'Q3174312': 'P1552',
#  'Q223933': 'P793',
#  'Q1160895': 'P793',
#  'Q32': 'P47',
#  'Q38': 'P530',
#  'Q183': 'P47',
#  'Q347': 'P530',
#  'Q408': 'P530',
#  'Q212': 'P530',
#  'Q1246': 'P530',
#  'Q142': 'P47',
#  'Q145': 'P530',
#  'Q16': 'P530',
#  'Q252': 'P530',
#  'Q35': 'P530',
#  'Q43': 'P530',
#  'Q55': 'P47',
#  'Q77': 'P530',
#  'Q833': 'P530',
#  'Q843': 'P530',
#  'Q865': 'P530',
#  'Q96': 'P530',
#  'Q974': 'P530',
#  'Q30': 'P530',
#  'Q159': 'P530',
#  'Q668': 'P530',
#  'Q41': 'P530',
#  'Q148': 'P530',
#  'Q230': 'P530',
#  'Q801': 'P530',
#  'Q29999': 'P47',
#  'Q28': 'P530',
#  'Q423': 'P530',
#  'Q13592862': 'P1906',
#  'Q1137059': 'P194',
#  'Q205317': 'P2184',
#  'Q7411': 'P2936',
#  'Q150': 'P2936',
#  'Q188': 'P2936',
#  'Q46': 'P361',
#  'Q239': 'P36',
#  'Q199614': 'P237',
#  'Q4366768': 'P910',
#  'Q155004': 'P35',
#  'Q12971': 'P35',
#  'Q12967': 'P35',
#  'Q55008046': 'P35',
#  'Q12973': 'P35',
#  'Q12976': 'P35',
#  'Q3911': 'P35',
#  'Q445553': 'P35',
#  'Q1079522': 'P35',
#  'Q7974978': 'P1791',
#  'Q54439832': 'P5008',
#  'Q18434995': 'P6',
#  'Q950958': 'P6',
#  'Q476596': 'P6',
#  'Q458': 'P361',
#  'Q1065': 'P361',
#  'Q7184': 'P463',
#  'Q41550': 'P463',
#  'Q8908': 'P463',
#  'Q13116': 'P361',
#  'Q42262': 'P463',
#  'Q7825': 'P463',
#  'Q141720': 'P463',
#  'Q1542735': 'P463',
#  'Q152299': 'P463',
#  'Q151991': 'P463',
#  'Q81299': 'P463',
#  'Q191384': 'P463',
#  'Q827525': 'P463',
#  'Q656801': 'P463',
#  'Q1043527': 'P463',
#  'Q899770': 'P463',
#  'Q340195': 'P463',
#  'Q188822': 'P463',
#  'Q782942': 'P463',
#  'Q161549': 'P463',
#  'Q1377612': 'P463',
#  'Q663492': 'P463',
#  'Q1928989': 'P463',
#  'Q1072120': 'P463',
#  'Q8475': 'P463',
#  'Q1480793': 'P463',
#  'Q842490': 'P463',
#  'Q3866537': 'P463',
#  'Q521227': 'P463',
#  'Q233611': 'P463',
#  'Q826700': 'P463',
#  'Q7809': 'P463',
#  'Q5611262': 'P463',
#  'Q17495': 'P463',
#  'Q376150': 'P463',
#  'Q1969730': 'P463',
#  'Q1531570': 'P463',
#  'Q134102': 'P463',
#  'Q45177': 'P463',
#  'Q170424': 'P463',
#  'Q7817': 'P463',
#  'Q13196750': 'P5658',
#  'Q594406': 'P1830',
#  'Q740553': 'P1830',
#  'Q1644661': 'P1830',
#  'Q2697443': 'P1830',
#  'Q3145723': 'P1830',
#  'Q1956014': 'P1830',
#  'Q2005282': 'P1830',
#  'Q536120': 'P1830',
#  'Q7522716': 'P1740',
#  'Q390947': 'P208',
#  'Q130201': 'P2238',
#  'Q8366417': 'P1465',
#  'Q161539': 'P85',
#  'Q1755321': 'P209',
#  'Q1230309': 'P209',
#  'Q1761425': 'P209',
#  'Q215669': 'P361',
#  'Q476033': 'P361',
#  'Q39773': 'P78',
#  'Q3624078': 'P31',
#  'Q43702': 'P31',
#  'Q6256': 'P31',
#  'Q20181813': 'P31',
#  'Q185441': 'P31',
#  'Q1250464': 'P31',
#  'Q322824': 'P610',
#  'Q7463296': 'P1464',
#  'Q14565199': 'P1622',
#  'Q25989': 'P421',
#  'Q6655': 'P421',
#  'Q6723': 'P421',
#  'Q207020': 'P421',
#  'Q5412099': 'P421',
#  'Q9337': 'P150',
#  'Q240': 'P527',
#  'Q9331': 'P527',
#  'Q89959': 'P527',
#  'Q90027': 'P527',
#  'Q231': 'P527',
#  'Q337104': 'P138',
#  'Q12990': 'P163',
#  'Q302556': 'P1343',
#  'Q2657718': 'P1343',
#  'Q4114391': 'P1343',
#  'Q602358': 'P1343',
#  'Q19211082': 'P1343',
#  'Q19180675': 'P1343',
#  'Q4173137': 'P1343',
#  'Q3181656': 'P1343',
#  'Q633629': 'P92',
#  'Q14455339': 'P6104',
#  'Q234': 'P527',
#  'Q685918': 'P1304',
#  'Q100103': 'P2936',
#  'Q102172': 'P2936',
#  'Q2107617': 'P2936',
#  'Q3217332': 'P2936',
#  'Q9051': 'P2936',
#  'Q34024': 'P2936',
#  'Q34219': 'P2936',
#  'Q430018': 'P2936',
#  'Q671198': 'P2936',
#  'Q151156': 'P2936',
#  'Q34147': 'P2936',
#  'Q1404296': 'P2936',
#  'Q815549': 'P2936',
#  'Q2668371': 'P2936',
#  'Q8641': 'P2936',
#  'Q33282': 'P2936',
#  'Q1793299': 'P2936',
#  'Q792363': 'P2596',
#  'Q8607310': 'P7867',
#  'Q63413946': 'P8402',
#  'Q15864': 'P1365',
#  'Q1769535': 'P8744'}

# %%
with open('../data/processed_data/entid2rel.json', 'w', encoding='utf-8') as f:
    json.dump(result_dict, f, indent=4)

# %%
import sys

sys.getsizeof(result_dict)
# Out:
# 5368709208

# %% [markdown]
# ## 위키데이터(지식 그래프) id 얻는 함수 작성

# %%
with open('../data/processed_data/ent2id.json', 'r') as f:
    ent2id = json.load(f)

def get_entity_id(entity_name: str, ent2id=ent2id) -> str:
    """ 주어진 개체명의 위키데이터 id를 얻는 함수.
    """
    return ent2id[entity_name] if entity_name in ent2id else None

# %%
get_entity_id('제임스 얼 카터')
# Out:
# 'Q23685'

# %% [markdown]
# ## Entity가 가지는 관계 정보를 얻는 함수 작성

# %%
# with open('../data/processed_data/entid2rel.json', 'r') as f:
#     entid2rel = json.load(f)
    
def get_rel_info(entity_id: str, entid2rel=result_dict) -> dict:
    """ 주어진 개체 id가 가지는 관계 정보를 담은 딕셔너리를 반환하는 함수.
    """
    return entid2rel[entity_id] if entity_id in entid2rel else None

# %%
get_rel_info(get_entity_id('제임스 얼 카터'))
# Out:
# {'Q677191': 'P735',
#  'Q8933847': 'P735',
#  'Q4166211': 'P735',
#  'Q35637': 'P166',
#  'Q17144': 'P166',
#  'Q27028': 'P166',
#  'Q1479435': 'P166',
#  'Q1126046': 'P166',
#  'Q3241794': 'P166',
#  'Q20203866': 'P166',
#  'Q7182737': 'P166',
#  'Q4744661': 'P166',
#  'Q5254719': 'P166',
#  'Q20745818': 'P166',
#  'Q4770571': 'P166',
#  'Q211692': 'P166',
#  'Q6565314': 'P166',
#  'Q17132005': 'P166',
#  'Q4711197': 'P166',
#  'Q5365910': 'P166',
#  'Q2611552': 'P166',
#  'Q2338107': 'P166',
#  'Q2079534': 'P166',
#  'Q1783222': 'P166',
#  'Q3885425': 'P166',
#  'Q2803223': 'P166',
#  'Q1068636': 'P166',
#  'Q1783970': 'P166',
#  'Q47009634': 'P166',
#  'Q41254': 'P166',
#  'Q1542342': 'P166',
#  'Q20891849': 'P166',
#  'Q41977694': 'P166',
#  'Q73216561': 'P166',
#  'Q42591771': 'P166',
#  'Q30': 'P27',
#  'Q608527': 'P551',
#  'Q6548118': 'P19',
#  'Q11696': 'P39',
#  'Q880198': 'P39',
#  'Q1467287': 'P39',
#  'Q20065663': 'P39',
#  'Q219353': 'P26',
#  'Q6111597': 'P40',
#  'Q4216197': 'P40',
#  'Q75766267': 'P40',
#  'Q75766268': 'P40',
#  'Q11220': 'P241',
#  'Q10669499': 'P106',
#  'Q193391': 'P106',
#  'Q6625963': 'P106',
#  'Q82955': 'P106',
#  'Q131512': 'P106',
#  'Q18814623': 'P106',
#  'Q3492027': 'P106',
#  'Q372436': 'P106',
#  'Q3578589': 'P106',
#  'Q43845': 'P106',
#  'Q81096': 'P106',
#  'Q16323111': 'P106',
#  'Q1476215': 'P106',
#  'Q36180': 'P106',
#  'Q5547746': 'P69',
#  'Q864855': 'P69',
#  'Q559549': 'P69',
#  'Q1567748': 'P69',
#  'Q29552': 'P102',
#  'Q6133272': 'P22',
#  'Q6548136': 'P25',
#  'Q463303': 'P463',
#  'Q468865': 'P463',
#  'Q5': 'P31',
#  'Q8566918': 'P910',
#  'Q362': 'P607',
#  'Q16101731': 'P734',
#  'Q1860': 'P6886',
#  'Q1321': 'P1412',
#  'Q386481': 'P485',
#  'Q3039938': 'P552',
#  'Q19831453': 'P1853',
#  'Q2657718': 'P1343',
#  'Q67311526': 'P1343',
#  'Q6859101': 'P1343',
#  'Q4912331': 'P3373',
#  'Q5571337': 'P3373',
#  'Q7382914': 'P3373',
#  'Q186024': 'P410',
#  'Q93191': 'P140',
#  'Q621043': 'P108',
#  'Q6581097': 'P21',
#  'Q13382529': 'P5008',
#  'Q1328508': 'P101',
#  'Q1051668': 'P793',
#  'Q699693': 'P3602',
#  'Q7892708': 'P3602'}

# %% [markdown]
# ## 문장으로부터 관계 트리플을 얻는 함수 작성

# %%
from itertools import permutations
import random

def sent2triple(sent: str) -> list:
    """ 문장으로부터 가능한 관계 트리플의 리스트를 얻는 함수.
    
    ex) sent = '제임스 얼 카터 주니어는 민주당 출신 미국 39대 대통령 이다.'
        
        Return:
            [
                {"sentence": "제임스 얼 카터 주니어는 민주당 출신 미국 39대 대통령 이다.",
                "subj_name": "제임스 얼 카터",
                "subj_start_pos": 0,
                "subj_end_pos": 8,
                "subj_type": "PERSON",
                "obj_name": "대통령",
                "obj_start_pos": 28,
                "obj_end_pos": 31,
                "obj_type": "CIVILIZATION",
                "relation": "~",
                
                { ...
                }
            ]
    """
    # 너무 긴 문장의 경우 제외
    if len(sent) >= 500:
        return []
    
    ner_result = ner(sent)
    
    # 인식된 각 개체명의 range 계산
    ner_result = [(item[0], item[1], len(item[0])) for item in ner_result]
    
    modified_list = []
    tmp_cnt = 0
    
    for item in ner_result:
        modified_list.append((item[0], item[1], [tmp_cnt, tmp_cnt + item[2]]))
        tmp_cnt += item[2]       
    
    # NER
    ent_list = [item for item in modified_list if item[1] != 'O']
    
    # wikidata id가 존재하는 것만 선택
    ent_list = [(item[0], get_entity_id(item[0]), item[1], item[2]) for item in ent_list if get_entity_id(item[0])]

    result_list = []
    
    # 같은 문장에 대한 관계 트리플이 너무 많아지는 것을 방지하기 위해 랜덤 샘플링
    if len(ent_list) >= 6:
        sampled_pairs = random.sample(list(permutations(ent_list, 2)), 10)
    
    else:
        sampled_pairs = list(permutations(ent_list, 2))
        
    for ent_subj, ent_obj in sampled_pairs:
        tmp_dict = {}
        tmp_rel = ""
        
        if ent_obj[1] in get_rel_info(ent_subj[1]):
            tmp_rel = get_rel_info(ent_subj[1])[ent_obj[1]]
            
            if tmp_rel:
                subj_pos = ent_subj[3]
                obj_pos = ent_obj[3]
                tmp_dict["sentence"] = sent
                
                tmp_dict["subj_name"] = ent_subj[0]
                tmp_dict["subj_start_pos"], tmp_dict["subj_end_pos"] = subj_pos[0], subj_pos[1]
                tmp_dict["subj_type"] = ent_subj[2]
                
                tmp_dict["obj_name"] = ent_obj[0]
                tmp_dict["obj_start_pos"], tmp_dict["obj_end_pos"] = obj_pos[0], obj_pos[1]
                tmp_dict["obj_type"] = ent_obj[2]
                
                tmp_dict["relation"] = tmp_rel
        
                result_list.append(tmp_dict)
            
    if len(result_list) >= 3:
        sampled_result = random.sample(result_list, 2)
    else:
        sampled_result = result_list
        
    return sampled_result

# %%
sent2triple(get_sent(0))
# Out:
# [{'sentence': '제임스 얼 카터 주니어는 민주당 출신 미국 39대 대통령 이다.',
#   'subj_name': '제임스 얼 카터',
#   'subj_start_pos': 0,
#   'subj_end_pos': 8,
#   'subj_type': 'PERSON',
#   'obj_name': '미국',
#   'obj_start_pos': 21,
#   'obj_end_pos': 23,
#   'obj_type': 'COUNTRY',
#   'relation': 'P27'},
#  {'sentence': '제임스 얼 카터 주니어는 민주당 출신 미국 39대 대통령 이다.',
#   'subj_name': '미국',
#   'subj_start_pos': 21,
#   'subj_end_pos': 23,
#   'subj_type': 'COUNTRY',
#   'obj_name': '제임스 얼 카터',
#   'obj_start_pos': 0,
#   'obj_end_pos': 8,
#   'obj_type': 'PERSON',
#   'relation': 'P6'}]

# %%
sent2triple(get_sent(4))
# Out:
# [{'sentence': '대통령이 되기 전 조지아주 상원의원을 두번 연임했으며, 1971년부터 1975년까지 조지아 지사로 근무했다.',
#   'subj_name': '조지아',
#   'subj_start_pos': 47,
#   'subj_end_pos': 50,
#   'subj_type': 'COUNTRY',
#   'obj_name': '조지아주',
#   'obj_start_pos': 10,
#   'obj_end_pos': 14,
#   'obj_type': 'LOCATION',
#   'relation': 'P1889'}]

# %% [markdown]
# ## 전체 위키피디아 코퍼스의 문장에서 관계 트리플 추출하여 csv 파일로 저장

# %%
len(sentences['data'])
# Out:
# 3862545

# %%
import random
random.shuffle(sentences['data'])
sentences['data'][0]
# Out:
# {'sentence': '모토로라 레이저 M는 모토로라 모빌리티에서 제조/판매하는 안드로이드 스마트폰이다.'}

# %%
sentences['data'][1]
# Out:
# {'sentence': '잔디로 식생된 지표지역을 잔디밭이라고 하며, 잔디나 잔디의 뿌리로 차 있는 토양표층이나, 이식 또는 증식의 목적으로 떼어낸 토양표층의 일부를 떼라고 한다.'}

# %%
import csv
from tqdm import tqdm
from itertools import permutations

result_csv_file = open('../data/processed_data/relation_triples.csv', 'w')
writer = csv.writer(result_csv_file, delimiter='\t')
writer.writerow(['sentence', 'subj_name', 'subj_start_pos', 'subj_end_pos', 'subj_type',
                'obj_name', 'obj_start_pos', 'obj_end_pos', 'obj_type', 'relation'])

for idx, sentence_item in enumerate(tqdm(sentences['data'])):
    tmp_result_list = sent2triple(get_sent(idx))
    
    for item in tmp_result_list:
        writer.writerow([item['sentence'], item['subj_name'], item['subj_start_pos'], item['subj_end_pos'],
                        item['subj_type'], item['obj_name'], item['obj_start_pos'], item['obj_end_pos'],
                        item['obj_type'], item['relation']])
        
result_csv_file.close()
# Out:
# 100%|██████████| 3862545/3862545 [57:49:52<00:00, 18.55it/s]

# %%
result_csv_file.close()
