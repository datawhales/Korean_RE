# %% [markdown]
# ## relid2label.json 파일 만들기

# %%
# pip install sparqlwrapper
# https://rdflib.github.io/sparqlwrapper/

import sys
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"

query = """SELECT ?property ?propertyType ?propertyLabel ?propertyDescription ?propertyAltLabel WHERE {
  # ?property wikibase:propertyType ?propertyType .
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
ORDER BY ASC(xsd:integer(STRAFTER(STR(?property), 'P')))"""


def get_results(endpoint_url, query):
    user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
    # TODO adjust user agent; see https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()


results = get_results(endpoint_url, query)

results_en = results["results"]["bindings"]

results_en[0]
# Out:
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P6'},
#  'propertyType': {'type': 'uri',
#   'value': 'http://wikiba.se/ontology#WikibaseItem'},
#  'propertyLabel': {'xml:lang': 'en',
#   'type': 'literal',
#   'value': 'head of government'},
#  'propertyDescription': {'xml:lang': 'en',
#   'type': 'literal',
#   'value': 'head of the executive power of this town, city, municipality, state, country, or other governmental body'},
#  'propertyAltLabel': {'xml:lang': 'en',
#   'type': 'literal',
#   'value': 'president, chancellor, mayor, prime minister, governor, premier, first minister, executive power headed by, government headed by, head of national government'}}

# %%
# pip install sparqlwrapper
# https://rdflib.github.io/sparqlwrapper/

import sys
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"

query = """SELECT ?property ?propertyType ?propertyLabel ?propertyDescription ?propertyAltLabel WHERE {
  # ?property wikibase:propertyType ?propertyType .
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],ko". }
}
ORDER BY ASC(xsd:integer(STRAFTER(STR(?property), 'P')))"""


def get_results(endpoint_url, query):
    user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
    # TODO adjust user agent; see https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()


results = get_results(endpoint_url, query)

results_ko = results["results"]["bindings"]

results_ko[0]
# Out:
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P6'},
#  'propertyType': {'type': 'uri',
#   'value': 'http://wikiba.se/ontology#WikibaseItem'},
#  'propertyLabel': {'xml:lang': 'ko', 'type': 'literal', 'value': '행정부 수반'},
#  'propertyDescription': {'xml:lang': 'ko',
#   'type': 'literal',
#   'value': '항목 주제인 행정부 또는 지자체의 수장'},
#  'propertyAltLabel': {'xml:lang': 'ko',
#   'type': 'literal',
#   'value': '군수, 구청장, 시장, 지사, 특별자치시장, 정부 대표, 정부 수반, 정부 수장, 행정부 수장, 광역시장, 도지사, 이곳의 행정부 수반, 지방 정부 대표, 지방 정부의 대표, 지방 정부의 장, 지자체 대표, 지자체 수장, 특별시장, 특별자치도지사, 현지사'}}

# %% [markdown]
# ## relation 정보 추출

# %%
result_dict = {}

for i, rel_item in enumerate(results_ko):
    tmp_id = rel_item['property']['value'].split('http://www.wikidata.org/entity/')[1]
    
    tmp_dict = {}
    
#     tmp_dict["relation_type"] = rel_item['propertyType']['value'].split('http://wikiba.se/ontology#')[1]

    tmp_dict["relation_label"] = rel_item['propertyLabel']['value']

    try:
        tmp_dict["relation_description"] = rel_item['propertyDescription']['value']
    except:
        pass
    
    result_dict[tmp_id] = tmp_dict
    
for i, rel_item in enumerate(results_en):
    tmp_id = rel_item['property']['value'].split('http://www.wikidata.org/entity/')[1]
    
    result_dict[tmp_id]['en_relation_label'] = rel_item['propertyLabel']['value']
    
    try:
        result_dict[tmp_id]['en_relation_description'] = rel_item['propertyDescription']['value']
    except:
        pass

# %%
result_dict
# Out:
# {'P6': {'relation_label': '행정부 수반',
#   'relation_description': '항목 주제인 행정부 또는 지자체의 수장',
#   'en_relation_label': 'head of government',
#   'en_relation_description': 'head of the executive power of this town, city, municipality, state, country, or other governmental body'},
#  'P10': {'relation_label': '동영상 파일',
#   'relation_description': '항목 주제와 관련된 동영상 (위키미디어 공용에 올라온 것에 한하며 유튜브 동영상인 경우 P1651를 이용하세요)',
#   'en_relation_label': 'video',
#   'en_relation_description': 'relevant video. For images, use the property P18. For film trailers, qualify with "object has role" (P3831)="trailer" (Q622550)'},
#  'P14': {'relation_label': '노선 상징 모양',
#   'relation_description': '항목 주제인 도로 노선을 상징하는 모양',
#   'en_relation_label': 'traffic sign',
#   'en_relation_description': 'graphic symbol describing the item, used at the side of or above roads to give instructions or provide information to road users'},
#  'P15': {'relation_label': '노선도',
#   'relation_description': '항목 주제인 노선의 지도',
#   'en_relation_label': 'route map',
#   'en_relation_description': 'image of route map at Wikimedia Commons'},
#  'P16': {'relation_label': '도로 노선의 등급',
#   'relation_description': '항목 주제인 도로 노선이 속한 체계(등급)',
#   'en_relation_label': 'highway system',
#   'en_relation_description': 'system (or specific country specific road type) of which the highway is a part'},
#  'P17': {'relation_label': '다음 나라의 것임',
#   'relation_description': '항목 주제는 다음 나라(국가)의 것을 다루고 있음',
#   'en_relation_label': 'country',
#   'en_relation_description': 'sovereign state of this item (not to be used for human beings)'},
#  'P18': {'relation_label': '모습',
#   'relation_description': '항목 주제와 관련된 것의 그림이나 사진 (위키미디어 공용에 등재된 것만 사용할 수 있습니다)',
#   'en_relation_label': 'image',
#   'en_relation_description': 'image of relevant illustration of the subject; if available, use more specific properties (sample: coat of arms image, locator map, flag image, signature image, logo image, collage image)'},
#  'P19': {'relation_label': '태어난 곳',
#   'relation_description': '항목 주제가 태어난 장소',
#   'en_relation_label': 'place of birth',
#   'en_relation_description': 'most specific known (e.g. city instead of country, or hospital instead of city) birth location of a person, animal or fictional character'},
#  'P20': {'relation_label': '사망한 곳',
#   'relation_description': '항목 주제가 죽은 장소',
#   'en_relation_label': 'place of death',
#   'en_relation_description': 'most specific known (e.g. city instead of country, or hospital instead of city) death location of a person, animal or fictional character'},
#  'P21': {'relation_label': '성별',
#   'relation_description': '항목 주제의 성별',
#   'en_relation_label': 'sex or gender',
#   'en_relation_description': 'sex or gender identity of human or animal. For human: male, female, non-binary, intersex, transgender female, transgender male, agender. For animal: male organism, female organism. Groups of same gender use subclass of (P279)'},
#  'P22': {'relation_label': '친아버지',
#   'relation_description': '항목 주제인 인물의 친부모 중 남성쪽 인물',
#   'en_relation_label': 'father',
#   'en_relation_description': 'male parent of the subject. For stepfather, use "stepparent" (P3448)'},
#  'P25': {'relation_label': '친어머니',
#   'relation_description': '항목 주제인 인물의 친부모 중 여성쪽 인물',
#   'en_relation_label': 'mother',
#   'en_relation_description': 'female parent of the subject. For stepmother, use "stepparent" (P3448)'},
#  'P26': {'relation_label': '배우자',
#   'relation_description': '항목 주제인 인물의 배우자 (결혼하지 않은 채 같이 지내는 "동거인"에 대해선 P451을 사용하세요)',
#   'en_relation_label': 'spouse',
#   'en_relation_description': 'the subject has the object as their spouse (husband, wife, partner, etc.). Use "unmarried partner" (P451) for non-married companions'},
#  'P27': {'relation_label': '국적',
#   'relation_description': '대상 인물의 국적',
#   'en_relation_label': 'country of citizenship',
#   'en_relation_description': 'the object is a country that recognizes the subject as its citizen'},
#  'P30': {'relation_label': '대륙',
#   'relation_description': '주제가 속한 대륙. 남극에 위치한 것, 국가, 러시아 도시들같은 둘 이상의 대륙에 걸친 항목에 사용함.',
#   'en_relation_label': 'continent',
#   'en_relation_description': 'continent of which the subject is a part'},
#  'P31': {'relation_label': '다음 종류에 속함',
#   'relation_description': '항목 주제는 다음 종류에 속함 (해당 종류에 속하는 것 중 하나를 고르라고 했을 때 이 항목도 고를 수 있어야 함)',
#   'en_relation_label': 'instance of',
#   'en_relation_description': 'that class of which this subject is a particular example and member'},
#  'P35': {'relation_label': '국가 원수',
#   'relation_description': '항목 주제인 나라에서 최고로 높은 직위에 있는 사람',
#   'en_relation_label': 'head of state',
#   'en_relation_description': 'official with the highest formal authority in a country/state'},
#  'P36': {'relation_label': '정부 소재지',
#   'relation_description': '항목 주제인 국가·지역의 행정부가 있는 곳',
#   'en_relation_label': 'capital',
#   'en_relation_description': 'seat of government of a country, province, state or other type of administrative territorial entity'},
#  'P37': {'relation_label': '공용어',
#   'relation_description': '해당 지역의 공용어로 지정된 언어',
#   'en_relation_label': 'official language',
#   'en_relation_description': 'language designated as official by this item'},
#  'P38': {'relation_label': '통화',
#   'relation_description': '항목 주제인 국가에서 사용하는 통화',
#   'en_relation_label': 'currency',
#   'en_relation_description': 'currency used by item'},
#  'P39': {'relation_label': '직위',
#   'relation_description': '주제의 인물이 현재나 과거에 맡았던 직위 또는 공직',
#   'en_relation_label': 'position held',
#   'en_relation_description': 'subject currently or formerly holds the object position or public office'},
#  'P40': {'relation_label': '자녀',
#   'relation_description': '항목 주제인 인물의 자녀들',
#   'en_relation_label': 'child',
#   'en_relation_description': 'subject has object as child. Do not use for stepchildren'},
#  'P41': {'relation_label': '상징기 모습',
#   'relation_description': '항목을 상징하는 깃발의 모습',
#   'en_relation_label': 'flag image',
#   'en_relation_description': "image of the item's flag"},
#  'P47': {'relation_label': '다음과 경계를 맞닿음',
#   'relation_description': '국경이나 경계를 접하는 국가나 (같은 단계의) 행정 구역',
#   'en_relation_label': 'shares border with',
#   'en_relation_description': 'countries or administrative subdivisions, of equal level, that this item borders, either by land or water. A single common point is enough.'},
#  'P50': {'relation_label': '저자',
#   'relation_description': '항목 주제인 글을 쓴 사람',
#   'en_relation_label': 'author',
#   'en_relation_description': 'main creator(s) of a written work (use on works, not humans); use P2093 when Wikidata item is unknown or does not exist'},
#  'P51': {'relation_label': '소리 파일',
#   'relation_description': '항목 주제와 관련된 오디오 또는 소리',
#   'en_relation_label': 'audio',
#   'en_relation_description': 'relevant sound. If available, use a more specific property. Samples: "spoken text audio" (P989), "pronunciation audio" (P443)'},
#  'P53': {'relation_label': '가문',
#   'relation_description': '항목 주제인 인물이 속해 있는 가문',
#   'en_relation_label': 'family',
#   'en_relation_description': 'family, including dynasty and nobility houses. Not family name (use P734 for family name).'},
#  'P54': {'relation_label': '소속 팀',
#   'relation_description': '현재나 과거에 활동했던 스포츠 팀',
#   'en_relation_label': 'member of sports team',
#   'en_relation_description': 'sports teams or clubs that the subject represents or represented'},
#  'P57': {'relation_label': '감독',
#   'relation_description': '항목 주제인 동영상, 영화, 비디오 게임 또는 그와 유사한 작품의 제작을 감독한 사람',
#   'en_relation_label': 'director',
#   'en_relation_description': 'director(s) of film, TV-series, stageplay, video game or similar'},
#  'P58': {'relation_label': '각본가',
#   'relation_description': '항목 주제인 극 작품의 시나리오나 각본을 쓴 사람',
#   'en_relation_label': 'screenwriter',
#   'en_relation_description': 'person(s) who wrote the script for subject item'},
#  'P59': {'relation_label': '별자리',
#   'en_relation_label': 'constellation',
#   'en_relation_description': 'the area of the celestial sphere of which the subject is a part (from a scientific standpoint, not an astrological one)'},
#  'P61': {'relation_label': '다음이 발견·발명하였음',
#   'relation_description': '항목 주제를 처음으로 발견·발명한 대상',
#   'en_relation_label': 'discoverer or inventor',
#   'en_relation_description': 'subject who discovered, first described, invented, or developed this discovery or invention'},
#  'P65': {'relation_label': '천체를 발견한 곳',
#   'relation_description': '항목 주제인 천체를 발견한 천문대 또는 위성 등의 장소',
#   'en_relation_label': 'site of astronomical discovery',
#   'en_relation_description': 'the place where an astronomical object was discovered (observatory, satellite)'},
#  'P66': {'relation_label': '고향',
#   'relation_description': '항목 주제인 인물 또는 성씨의 조상들이 대대로 살았던 곳',
#   'en_relation_label': 'ancestral home',
#   'en_relation_description': 'place of origin for ancestors of subject'},
#  'P69': {'relation_label': '다녔던 학교',
#   'relation_description': '항목 주제인 인물이 교육받은 곳',
#   'en_relation_label': 'educated at',
#   'en_relation_description': 'educational institution attended by subject'},
#  'P78': {'relation_label': '최상위 도메인',
#   'relation_description': '항목 주제인 국가에게 할당된 최상위 도메인',
#   'en_relation_label': 'top-level Internet domain',
#   'en_relation_description': 'Internet domain name system top-level code'},
#  'P81': {'relation_label': '이 정거장을 거쳐가는 노선',
#   'relation_description': '항목 주제인 역·정류장을 거쳐 가는 철도·대중교통 노선',
#   'en_relation_label': 'connecting line',
#   'en_relation_description': 'railway line(s) subject is directly connected to'},
#  'P84': {'relation_label': '건축가',
#   'relation_description': '항목 주제인 건물을 계획 또는 디자인하거나 건설을 감독한 사람',
#   'en_relation_label': 'architect',
#   'en_relation_description': 'person or architectural firm responsible for designing this building'},
#  'P85': {'relation_label': '국가',
#   'relation_description': '항목 주제인 나라의 국가를 다룬 항목의 명칭',
#   'en_relation_label': 'anthem',
#   'en_relation_description': "subject's official anthem"},
#  'P86': {'relation_label': '작곡가',
#   'relation_description': '항목 주제인 곡을 쓴 사람, 또는 작품에 들어가는 곡을 쓴 사람 (작사가에 대해선 P676을 사용하세요)',
#   'en_relation_label': 'composer',
#   'en_relation_description': 'person(s) who wrote the music [for lyricist, use "lyrics by" (P676)]'},
#  'P87': {'relation_label': '오페라 대본 작가',
#   'en_relation_label': 'librettist',
#   'en_relation_description': 'author of the libretto (words) of an opera, operetta, oratorio or cantata, or of the book of a musical'},
#  'P88': {'relation_label': '의뢰인',
#   'relation_description': '항목 주제인 작업물을 의뢰한 인물·단체',
#   'en_relation_label': 'commissioned by',
#   'en_relation_description': 'person or organization that commissioned this work'},
#  'P91': {'relation_label': '성적 지향',
#   'en_relation_label': 'sexual orientation',
#   'en_relation_description': 'the sexual orientation of the person — use IF AND ONLY IF they have stated it themselves, unambiguously, or it has been widely agreed upon by historians after their death'},
#  'P92': {'relation_label': '다음 법령에서 규정하고 있음',
#   'relation_description': '항목 주제의 범위를 규정하는 법적 근거',
#   'en_relation_label': 'main regulatory text',
#   'en_relation_description': 'text setting the main rules by which the subject is regulated'},
#  'P94': {'relation_label': '문장 모습',
#   'relation_description': '항목 주제를 상징하는 문장의 모습',
#   'en_relation_label': 'coat of arms image',
#   'en_relation_description': "image of the item's coat of arms - for the shield part only use P4004"},
#  'P97': {'relation_label': '작위',
#   'en_relation_label': 'noble title',
#   'en_relation_description': 'titles held by the person'},
#  'P98': {'relation_label': '편집자',
#   'relation_description': '책이나 잡지를 편집한 사람',
#   'en_relation_label': 'editor',
#   'en_relation_description': 'editor of a compiled work such as a book or a periodical (newspaper or an academic journal)'},
#  'P101': {'relation_label': '전문 분야',
#   'relation_description': '물리학, 역사 같은 주요 활동 분야, 사람을 포함한 어떤 항목에도 사용될 수 있음 (물리학자, 역사가 같은 인물의 직업은 P106 참고)',
#   'en_relation_label': 'field of work',
#   'en_relation_description': 'specialization of a person or organization; see P106 for the occupation'},
#  'P102': {'relation_label': '소속 정당',
#   'relation_description': '정치인 또는 당원이 소속되어 있는 당',
#   'en_relation_label': 'member of political party',
#   'en_relation_description': 'the political party of which this politician is or has been a member or otherwise affiliated'},
#  'P103': {'relation_label': '모어',
#   'relation_description': '인물이 모어로써 배웠던 언어',
#   'en_relation_label': 'native language',
#   'en_relation_description': 'language or languages a person has learned from early childhood'},
#  'P105': {'relation_label': '분류 계급',
#   'en_relation_label': 'taxon rank',
#   'en_relation_description': 'level in a taxonomic hierarchy'},
#  'P106': {'relation_label': '직업',
#   'relation_description': '항목 주제인 인물의 직업',
#   'en_relation_label': 'occupation',
#   'en_relation_description': 'occupation of a person; see also "field of work" (Property:P101), "position held" (Property:P39)'},
#  'P108': {'relation_label': '고용한 곳',
#   'relation_description': '주제의 인물이 일하거나 일했던 기관/단체',
#   'en_relation_label': 'employer',
#   'en_relation_description': 'person or organization for which the subject works or worked'},
#  'P109': {'relation_label': '서명',
#   'relation_description': '사람의 서명 그림',
#   'en_relation_label': 'signature',
#   'en_relation_description': "image of a person's signature"},
#  'P110': {'relation_label': '삽화가',
#   'relation_description': '항목 주제인 책의 삽화를 그린 인물',
#   'en_relation_label': 'illustrator',
#   'en_relation_description': 'person drawing the pictures or taking the photographs in a book'},
#  'P111': {'relation_label': '다음 물리량의 단위임',
#   'relation_description': '항목 주제인 단위는 이 물리량을 세거나 측정할 때 쓰는 단위임',
#   'en_relation_label': 'measured physical quantity',
#   'en_relation_description': 'value of a physical property expressed as number multiplied by a unit'},
#  'P112': {'relation_label': '설립자',
#   'relation_description': '단체의 설립자',
#   'en_relation_label': 'founded by',
#   'en_relation_description': 'founder or co-founder of this organization, religion or place'},
#  'P113': {'relation_label': '허브 공항',
#   'en_relation_label': 'airline hub',
#   'en_relation_description': 'airport that serves as a hub for an airline'},
#  'P114': {'relation_label': '항공 동맹',
#   'en_relation_label': 'airline alliance',
#   'en_relation_description': 'alliance the airline belongs to'},
#  'P115': {'relation_label': '홈경기장',
#   'en_relation_label': 'home venue',
#   'en_relation_description': 'home stadium or venue of a sports team or applicable performing arts organization'},
#  'P117': {'relation_label': '화학 구조',
#   'relation_description': '화합물 구조를 나타낸 그림',
#   'en_relation_label': 'chemical structure',
#   'en_relation_description': 'image of a representation of the structure for a chemical compound'},
#  'P118': {'relation_label': '리그',
#   'relation_description': '팀이 출전한 리그',
#   'en_relation_label': 'league',
#   'en_relation_description': 'league in which team or player plays or has played in'},
#  'P119': {'relation_label': '묻힌 곳',
#   'relation_description': '항목 주제인 고인(사망한 사람)이 묻혀있는 장소',
#   'en_relation_label': 'place of burial',
#   'en_relation_description': 'location of grave, resting place, place of ash-scattering, etc. (e.g., town/city or cemetery) for a person or animal. There may be several places: e.g., re-burials, parts of body buried separately.'},
#  'P121': {'relation_label': '다음을 운용함',
#   'relation_description': '주제가 이용/운용하는 대상',
#   'en_relation_label': 'item operated',
#   'en_relation_description': 'equipment, installation or service operated by the subject'},
#  'P122': {'relation_label': '정부 형태',
#   'relation_description': '항목 주제인 나라의 정부 형태',
#   'en_relation_label': 'basic form of government',
#   'en_relation_description': "subject's government"},
#  'P123': {'relation_label': '발행 주체',
#   'relation_description': '도서, 정기간행물, 소프트웨어 등을 출판/발행/배급하는 개인 또는 단체',
#   'en_relation_label': 'publisher',
#   'en_relation_description': 'organization or person responsible for publishing books, periodicals, printed music, podcasts, games or software'},
#  'P126': {'relation_label': '관리 기관',
#   'relation_description': '해당 주제를 관리하는 단체 또는 사람',
#   'en_relation_label': 'maintained by',
#   'en_relation_description': 'person or organization in charge of keeping the subject (for instance an infrastructure) in functioning order'},
#  'P127': {'relation_label': '소유자',
#   'relation_description': '항목 주제를 소유하고 있는 사람/단체',
#   'en_relation_label': 'owned by',
#   'en_relation_description': 'owner of the subject'},
#  'P128': {'relation_label': 'P128',
#   'en_relation_label': 'regulates (molecular biology)',
#   'en_relation_description': 'process regulated by a protein or RNA in molecular biology'},
#  'P129': {'relation_label': 'P129',
#   'en_relation_label': 'physically interacts with',
#   'en_relation_description': 'physical entity that the subject interacts with'},
#  'P131': {'relation_label': '다음 행정구역에 위치함',
#   'relation_description': "항목 주제가 위치한 행정 구역 (행정 구역이 아닌 값을 쓰고 싶거나, 사건이 일어난 장소를 쓰고 싶다면 '위치'(P276) 속성을 대신 쓰세요)",
#   'en_relation_label': 'located in the administrative territorial entity',
#   'en_relation_description': 'the item is located on the territory of the following administrative entity. Use P276 for specifying locations that are non-administrative places and for items about events. Use P1382 if the item falls only partially into the administrative entity.'},
#  'P135': {'relation_label': '예술 사상',
#   'en_relation_label': 'movement',
#   'en_relation_description': 'literary, artistic, scientific or philosophical movement or scene associated with this person or work'},
#  'P136': {'relation_label': '장르',
#   'relation_description': '항목 주제인 작품의 장르(갈래) 또는 항목 주제인 팀이 추구하는 장르',
#   'en_relation_label': 'genre',
#   'en_relation_description': "creative work's genre or an artist's field of work (P101). Use main subject (P921) to relate creative works to their topic"},
#  'P137': {'relation_label': '운영 주체',
#   'relation_description': '항목 주제인 시설, 장비, 서비스 등을 운영하는 사람/단체',
#   'en_relation_label': 'operator',
#   'en_relation_description': 'person, profession, or organization that operates the equipment, facility, or service'},
#  'P138': {'relation_label': '명칭의 유래',
#   'relation_description': '항목 주제의 명칭은 다음 항목/사건에서 유래되었음',
#   'en_relation_label': 'named after',
#   'en_relation_description': 'entity or event that inspired the subject\'s name, or namesake (in at least one language). Qualifier "applies to name" (P5168) can be used to indicate which one'},
#  'P140': {'relation_label': '종교',
#   'relation_description': '주제 항목인 사람, 단체 또는 종교적 건물과 연관된 종교',
#   'en_relation_label': 'religion',
#   'en_relation_description': 'religion of a person, organization or religious building, or associated with this subject'},
#  'P141': {'relation_label': 'IUCN 보호 상태',
#   'relation_description': '국제자연보호연맹이 할당한 보호 상태',
#   'en_relation_label': 'IUCN conservation status',
#   'en_relation_description': 'conservation status assigned by the International Union for Conservation of Nature'},
#  'P143': {'relation_label': '다음 위키미디어 위키에서 들여온 서술임',
#   'relation_description': '서술을 들여올 때 사용된 출처; 위키미디어 위키에서 봇을 이용해 들여올 때 또는 수동으로 값을 입력할 때 쓸 수 있습니다',
#   'en_relation_label': 'imported from Wikimedia project',
#   'en_relation_description': "source of this claim's value; used in references section by bots or humans importing data from Wikimedia projects"},
#  'P144': {'relation_label': '다음에 기반을 두었음',
#   'relation_description': '항목 주제가 기반한 것',
#   'en_relation_label': 'based on',
#   'en_relation_description': 'the work(s) used as the basis for subject item'},
#  'P149': {'relation_label': '건축 양식',
#   'relation_description': '건축물의 건축 양식',
#   'en_relation_label': 'architectural style',
#   'en_relation_description': 'architectural style of a structure'},
#  'P150': {'relation_label': '하위 행정구역',
#   'relation_description': '항목 주제인 행정 구역이 관할하는 하위 행정 구역',
#   'en_relation_label': 'contains administrative territorial entity',
#   'en_relation_description': '(list of) direct subdivisions of an administrative territorial entity'},
#  'P154': {'relation_label': '로고 모습',
#   'relation_description': '항목 주제의 회사, 단체, 제품에 쓰인 그림 표식이나 그림 문장',
#   'en_relation_label': 'logo image',
#   'en_relation_description': 'graphic mark or emblem commonly used by commercial enterprises, organizations and products'},
#  'P155': {'relation_label': '이전',
#   'relation_description': '여럿 가운데 시간적 또는 공간적으로 앞에 오는 것',
#   'en_relation_label': 'follows',
#   'en_relation_description': 'immediately prior item in a series of which the subject is a part [if the subject has replaced the preceding item, e.g. political offices, use "replaces" (P1365)]'},
#  'P156': {'relation_label': '다음',
#   'relation_description': '여럿 가운데 시간적 또는 공간적으로 뒤에 오는 것',
#   'en_relation_label': 'followed by',
#   'en_relation_description': 'immediately following item in a series of which the subject is a part [if the subject has been replaced, e.g. political offices, use "replaced by" (P1366)]'},
#  'P157': {'relation_label': '다음에게 목숨을 잃었음',
#   'relation_description': '대상을 죽이거나 암살한 사람 또는 생물',
#   'en_relation_label': 'killed by',
#   'en_relation_description': 'person who killed the subject'},
#  'P158': {'relation_label': '인장 모습',
#   'relation_description': '항목 주제를 상징하는 인장 모습',
#   'en_relation_label': 'seal image',
#   'en_relation_description': "image of subject's seal (emblem)"},
#  'P159': {'relation_label': '본부 위치',
#   'relation_description': '항목 주제인 기관·단체의 본부·본사가 있거나 있었던 곳',
#   'en_relation_label': 'headquarters location',
#   'en_relation_description': "city, where an organization's headquarters is or has been situated. Use P276 qualifier for specific building"},
#  'P161': {'relation_label': '출연한 배우',
#   'relation_description': '이 속성을 사용할 때는 "맡은 배역"(P453)을 한정자로 같이 넣어주세요. 또한 음성으로만 출연한 경우 이 속성 대신 "출연한 성우"(P725)를 사용해주세요.',
#   'en_relation_label': 'cast member',
#   'en_relation_description': 'actor in the subject production [use "character role" (P453) and/or "name of the character role" (P4633) as qualifiers] [use "voice actor" (P725) for voice-only role]'},
#  'P162': {'relation_label': '제작자',
#   'relation_description': '영화나 음악 작품의 제작자(들)',
#   'en_relation_label': 'producer',
#   'en_relation_description': 'person(s) who produced the film, musical work, theatrical production, etc. (for film, this does not include executive producers, associate producers, etc.) [for production company, use P272, video games - use P178]'},
#  'P163': {'relation_label': '상징기를 다룬 항목',
#   'relation_description': '항목 주제를 상징하는 상징기를 다룬 항목',
#   'en_relation_label': 'flag',
#   'en_relation_description': "subject's flag"},
#  'P166': {'relation_label': '다음 상을 수상하였음',
#   'relation_description': '항목 주제인 인물이나 단체, 작품이 받은 상',
#   'en_relation_label': 'award received',
#   'en_relation_description': 'award or recognition received by a person, organisation or creative work'},
#  'P167': {'relation_label': '대체한 구조물',
#   'relation_description': '동일한 지리적 위치에서 이 건물이나 구조물을 대체한 구조물',
#   'en_relation_label': 'structure replaced by',
#   'en_relation_description': 'the item which replaced this building or structure, at the same geographic location'},
#  'P169': {'relation_label': '최고 경영자',
#   'en_relation_label': 'chief executive officer',
#   'en_relation_description': 'highest-ranking corporate officer appointed as the CEO within an organization'},
#  'P170': {'relation_label': '창작자',
#   'relation_description': '항목 주제인 창작물 등을 만든 사람',
#   'en_relation_label': 'creator',
#   'en_relation_description': 'maker of this creative work or other object (where no more specific property exists)'},
#  'P171': {'relation_label': '다음의 하위 분류군임',
#   'relation_description': '항목 주제인 분류군의 바로 위의 분류군',
#   'en_relation_label': 'parent taxon',
#   'en_relation_description': 'closest parent taxon of the taxon in question'},
#  'P172': {'relation_label': '민족',
#   'en_relation_label': 'ethnic group',
#   'en_relation_description': "subject's ethnicity (consensus is that a VERY high standard of proof is needed for this field to be used. In general this means 1) the subject claims it themself, or 2) it is widely agreed on by scholars, or 3) is fictional and portrayed as such)"},
#  'P175': {'relation_label': '연주자·가수',
#   'relation_description': '이 역할이나 음악 작품과 관련된 배우, 음악가, 밴드 또는 기타 공연자',
#   'en_relation_label': 'performer',
#   'en_relation_description': 'actor, musician, band or other performer associated with this role or musical work'},
#  'P176': {'relation_label': '제조사',
#   'relation_description': '이 물건을 제조/제작한 주요 회사',
#   'en_relation_label': 'manufacturer',
#   'en_relation_description': 'manufacturer or producer of this product'},
#  'P177': {'relation_label': '다음을 가로지름',
#   'relation_description': '항목 주제인 다리가 가로지르는 수역이나 장애물',
#   'en_relation_label': 'crosses',
#   'en_relation_description': 'obstacle (body of water, road, railway...) which this bridge crosses over or this tunnel goes under'},
#  'P178': {'relation_label': '개발 주체',
#   'relation_description': '아이템을 주체적으로 개발한 단체 또는 인물',
#   'en_relation_label': 'developer',
#   'en_relation_description': 'organisation or person that developed the item'},
#  'P179': {'relation_label': '시리즈',
#   'relation_description': '항목 주제인 작품이 포함되어 있는 시리즈',
#   'en_relation_label': 'part of the series',
#   'en_relation_description': 'series which contains the subject'},
#  'P180': {'relation_label': '다음을 묘사함',
#   'relation_description': '항목 주제인 작품에서 묘사한 사람, 장소, 물체, 사건',
#   'en_relation_label': 'depicts',
#   'en_relation_description': 'depicted entity (see also P921: main subject)'},
#  'P181': {'relation_label': '서식지 분포도',
#   'relation_description': '항목 주제인 분류군의 서식지 분포도',
#   'en_relation_label': 'taxon range map image',
#   'en_relation_description': 'range map of a taxon'},
#  'P183': {'relation_label': '다음 지역의 고유종임',
#   'relation_description': '항목 주제의 분류군이 유일하게 서식하는 장소나 서식 환경',
#   'en_relation_label': 'endemic to',
#   'en_relation_description': 'sole location or habitat type where the taxon lives'},
#  'P184': {'relation_label': '박사과정 당시 지도교수',
#   'relation_description': '항목 주제인 인물이 박사과정을 거치는 동안 논문 등을 지도해 준 교수',
#   'en_relation_label': 'doctoral advisor',
#   'en_relation_description': 'person who supervised the doctorate or PhD thesis of the subject'},
#  'P185': {'relation_label': '다음 박사과정 학생들을 지도함',
#   'relation_description': '항목 주제인 교수가 지도했거나 지도하는 박사과정학생',
#   'en_relation_label': 'doctoral student',
#   'en_relation_description': 'doctoral student(s) of a professor'},
#  'P186': {'relation_label': '사용된 재료',
#   'relation_description': '주제를 만든 재료',
#   'en_relation_label': 'made from material',
#   'en_relation_description': 'material the subject or the object is made of or derived from'},
#  'P189': {'relation_label': '발견된 곳',
#   'relation_description': '항목 주제가 발견된 장소',
#   'en_relation_label': 'location of discovery',
#   'en_relation_description': 'where the item was located when discovered'},
#  'P190': {'relation_label': '자매 결연 도시',
#   'relation_description': '항목 주제인 도시와 자매결연 또는 우호교류 협약을 맺은 도시',
#   'en_relation_label': 'twinned administrative body',
#   'en_relation_description': 'twin towns, sister cities, twinned municipalities and other localities that have a partnership or cooperative agreement, either legally or informally acknowledged by their governments'},
#  'P193': {'relation_label': '건설업자',
#   'en_relation_label': 'main building contractor',
#   'en_relation_description': 'the main organization responsible for construction of this structure or building'},
#  'P194': {'relation_label': '입법부',
#   'en_relation_label': 'legislative body',
#   'en_relation_description': 'legislative body governing this entity; political institution with elected representatives, such as a parliament/legislature or council'},
#  'P195': {'relation_label': '소장처',
#   'relation_description': '박물관, 미술관과 같이 주제 항목이 있는 곳',
#   'en_relation_label': 'collection',
#   'en_relation_description': 'art, museum, archival, or bibliographic collection the subject is part of'},
#  'P196': {'relation_label': '소행성군',
#   'en_relation_label': 'minor planet group',
#   'en_relation_description': 'is in grouping of minor planets according to similar orbital characteristics'},
#  'P197': {'relation_label': '인접 역',
#   'relation_description': '같은 선로를 공유하는 다음, 이전 역',
#   'en_relation_label': 'adjacent station',
#   'en_relation_description': 'the stations next to this station, sharing the same line(s)'},
#  'P199': {'relation_label': '사업 부문',
#   'en_relation_label': 'business division',
#   'en_relation_description': 'organizational divisions of this organization (which are not independent legal entities)'},
#  'P200': {'relation_label': '이 호수로 흐르는 하천들',
#   'relation_description': '항목 주제인 호수로 흐르는 주요 하천들',
#   'en_relation_label': 'inflows',
#   'en_relation_description': 'major inflow sources — rivers, aquifers, glacial runoff, etc. Some terms may not be place names, e.g. none'},
#  'P201': {'relation_label': '이 호수에서 흘러나오는 하천',
#   'relation_description': '항목 주제인 호수로부터 흐르는 하천(들)',
#   'en_relation_label': 'lake outflow',
#   'en_relation_description': 'rivers and other outflows waterway names. If evaporation or seepage are notable outflows, they may be included. Some terms may not be place names, e.g. evaporation'},
#  'P205': {'relation_label': '이 유역을 끼고 있는 국가',
#   'relation_description': '항목 주제의 하천/호수/바다의 유역(수역)을 끼고 있는 나라들',
#   'en_relation_label': 'basin country',
#   'en_relation_description': 'country that have drainage to/from or border the body of water'},
#  'P206': {'relation_label': '다음 유역을 끼고 있음',
#   'relation_description': '항목 주제인 지역이 끼고 있는 유역(들)',
#   'en_relation_label': 'located in or next to body of water',
#   'en_relation_description': 'sea, lake, river or stream'},
#  'P207': {'relation_label': '수심 지도',
#   'en_relation_label': 'bathymetry image',
#   'en_relation_description': 'image showing bathymetric chart, bathymetric map'},
#  'P208': {'relation_label': '행정부',
#   'relation_description': '항목 주제인 국가 또는 행정 구역의 행정을 담당하는 부처',
#   'en_relation_label': 'executive body',
#   'en_relation_description': 'branch of government for the daily administration of the state'},
#  'P209': {'relation_label': '최고 사법 기관',
#   'en_relation_label': 'highest judicial authority',
#   'en_relation_description': 'supreme judicial body within a country, administrative division, or other organization'},
#  'P210': {'relation_label': '당 서기',
#   'en_relation_label': 'party chief representative',
#   'en_relation_description': 'chief representative of a party in an institution or an administrative unit (use qualifier to identify the party)'},
#  'P212': {'relation_label': 'ISBN-13',
#   'relation_description': '항목 주제에게 부여된 국제표준도서번호(ISBN) 중 13자리 형태',
#   'en_relation_label': 'ISBN-13',
#   'en_relation_description': 'identifier for a book (edition), thirteen digit'},
#  'P213': {'relation_label': 'ISNI',
#   'relation_description': '항목 주제에게 부여된 국제 표준 이름 식별자(ISNI)',
#   'en_relation_label': 'ISNI',
#   'en_relation_description': 'International Standard Name Identifier for an identity. Format: 4 blocks of 4 digits separated by a space, first block is 0000'},
#  'P214': {'relation_label': 'VIAF 식별자',
#   'relation_description': '항목 주제에게 부여된 가상국제전거파일(VIAF) 식별자',
#   'en_relation_label': 'VIAF ID',
#   'en_relation_description': 'identifier for the Virtual International Authority File database [format: up to 22 digits]'},
#  'P215': {'relation_label': '항성 분류',
#   'en_relation_label': 'spectral class',
#   'en_relation_description': 'spectral class of an astronomical object'},
#  'P217': {'relation_label': '등재 번호',
#   'relation_description': '항목 주제가 어떤 목록에 등재되면서 받은 번호(순번)',
#   'en_relation_label': 'inventory number',
#   'en_relation_description': 'identifier for a physical object or a set of physical objects in a collection'},
#  'P218': {'relation_label': 'ISO 639-1 코드',
#   'relation_description': '언어나 어족을 구분하기 위해 ISO 639-1에 정의되어 있는 두 글자로 된 식별자',
#   'en_relation_label': 'ISO 639-1 code',
#   'en_relation_description': '2-letter identifier for language or family of languages defined in ISO 639-1 standard'},
#  'P219': {'relation_label': 'ISO 639-2 코드',
#   'relation_description': '언어나 어족을 구분하기 위해 ISO 639-2에 정의되어 있는 세 글자로 된 식별자',
#   'en_relation_label': 'ISO 639-2 code',
#   'en_relation_description': '3-letter identifier for language,  macro-language or language family, defined in ISO 639-2 standard'},
#  'P220': {'relation_label': 'ISO 639-3 코드',
#   'relation_description': '항목 주제인 언어에 대해 ISO 639-3에서 부여한 식별자',
#   'en_relation_label': 'ISO 639-3 code',
#   'en_relation_description': '3-letter identifier for language defined in ISO 639-3, extension of ISO 639-2'},
#  'P221': {'relation_label': 'ISO 639-6 코드',
#   'en_relation_label': 'ISO 639-6 code',
#   'en_relation_description': '4-letter identifier for language variants per ISO 639-6, standard between 2009-2014'},
#  'P223': {'relation_label': '은하 형태',
#   'en_relation_label': 'galaxy morphological type',
#   'en_relation_description': 'galaxy morphological classification code'},
#  'P225': {'relation_label': '학명',
#   'relation_description': '생물의 분류군 이름',
#   'en_relation_label': 'taxon name',
#   'en_relation_description': 'correct scientific name of a taxon (according to the reference given)'},
#  'P227': {'relation_label': 'GND 식별자',
#   'relation_description': '항목 주제에 대해 독일 국립도서관의 통합 전거 파일(게마인자메 노름다타이; GND)에서 사용하는 식별자',
#   'en_relation_label': 'GND ID',
#   'en_relation_description': "identifier from an international authority file of names, subjects, and organizations (please don't use type n = name, disambiguation) - Deutsche Nationalbibliothek"},
#  'P229': {'relation_label': 'IATA 항공사 코드',
#   'en_relation_label': 'IATA airline designator',
#   'en_relation_description': 'two-character identifier for an airline'},
#  'P230': {'relation_label': 'ICAO 항공사 코드',
#   'en_relation_label': 'ICAO airline designator',
#   'en_relation_description': 'three letter identifier for an airline (two letters only until 1982) (for airports, see P239)'},
#  'P231': {'relation_label': 'CAS 등록번호',
#   'relation_description': '미국의 화학초록서비스(Chemical Abstract Service)에 등재된 화합물에 대한 식별자',
#   'en_relation_label': 'CAS Registry Number',
#   'en_relation_description': "identifier for a chemical substance or compound per Chemical Abstract Service's Registry database"},
#  'P232': {'relation_label': 'EC번호',
#   'relation_description': 'urea',
#   'en_relation_label': 'EC number',
#   'en_relation_description': 'identifier for a chemical compound per EINECS or ELINCS'},
#  'P233': {'relation_label': 'SMILES',
#   'en_relation_label': 'canonical SMILES',
#   'en_relation_description': 'Simplified Molecular Input Line Entry Specification (canonical format)'},
#  'P234': {'relation_label': 'InChI',
#   'en_relation_label': 'InChI',
#   'en_relation_description': 'International Chemical Identifier'},
#  'P235': {'relation_label': 'InChIKey',
#   'en_relation_label': 'InChIKey',
#   'en_relation_description': 'A hashed version of the full standard InChI - designed to create an identifier that encodes structural information and can also be practically used in web searching.'},
#  'P236': {'relation_label': '국제표준연속간행물번호',
#   'relation_description': '연속 간행물(잡지, 학회지 등)에 부여되는 번호',
#   'en_relation_label': 'ISSN',
#   'en_relation_description': 'International Standard Serial Number (print or electronic)'},
#  'P237': {'relation_label': '문장을 다룬 항목',
#   'relation_description': '항목 주제를 상징하는 문장을 다룬 항목',
#   'en_relation_label': 'coat of arms',
#   'en_relation_description': "subject's coat of arms"},
#  'P238': {'relation_label': 'IATA 공항 코드',
#   'en_relation_label': 'IATA airport code',
#   'en_relation_description': 'three-letter identifier for designating airports or cities (for airlines, see P229)'},
#  'P239': {'relation_label': 'ICAO 공항 코드',
#   'en_relation_label': 'ICAO airport code',
#   'en_relation_description': 'four-character alphanumeric identifier for designating airports (for airlines, see P230)'},
#  'P240': {'relation_label': 'FAA 공항 코드',
#   'en_relation_label': 'FAA airport code',
#   'en_relation_description': 'three-letter or four-letter alphanumeric code identifying United States airports'},
#  'P241': {'relation_label': '군별',
#   'relation_description': '항목 주제인 인물, 부대 등이 속해 있는 군',
#   'en_relation_label': 'military branch',
#   'en_relation_description': 'branch to which this military unit, award, office, or person belongs, e.g. Royal Navy'},
#  'P242': {'relation_label': '이 주제의 위치를 나타낸 지도',
#   'relation_description': '항목 주제의 위치를 강조한 지도',
#   'en_relation_label': 'locator map image',
#   'en_relation_description': 'geographic map image which highlights the location of the subject within some larger entity'},
#  'P243': {'relation_label': 'OCLC 제어 번호',
#   'relation_description': '온라인 컴퓨터 도서관 센터(OCLC)에서 사용하는 식별자',
#   'en_relation_label': 'OCLC control number',
#   'en_relation_description': 'identifier for a unique bibliographic record in OCLC WorldCat'},
#  'P244': {'relation_label': '미국 의회도서관 전거 ID',
#   'relation_description': '항목 주제에 대해 미국 의회도서관에서 전거 통제용으로 사용하는 식별자 (도서에 쓰는 ID는 P1144를 사용하세요)',
#   'en_relation_label': 'Library of Congress authority ID',
#   'en_relation_description': 'Library of Congress name authority (persons, families, corporate bodies, events, places, works and expressions) and subject authority identifier [Format: 1-2 specific letters followed by 8-10 digits (see regex). For manifestations, use P1144]'},
#  'P245': {'relation_label': 'ULAN ID',
#   'relation_description': '항목 주제에 대해 Getty Union List of Artist Names에서 사용하는 식별자',
#   'en_relation_label': 'Union List of Artist Names ID',
#   'en_relation_description': 'identifier from the Getty Union List of Artist Names'},
#  'P246': {'relation_label': '원소 기호',
#   'relation_description': '항목 주제인 화학 원소를 식으로 나타낼 때 사용하는 기호',
#   'en_relation_label': 'element symbol',
#   'en_relation_description': 'identifier for a chemical element'},
#  'P247': {'relation_label': 'COSPAR ID',
#   'en_relation_label': 'COSPAR ID',
#   'en_relation_description': 'international satellite designation, administered by the UN Committee on Space Research (COSPAR), similar but not synonymous with the NSSDCA ID (P8913)'},
#  'P248': {'relation_label': '다음에 명시되어 있음',
#   'relation_description': '이 서술은 다음의 정보원(문헌)을 참고하여 작성되었음',
#   'en_relation_label': 'stated in',
#   'en_relation_description': 'to be used in the references field to refer to the information document or database in which a claim is made; for qualifiers use P805; for the type of document in which a claim is made use P3865'},
#  'P249': {'relation_label': '상장 코드',
#   'en_relation_label': 'ticker symbol',
#   'en_relation_description': 'identifier for a publicly traded share of a particular stock on a particular stock market or that of a cryptocurrency'},
#  'P263': {'relation_label': '관저',
#   'relation_description': '항목 주제인 직함을 위해 마련된 거주 시설, 또는 항목 주제인 인물이 임기 동안 거주한 장소',
#   'en_relation_label': 'official residence',
#   'en_relation_description': 'the residence at which heads of government and other senior figures officially reside'},
#  'P264': {'relation_label': '음반 레이블',
#   'relation_description': '음악 레코딩과 뮤직비디오의 마케팅을 위한 브랜드나 상표',
#   'en_relation_label': 'record label',
#   'en_relation_description': 'brand and trademark associated with the marketing of subject music recordings and music videos'},
#  'P267': {'relation_label': 'ATC 코드',
#   'en_relation_label': 'ATC code',
#   'en_relation_description': 'therapeutic chemical identification code per ATC'},
#  'P268': {'relation_label': '프랑스 국립도서관 ID',
#   'relation_description': '항목 주제에 대해 프랑스 국립도서관(BnF)에서 부여한 식별자',
#   'en_relation_label': 'Bibliothèque nationale de France ID',
#   'en_relation_description': "identifier for the subject issued by BNF (Bibliothèque nationale de France). Format: 8 digits followed by a check-digit or letter, do not include the initial 'cb'."},
#  'P269': {'relation_label': 'SUDOC 전거 식별자',
#   'relation_description': '프랑스 대학 도서관 종합목록에서 쓰는 전거 통제용 식별자',
#   'en_relation_label': 'IdRef ID',
#   'en_relation_description': 'identifier for authority control in the French collaborative library catalog (see also P1025). Format: 8 digits followed by a digit or "X"'},
#  'P270': {'relation_label': 'CALIS',
#   'en_relation_label': 'CALIS ID',
#   'en_relation_description': 'identifier for authority control per CALIS (China Academic Library & Information System)'},
#  'P271': {'relation_label': 'CiNii 저자 식별자',
#   'en_relation_label': 'CiNii author ID (books)',
#   'en_relation_description': 'identifier for a book author in CiNii (Scholarly and Academic Information Navigator)'},
#  'P272': {'relation_label': '제작사',
#   'relation_description': '영화, 음반, 공연 예술 작품을 제작하는 회사',
#   'en_relation_label': 'production company',
#   'en_relation_description': 'company that produced this film, audio or performing arts work'},
#  'P274': {'relation_label': '화학식',
#   'relation_description': '화합물을 원소 기호들로 표현한 식',
#   'en_relation_label': 'chemical formula',
#   'en_relation_description': 'description of chemical compound  giving element symbols and counts'},
#  'P275': {'relation_label': '라이선스',
#   'relation_description': '저작물의 배포 라이선스',
#   'en_relation_label': 'copyright license',
#   'en_relation_description': 'license under which this copyrighted work is released'},
#  'P276': {'relation_label': '위치',
#   'relation_description': '항목 주제인 물리적 대상이 있는 곳, 또는 사건이 일어나거나 행사가 열린 곳 (단 위치를 행정 구역으로 나타낼 때는 P131을, 지형의 특징으로 나타낼 떄는 P706을 대신 사용할 것)',
#   'en_relation_label': 'location',
#   'en_relation_description': 'location of the object, structure or event. In the case of an administrative entity as containing item use P131. For statistical entities use P8138. In the case of a geographic entity use P706. Use P7153 for locations associated with the object.'},
#  'P277': {'relation_label': '프로그래밍 언어',
#   'relation_description': '소프트웨어 개발에 사용된 프로그래밍 언어(들)',
#   'en_relation_label': 'programming language',
#   'en_relation_description': 'the programming language(s) in which the software is developed'},
#  'P278': {'relation_label': 'GOST 7.75–97 부호',
#   'en_relation_label': 'GOST 7.75–97 code',
#   'en_relation_description': 'identifier for a language according to GOST 7.75–97'},
#  'P279': {'relation_label': '다음의 하위 개념임',
#   'relation_description': '항목 주제는 다음의 개념을 특징에 따라 다시 정의한 하위 개념임 (이 항목을 범주로 삼는 하위 항목 주제들의 상위 개념들에는 이 항목의 상위 개념도 포함되어 있어야 함)',
#   'en_relation_label': 'subclass of',
#   'en_relation_description': 'next higher class or type; all instances of these items are instances of those items; this item is a class (subset) of that item. Not to be confused with P31 (instance of)'},
#  'P281': {'relation_label': '우편번호',
#   'relation_description': '항목 주제인 장소의 우편번호',
#   'en_relation_label': 'postal code',
#   'en_relation_description': 'identifier assigned by postal authorities for the subject area or building'},
#  'P282': {'relation_label': '문자 체계',
#   'relation_description': '항목 주제인 언어 등을 표기하는데 쓰이는 글자 또는 수단',
#   'en_relation_label': 'writing system',
#   'en_relation_description': 'alphabet, character set or other system of writing used by a language, supported by a typeface'},
#  'P286': {'relation_label': '이 팀의 감독',
#   'relation_description': '항목 주제인 팀(구단)의 감독을 맡은 사람',
#   'en_relation_label': 'head coach',
#   'en_relation_description': 'on-field manager or head coach of a sports club (not to be confused with a general manager P505, which is not a coaching position) or person'},
#  'P287': {'relation_label': '디자이너',
#   'en_relation_label': 'designed by',
#   'en_relation_description': 'person(s) or organization which designed the object'},
#  'P289': {'relation_label': '선급',
#   'en_relation_label': 'vessel class',
#   'en_relation_description': 'series of vessels built to the same design of which this vessel is a member'},
#  'P291': {'relation_label': '발행 장소',
#   'relation_description': '항목 주제인 저작물을 처음 발행한 장소',
#   'en_relation_label': 'place of publication',
#   'en_relation_description': 'geographical place of publication of the edition (use 1st edition when referring to works)'},
#  'P296': {'relation_label': '역 코드',
#   'relation_description': '항목 주제인 철도역에 할당된 고유 식별자',
#   'en_relation_label': 'station code',
#   'en_relation_description': 'generic identifier for a railway station, when possible, use specific property on certain coding system (e.g. P1378 for China Railway TMIS codes)'},
#  'P297': {'relation_label': 'ISO 3166-1 코드 (alpha-2)',
#   'relation_description': '항목 주제인 국가에 대해 ISO 3166-1에서 정의한 코드 중 두 글자의 로마자로 구성된 코드',
#   'en_relation_label': 'ISO 3166-1 alpha-2 code',
#   'en_relation_description': 'identifier for a country in two-letter format per ISO 3166-1'},
#  'P298': {'relation_label': 'ISO 3166-1 코드 (alpha-3)',
#   'relation_description': '항목 주제인 국가에 대해 ISO 3166-1에서 정의한 코드 중 세 글자의 로마자로 구성된 코드',
#   'en_relation_label': 'ISO 3166-1 alpha-3 code',
#   'en_relation_description': 'identifier for a country in three-letter format per ISO 3166-1'},
#  'P299': {'relation_label': 'ISO 3166-1 코드 (숫자)',
#   'relation_description': '항목 주제인 국가에 대해 ISO 3166-1에서 정의한 코드 중 숫자로 구성된 코드',
#   'en_relation_label': 'ISO 3166-1 numeric code',
#   'en_relation_description': 'identifier for a country in numeric format per ISO 3166-1'},
#  'P300': {'relation_label': 'ISO 3166-2 코드',
#   'relation_description': '항목 주제인 행정 구역에 대해 ISO 3166-2에서 정의한 코드 (ISO 3166-1 alpha-2 코드 포함)',
#   'en_relation_label': 'ISO 3166-2 code',
#   'en_relation_description': 'identifier for a country subdivision per ISO 3166-2 (include country code)'},
#  'P301': {'relation_label': '이 분류에서 다루는 주제',
#   'relation_description': '항목 주제인 위키미디어 분류에서 중점적으로 다룬 것',
#   'en_relation_label': "category's main topic",
#   'en_relation_description': 'primary topic of the subject Wikimedia category'},
#  'P303': {'relation_label': 'EE 번호',
#   'en_relation_label': 'EE breed number',
#   'en_relation_description': 'breed identification number per the EE list of the breeds of fancy pigeons (ELFP)'},
#  'P304': {'relation_label': '실려 있는 쪽수',
#   'relation_description': '항목 주제가 실려 있는 쪽수',
#   'en_relation_label': 'page(s)',
#   'en_relation_description': 'page number of source referenced for statement. Note "column(s)" (P3903) and "folio(s)" (P7416) for other numbering systems'},
#  'P305': {'relation_label': 'IETF 언어 태그',
#   'en_relation_label': 'IETF language tag',
#   'en_relation_description': 'identifier for language or languoid per the Internet Engineering Task Force; can include a primary language subtag,  subtags for script, region, variant, extension, or private-use. Format: 2 or 3 letters, followed by "-" if subtags present'},
#  'P306': {'relation_label': '운영 체제',
#   'relation_description': '항목 주제인 소프트웨어를 실행시킬 수 있는 운영 체제',
#   'en_relation_label': 'operating system',
#   'en_relation_description': 'operating system (OS) on which a software works or the OS installed on hardware'},
#  'P344': {'relation_label': '촬영 감독',
#   'en_relation_label': 'director of photography',
#   'en_relation_description': 'person responsible for the framing, lighting, and filtration of the subject work'},
#  'P345': {'relation_label': 'IMDb ID',
#   'relation_description': '항목 주제에 대해 인터넷 영화 데이터베이스(IMDb)에서 사용하는 식별자 (tt, nm, ch, co, ev의 접두사를 가짐)',
#   'en_relation_label': 'IMDb ID',
#   'en_relation_description': "identifier for the IMDb [with prefix 'tt', 'nm', 'co', 'ev', 'ch' or 'ni']"},
#  'P347': {'relation_label': 'Joconde',
#   'relation_description': '프랑스 문화부 Joconde 데이터베이스 ID',
#   'en_relation_label': 'Joconde work ID',
#   'en_relation_description': 'identifier in the Joconde database of the French Ministry of Culture'},
#  'P348': {'relation_label': '소프트웨어 버전',
#   'relation_description': '소프트웨어의 현재와 과거의 버전(들)',
#   'en_relation_label': 'software version identifier',
#   'en_relation_description': 'numeric or nominal identifier of a version of a software program or file format, current or past'},
#  'P349': {'relation_label': '일본 국립국회도서관 ID',
#   'relation_description': '항목 주제에 대해 일본 국립국회도서관(NDL)에서 전거 통제용으로 사용하는 식별자',
#   'en_relation_label': 'National Diet Library ID',
#   'en_relation_description': 'identifier for authority control per the National Diet Library of Japan'},
#  'P350': {'relation_label': 'RKDimages',
#   'en_relation_label': 'RKDimages ID',
#   'en_relation_description': 'identifier per RKDimages of the Netherlands Institute for Art History'},
#  'P351': {'relation_label': 'Entrez 유전자 ID',
#   'en_relation_label': 'Entrez Gene ID',
#   'en_relation_description': 'identifier for a gene per the NCBI Entrez database'},
#  'P352': {'relation_label': 'UniProt ID',
#   'en_relation_label': 'UniProt protein ID',
#   'en_relation_description': 'identifier for a protein per the UniProt database'},
#  'P353': {'relation_label': '유전자 기호',
#   'en_relation_label': 'HGNC gene symbol',
#   'en_relation_description': 'The official gene symbol approved by the HGNC, which is typically a short form of the gene name.'},
#  'P354': {'relation_label': 'HGNC ID',
#   'en_relation_label': 'HGNC ID',
#   'en_relation_description': 'A unique ID provided by the HGNC for each gene with an approved symbol. HGNC IDs remain stable even if a name or symbol changes.'},
#  'P355': {'relation_label': '산하 기관',
# ...
#  'P1217': {'relation_label': 'IBDB 극장 식별자',
#   'en_relation_label': 'Internet Broadway Database venue ID',
#   'en_relation_description': 'identifier for a theatre or other venue in the IBDB'},
#  'P1218': {'relation_label': 'P1218',
#   'en_relation_label': 'Internet Broadway Database production ID',
#   'en_relation_description': 'identifier for a specific run of a show'},
#  'P1219': {'relation_label': 'IBDB 작품 식별자',
#   'en_relation_label': 'Internet Broadway Database show ID',
#   'en_relation_description': 'identifier for a play or other work (which may have had 1 or more productions)'},
#  'P1220': {'relation_label': 'IBDB 인물 ID',
#   'relation_description': '항목 주제의 인물에 대해 인터넷 브로드웨이 데이터베이스(IBDB)에서 사용하는 식별자',
#   'en_relation_label': 'Internet Broadway Database person ID',
#   'en_relation_description': 'identifier\xa0for personnel or organizations on Broadway'},
#  'P1221': {'relation_label': '압축기 유형', 'en_relation_label': 'compressor type'},
#  'P1225': {'relation_label': '미 국립문서기록관리청 식별자',
#   'relation_description': '미합중국 국립문서기록관리청 온라인 카탈로그에서 사용하는 식별자',
#   'en_relation_label': 'U.S. National Archives Identifier',
#   'en_relation_description': "identifier for the United States National Archives and Records Administration's online catalog"},
#  'P1227': {'relation_label': '천문학적 필터',
#   'relation_description': '전자기 스펙트럼에서 특별한 구역을 분리하기 위해 사용하는 필터',
#   'en_relation_label': 'astronomical filter',
#   'en_relation_description': 'passband used to isolate particular sections of the electromagnetic spectrum'},
#  'P1229': {'relation_label': '오픈폴리스 ID',
#   'en_relation_label': 'Openpolis ID',
#   'en_relation_description': 'identifier in Openpolis, a database of Italian politicians'},
#  'P1230': {'relation_label': 'JSTOR 저널 코드',
#   'relation_description': 'JSTOR 저널 식별자',
#   'en_relation_label': 'JSTOR journal ID',
#   'en_relation_description': 'identifier for a journal in JSTOR'},
#  'P1232': {'relation_label': 'P1232',
#   'en_relation_label': 'Linguist list code',
#   'en_relation_description': 'identifier for a language per Linguist list'},
#  'P1233': {'relation_label': 'ISFDB 저자 ID',
#   'relation_description': '인터넷 사변 소설 데이터베이스(ISFDB)에서 사용하는 저자 식별자',
#   'en_relation_label': 'Internet Speculative Fiction Database author ID',
#   'en_relation_description': 'identifier for a person in the Internet Speculative Fiction Database'},
#  'P1234': {'relation_label': 'ISFDB 출판 ID',
#   'en_relation_label': 'ISFDB publication ID',
#   'en_relation_description': 'identifier for an edition of a publication in the Internet Speculative Fiction Database'},
#  'P1235': {'relation_label': 'ISFDB 시리즈 ID',
#   'en_relation_label': 'ISFDB series ID',
#   'en_relation_description': 'identifier for a series, periodical or franchise in the Internet Speculative Fiction Database'},
#  'P1236': {'relation_label': '파슨스 코드',
#   'en_relation_label': 'Parsons code',
#   'en_relation_description': 'identifier for melodic contours of music'},
#  'P1237': {'relation_label': '박스 오피스 모조 영화 ID',
#   'relation_description': '박스 오피스 모조(Box Office Mojo)에서 사용하는 영화의 식별자',
#   'en_relation_label': 'Box Office Mojo film ID (former scheme)',
#   'en_relation_description': 'identifier for a movie at the website Box Office Mojo'},
#  'P1238': {'relation_label': '스웨덴축구협회 ID',
#   'relation_description': '항목 주제인 스웨덴 축구 선수에 대해 스웨덴 축구 협회의 데이터베이스에서 사용하는 식별자',
#   'en_relation_label': 'Swedish Football Association player ID',
#   'en_relation_description': "identifier for a Swedish association football (soccer) player's page at Svenskfotboll.se, the official website of the Swedish Football Association (in Swedish: Svenska Fotbollförbundet; SvFF)"},
#  'P1239': {'relation_label': 'P1239',
#   'en_relation_label': 'ISFDB publisher ID',
#   'en_relation_description': 'identifier for a publisher in the Internet Speculative Fiction Database'},
#  'P1240': {'relation_label': 'P1240',
#   'en_relation_label': 'Danish Bibliometric Research Indicator level',
#   'en_relation_description': 'Danish scientific level of research publications, coordinated with the nordic list of publication channels. See also item {{q|Q57408668}}'},
#  'P1241': {'relation_label': '스위스축구협회 클럽 번호',
#   'relation_description': '항목 주제의 스위스 축구 클럽에 대해 스위스축구협회가 부여한 식별 번호',
#   'en_relation_label': 'Swiss Football Association club number',
#   'en_relation_description': 'identifier'},
#  'P1242': {'relation_label': 'P1242',
#   'en_relation_label': 'Theatricalia play ID',
#   'en_relation_description': 'identifier for a theatrical work, in the Theatricalia database'},
#  'P1243': {'relation_label': 'P1243',
#   'en_relation_label': 'ISRC',
#   'en_relation_description': 'international standard code for uniquely identifying sound recordings and music video recordings'},
#  'P1245': {'relation_label': 'P1245',
#   'en_relation_label': 'OmegaWiki Defined Meaning',
#   'en_relation_description': '"Defined Meaning" on the site'},
#  'P1246': {'relation_label': '특허 번호',
#   'en_relation_label': 'patent number',
#   'en_relation_description': 'identifier for a patented invention'},
#  'P1247': {'relation_label': '압축비',
#   'relation_description': '엔진의 압축비',
#   'en_relation_label': 'compression ratio',
#   'en_relation_description': 'compression ratio of a reciprocating combustion engine; for data compression, use P1107 with qualifiers'},
#  'P1248': {'relation_label': 'P1248',
#   'en_relation_label': 'KulturNav-ID',
#   'en_relation_description': 'identifier for people, places, events, etc. used by some Nordic museums'},
#  'P1249': {'relation_label': '문헌 기록상 최초 연도',
#   'relation_description': '주제 항목이 기록된 가장 오래된 연도',
#   'en_relation_label': 'time of earliest written record',
#   'en_relation_description': 'first time a subject was mentioned in writing'},
#  'P1250': {'relation_label': 'P1250',
#   'en_relation_label': 'Danish Bibliometric Research Indicator (BFI) SNO/CNO',
#   'en_relation_description': 'serial & conference identifier'},
#  'P1251': {'relation_label': 'ABS ASCL 코드',
#   'en_relation_label': 'ABS ASCL 2011 code',
#   'en_relation_description': 'Numerical language identifier in the Australian Standard Classification of Languages regulated by Australian Bureau of Statistics'},
#  'P1252': {'relation_label': 'AUSTLANG 코드',
#   'en_relation_label': 'AUSTLANG code',
#   'en_relation_description': 'identifier for a language in the Australian Indigenous Languages Database'},
#  'P1253': {'relation_label': 'P1253',
#   'en_relation_label': 'BCU Ecrivainsvd ID',
#   'en_relation_description': 'identifier in the database of writers from the canton of Vaud'},
#  'P1254': {'relation_label': 'P1254',
#   'en_relation_label': 'Slovenska biografija ID',
#   'en_relation_description': 'identifier in the "Slovenska biografija" reference project'},
#  'P1255': {'relation_label': 'P1255',
#   'en_relation_label': 'HelveticArchives ID',
#   'en_relation_description': "identifier in the Swiss National Library's archive database"},
#  'P1256': {'relation_label': 'P1256',
#   'en_relation_label': 'Iconclass notation',
#   'en_relation_description': 'Iconclass code that corresponds with an artistic theme or concept. For artworks, use P1257 (depicts Iconclass notation)'},
#  'P1257': {'relation_label': 'P1257',
#   'en_relation_label': 'depicts Iconclass notation',
#   'en_relation_description': 'Iconclass code depicted in an artwork. For linking Iconclass codes with their corresponding artistic themes or concepts, use P1256 (Iconclass notation).'},
#  'P1258': {'relation_label': '로튼 토마토 ID',
#   'relation_description': '항목 주제에 대해 로튼 토마토(Rotten Tomatoes)에서 사용하는 식별자',
#   'en_relation_label': 'Rotten Tomatoes ID',
#   'en_relation_description': 'identifier on Rotten Tomatoes'},
#  'P1259': {'relation_label': '보이는 대상의 좌표',
#   'relation_description': '요소에 의해 묘사되는 장면이 보이는 지점 (요소는 사진, 그림 등이 될 수 있음)',
#   'en_relation_label': 'coordinates of the point of view',
#   'en_relation_description': 'point from which the scene depicted by the element is seen (element can be a photo, a painting, etc.)'},
#  'P1260': {'relation_label': 'P1260',
#   'en_relation_label': 'Swedish Open Cultural Heritage URI',
#   'en_relation_description': 'identifier'},
#  'P1261': {'relation_label': 'P1261',
#   'en_relation_label': 'Scandinavian Runic-text Database',
#   'en_relation_description': 'database about runic inscriptions (including runestones), mainly in Sweden, but stones in all of Europe, Greenland and U.S. can be found here'},
#  'P1262': {'relation_label': 'RAÄ 번호',
#   'en_relation_label': 'RAÄ number',
#   'en_relation_description': 'Identificator  for an element in the Database of the cultural heritage in Sweden'},
#  'P1263': {'relation_label': 'NNDB 인물 ID',
#   'relation_description': '항목 주제인 인물에 대해 Notable Names Database(노터블 네임스 데이터베이스)에서 사용하는 식별자',
#   'en_relation_label': 'NNDB people ID',
#   'en_relation_description': 'identifier in the Notable Names Database, a biographical database: only for people entries'},
#  'P1264': {'relation_label': '유효 기간',
#   'en_relation_label': 'valid in period',
#   'en_relation_description': 'time period when a statement is valid'},
#  'P1265': {'relation_label': 'AlloCiné 영화 ID',
#   'relation_description': '항목 주제인 영화에 대해 AlloCiné(알로시네)에서 사용하는 식별자',
#   'en_relation_label': 'AlloCiné film ID',
#   'en_relation_description': 'identifier for a film in the French AlloCiné database'},
#  'P1266': {'relation_label': 'AlloCiné 인물 ID',
#   'relation_description': '항목 주제인 인물에 대해 AlloCiné(알로시네)에서 사용하는 식별자',
#   'en_relation_label': 'AlloCiné person ID',
#   'en_relation_description': 'identifier for a person on the AlloCiné film database'},
#  'P1267': {'relation_label': 'AlloCiné 시리즈 ID',
#   'relation_description': '항목 주제인 시리즈에 대해 AlloCiné(알로시네)에서 사용하는 식별자',
#   'en_relation_label': 'AlloCiné series ID',
#   'en_relation_description': 'identifier for a serie in the AlloCiné film database'},
#  'P1268': {'relation_label': '대표하는 조직 또는 개인',
#   'en_relation_label': 'represents',
#   'en_relation_description': 'organization, individual, or concept that an entity represents'},
#  'P1269': {'relation_label': '상위 주제',
#   'relation_description': '다음 주제의 특정 부분을 현재 항목에서 다루고 있음',
#   'en_relation_label': 'facet of',
#   'en_relation_description': 'topic of which this item is an aspect, item that offers a broader perspective on the same topic'},
#  'P1270': {'relation_label': 'P1270',
#   'en_relation_label': 'Norwegian Register journal ID',
#   'en_relation_description': 'identifier for academic journals'},
#  'P1271': {'relation_label': 'P1271',
#   'en_relation_label': 'Norway Database for Statistics on Higher education publisher ID',
#   'en_relation_description': 'identifier'},
#  'P1272': {'relation_label': 'P1272',
#   'en_relation_label': 'Norway Import Service and Registration Authority periodical code',
#   'en_relation_description': 'Wikidata property for authority control for academic journals'},
#  'P1273': {'relation_label': '카탈루냐 국립도서관 ID',
#   'relation_description': '항목 주제에 대해 카탈루냐 국립도서관(BNC)에서 사용하는 전거 통제용 식별자',
#   'en_relation_label': 'CANTIC ID (old)',
#   'en_relation_description': 'old identifier for authority control managed by the Library of Catalonia. Format: "a", 7 digits, "x" or digit'},
#  'P1274': {'relation_label': 'P1274',
#   'en_relation_label': 'ISFDB title ID',
#   'en_relation_description': 'identifier for a title in the Internet Speculative Fiction Database'},
#  'P1275': {'relation_label': 'P1275',
#   'en_relation_label': 'Norway Import Service and Registration Authority publisher code',
#   'en_relation_description': 'identifier'},
#  'P1276': {'relation_label': 'P1276',
#   'en_relation_label': 'Dictionnaire du Jura ID',
#   'en_relation_description': 'identifier in the encyclopedia Dictionnaire du Jura'},
#  'P1277': {'relation_label': 'P1277',
#   'en_relation_label': 'JUFO ID',
#   'en_relation_description': 'identifier in the Julkaisufoorumi (Finnish Publication Forum)'},
#  'P1278': {'relation_label': 'P1278',
#   'en_relation_label': 'Legal Entity Identifier',
#   'en_relation_description': 'identifier for a legally distinct entity per ISO 17442'},
#  'P1279': {'relation_label': '물가상승률',
#   'en_relation_label': 'inflation rate',
#   'en_relation_description': 'percent change in the consumer price index (CPI)'},
#  'P1280': {'relation_label': 'CONOR.SI ID',
#   'en_relation_label': 'CONOR.SI ID',
#   'en_relation_description': 'identifier\xa0in the National and University Library, Ljubljana database'},
#  'P1281': {'relation_label': 'WOEID',
#   'en_relation_label': 'WOEID',
#   'en_relation_description': 'identifier for a location on Yahoo! GeoPlanet and Flickr'},
#  'P1282': {'relation_label': '오픈스트리트맵 태그/키',
#   'relation_description': '항목 주제인 개념에 대해 오픈스트리트맵(OpenStreetMap)에서 사용하는 태그 또는 스키마(속성)',
#   'en_relation_label': 'OpenStreetMap tag or key',
#   'en_relation_description': 'OpenStreetMap tagging schema (a Key:key, Tag:key=value, Relation:type, or Role:role) for classes, properties, and values'},
#  'P1283': {'relation_label': '제작에 참여한 영화들의 목록',
#   'relation_description': '항목의 인물이 참여했던 영화 작품들의 목록 문서',
#   'en_relation_label': 'filmography',
#   'en_relation_description': 'item for the list of films a person has contributed to. Don\'t use it to add film items. Instead, add actors as "cast member" (P161) on items for films, directors with "director" (P57)'},
#  'P1284': {'relation_label': 'P1284',
#   'en_relation_label': 'Munzinger person ID',
#   'en_relation_description': 'identifier on the Munzinger Archiv'},
#  'P1285': {'relation_label': 'P1285',
#   'en_relation_label': 'Munzinger Sport number',
#   'en_relation_description': 'identifer on the Munzinger Archiv'},
#  'P1286': {'relation_label': 'P1286',
#   'en_relation_label': 'Munzinger Pop ID',
#   'en_relation_description': 'identifier on the Munzinger Archiv'},
#  'P1287': {'relation_label': 'P1287',
#   'en_relation_label': 'KDG Komponisten der Gegenwart ID',
#   'en_relation_description': 'identifier on the Munzinger Archiv'},
#  'P1288': {'relation_label': 'P1288',
#   'en_relation_label': 'Kritisches Lexikon der Gegenwartsliteratur ID',
#   'en_relation_description': 'identifier on the Munzinger Archiv'},
#  'P1289': {'relation_label': 'P1289',
#   'en_relation_label': 'Kritisches Lexikon zur fremdsprachigen Gegenwartsliteratur ID',
#   'en_relation_description': 'identifier in the critical dictionary of foreign contemporary literature'},
#  'P1290': {'relation_label': '대부모',
#   'relation_description': '항목 주제인 기독교 신자의 대부모(신앙적 후견인)',
#   'en_relation_label': 'godparent',
#   'en_relation_description': 'person who is the godparent of a given person'},
#  'P1291': {'relation_label': 'P1291',
#   'en_relation_label': 'Association Authors of Switzerland ID (former scheme)',
#   'en_relation_description': 'identifier in a Swiss database of modern writers'},
#  'P1292': {'relation_label': 'DNB 에디션',
#   'en_relation_label': 'DNB editions',
#   'en_relation_description': 'identifier\xa0in the German National Library catalogue (see also authority data P227)'},
#  'P1293': {'relation_label': 'P1293',
#   'en_relation_label': "Royal Aero Club Aviator's Certificate ID",
#   'en_relation_description': 'identifier'},
#  'P1294': {'relation_label': 'P1294',
#   'en_relation_label': 'WWF ecoregion code',
#   'en_relation_description': 'identifier for ecoregions'},
#  'P1295': {'relation_label': '방사율',
#   'en_relation_label': 'emissivity',
#   'en_relation_description': 'ability of a substance to radiate thermal energy from its surface'},
#  'P1296': {'relation_label': 'P1296',
#   'en_relation_label': 'Gran Enciclopèdia Catalana ID',
#   'en_relation_description': 'identifier for an item in the Gran Enciclopèdia Catalana'},
#  'P1297': {'relation_label': 'P1297',
#   'en_relation_label': 'IRS Employer Identification Number',
#   'en_relation_description': 'number given to businesses by the United States Internal Revenue Service'},
#  'P1299': {'relation_label': '묘사된 작품',
#   'en_relation_label': 'depicted by',
#   'en_relation_description': 'object depicting this subject (creative works, books of the bible)'},
#  'P1300': {'relation_label': 'P1300',
#   'en_relation_label': 'bibcode',
#   'en_relation_description': 'bibcode for a journal'},
#  'P1301': {'relation_label': '엘리베이터 개수',
#   'en_relation_label': 'number of elevators',
#   'en_relation_description': 'number of elevators in a building'},
#  ...}

# %%
with open('../data/relation/relation_list.txt', 'r') as f:
    rel_list = [x.strip() for x in f.readlines()]
rel_list
# Out:
# ['P17',
#  'P131',
#  'P530',
#  'P150',
#  'P47',
#  'P106',
#  'P27',
#  'P461',
#  'P279',
#  'P495',
#  'P641',
#  'P156',
#  'P155',
#  'P527',
#  'P361',
#  'P1376',
#  'P36',
#  'P118',
#  'P1889',
#  'P31',
#  'P175',
#  'P463',
#  'P54',
#  'P138',
#  'P81',
#  'P40',
#  'P159',
#  'P136',
#  'P171',
#  'P22',
#  'P26',
#  'P3373',
#  'P50',
#  'P30',
#  'P1532',
#  'P178',
#  'P413',
#  'P800',
#  'P1365',
#  'P276',
#  'P1366',
#  'P19',
#  'P449',
#  'P710',
#  'P2936',
#  'P1001',
#  'P140',
#  'P206',
#  'P1056',
#  'P20',
#  'P6',
#  'P123',
#  'P1830',
#  'P127',
#  'P1659',
#  'P112',
#  'P101',
#  'P3095',
#  'P749',
#  'P1696',
#  'P137',
#  'P2789',
#  'P706',
#  'P3842',
#  'P39',
#  'P425',
#  'P1336',
#  'P108',
#  'P172',
#  'P737',
#  'P176',
#  'P102',
#  'P35',
#  'P3730',
#  'P1687',
#  'P945',
#  'P264',
#  'P161',
#  'P69',
#  'P190',
#  'P355',
#  'P2341',
#  'P664',
#  'P407',
#  'P793',
#  'P840',
#  'P1441',
#  'P607',
#  'P197',
#  'P205',
#  'P162',
#  'P807',
#  'P1269',
#  'P170',
#  'P97',
#  'P750',
#  'P551']

# %%
len(rel_list)
# Out:
# 97

# %%
rel_dict = {}

for i, rel_id in enumerate(rel_list):
    tmp_dict = result_dict[rel_id]
    
    rel_dict[rel_id] = tmp_dict
    
len(rel_dict)
# Out:
# 97

# %%
result_dict['P17']
# Out:
# {'relation_label': '다음 나라의 것임',
#  'relation_description': '항목 주제는 다음 나라(국가)의 것을 다루고 있음',
#  'en_relation_label': 'country',
#  'en_relation_description': 'sovereign state of this item (not to be used for human beings)'}

# %%
for i, rel_id in enumerate(rel_list):
    tmp_dict = result_dict[rel_id]
# Out:
# {'relation_label': '다음 나라의 것임', 'relation_description': '항목 주제는 다음 나라(국가)의 것을 다루고 있음', 'en_relation_label': 'country', 'en_relation_description': 'sovereign state of this item (not to be used for human beings)'}

# %%
relid2label = {}

for i, rel_id in enumerate(rel_list):
    tmp_dict = result_dict[rel_id]
    
    relid2label[rel_id] = f"{tmp_dict['relation_label']}({tmp_dict['en_relation_label']})"

# %%
relid2label
# Out:
# {'P17': '다음 나라의 것임(country)',
#  'P131': '다음 행정구역에 위치함(located in the administrative territorial entity)',
#  'P530': '수교국(diplomatic relation)',
#  'P150': '하위 행정구역(contains administrative territorial entity)',
#  'P47': '다음과 경계를 맞닿음(shares border with)',
#  'P106': '직업(occupation)',
#  'P27': '국적(country of citizenship)',
#  'P461': '반대 개념(opposite of)',
#  'P279': '다음의 하위 개념임(subclass of)',
#  'P495': '처음 나온 나라(country of origin)',
#  'P641': '관련 스포츠 종목(sport)',
#  'P156': '다음(followed by)',
#  'P155': '이전(follows)',
#  'P527': '다음으로 이루어져 있음(has part)',
#  'P361': '다음의 한 부분임(part of)',
#  'P1376': '다음 정부의 소재지임(capital of)',
#  'P36': '정부 소재지(capital)',
#  'P118': '리그(league)',
#  'P1889': '다음과는 확실히 다름(different from)',
#  'P31': '다음 종류에 속함(instance of)',
#  'P175': '연주자·가수(performer)',
#  'P463': '다음 공동체의 구성원임(member of)',
#  'P54': '소속 팀(member of sports team)',
#  'P138': '명칭의 유래(named after)',
#  'P81': '이 정거장을 거쳐가는 노선(connecting line)',
#  'P40': '자녀(child)',
#  'P159': '본부 위치(headquarters location)',
#  'P136': '장르(genre)',
#  'P171': '다음의 하위 분류군임(parent taxon)',
#  'P22': '친아버지(father)',
#  'P26': '배우자(spouse)',
#  'P3373': '친형제자매(sibling)',
#  'P50': '저자(author)',
#  'P30': '대륙(continent)',
#  'P1532': '대표국가(country for sport)',
#  'P178': '개발 주체(developer)',
#  'P413': '포지션(position played on team / speciality)',
#  'P800': '대표 작품(notable work)',
#  'P1365': '다음으로부터 이어짐(replaces)',
#  'P276': '위치(location)',
#  'P1366': '다음으로 이어짐(replaced by)',
#  'P19': '태어난 곳(place of birth)',
#  'P449': '다음에서 본방송을 함(original broadcaster)',
#  'P710': '다음이 참여함(participant)',
#  'P2936': '다음 언어가 주로 사용됨(language used)',
#  'P1001': '관할 구역(applies to jurisdiction)',
#  'P140': '종교(religion)',
#  'P206': '다음 유역을 끼고 있음(located in or next to body of water)',
#  'P1056': '제품(product or material produced)',
#  'P20': '사망한 곳(place of death)',
#  'P6': '행정부 수반(head of government)',
#  'P123': '발행 주체(publisher)',
#  'P1830': '소유한 것(owner of)',
#  'P127': '소유자(owned by)',
#  'P1659': '같이 보기(see also)',
#  'P112': '설립자(founded by)',
#  'P101': '전문 분야(field of work)',
#  'P3095': '다음이 이것을 실천함(practiced by)',
#  'P749': '다음의 산하 기관임(parent organization)',
#  'P1696': '반대 속성(inverse property)',
#  'P137': '운영 주체(operator)',
#  'P2789': '다음과 연결되어 있음(connects with)',
#  'P706': '다음 지형에 위치함(located in/on physical feature)',
#  'P3842': '현재 다음 행정구역에 위치함(located in present-day administrative territorial entity)',
#  'P39': '직위(position held)',
#  'P425': '직업의 분야(field of this occupation)',
#  'P1336': '자신의 지역이라 주장하는 곳(territory claimed by)',
#  'P108': '고용한 곳(employer)',
#  'P172': '민족(ethnic group)',
#  'P737': '다음에게서 영향을 받음(influenced by)',
#  'P176': '제조사(manufacturer)',
#  'P102': '소속 정당(member of political party)',
#  'P35': '국가 원수(head of state)',
#  'P3730': '바로 윗 계급(next higher rank)',
#  'P1687': '위키데이터 속성(Wikidata property)',
#  'P945': '따르는 대상(allegiance)',
#  'P264': '음반 레이블(record label)',
#  'P161': '출연한 배우(cast member)',
#  'P69': '다녔던 학교(educated at)',
#  'P190': '자매 결연 도시(twinned administrative body)',
#  'P355': '산하 기관(subsidiary)',
#  'P2341': 'P2341(indigenous to)',
#  'P664': '주최자(organizer)',
#  'P407': '저작물·명칭의 언어(language of work or name)',
#  'P793': '특기할 만한 관련 사건(significant event)',
#  'P840': '공간적 배경(narrative location)',
#  'P1441': '다음 작품에 나옴(present in work)',
#  'P607': '참전한 전쟁(conflict)',
#  'P197': '인접 역(adjacent station)',
#  'P205': '이 유역을 끼고 있는 국가(basin country)',
#  'P162': '제작자(producer)',
#  'P807': '다음에서 떨어져 나온 것임(separated from)',
#  'P1269': '상위 주제(facet of)',
#  'P170': '창작자(creator)',
#  'P97': '작위(noble title)',
#  'P750': '다음이 유통을 맡음(distributed by)',
#  'P551': '거주지(residence)'}

# %%
len(relid2label)
# Out:
# 97

# %%
rel_dict
# Out:
# {'P17': {'relation_label': '다음 나라의 것임',
#   'relation_description': '항목 주제는 다음 나라(국가)의 것을 다루고 있음',
#   'en_relation_label': 'country',
#   'en_relation_description': 'sovereign state of this item (not to be used for human beings)'},
#  'P131': {'relation_label': '다음 행정구역에 위치함',
#   'relation_description': "항목 주제가 위치한 행정 구역 (행정 구역이 아닌 값을 쓰고 싶거나, 사건이 일어난 장소를 쓰고 싶다면 '위치'(P276) 속성을 대신 쓰세요)",
#   'en_relation_label': 'located in the administrative territorial entity',
#   'en_relation_description': 'the item is located on the territory of the following administrative entity. Use P276 for specifying locations that are non-administrative places and for items about events. Use P1382 if the item falls only partially into the administrative entity.'},
#  'P530': {'relation_label': '수교국',
#   'relation_description': '항목 주제인 나라와 수교한 나라들',
#   'en_relation_label': 'diplomatic relation',
#   'en_relation_description': 'diplomatic relations of the country'},
#  'P150': {'relation_label': '하위 행정구역',
#   'relation_description': '항목 주제인 행정 구역이 관할하는 하위 행정 구역',
#   'en_relation_label': 'contains administrative territorial entity',
#   'en_relation_description': '(list of) direct subdivisions of an administrative territorial entity'},
#  'P47': {'relation_label': '다음과 경계를 맞닿음',
#   'relation_description': '국경이나 경계를 접하는 국가나 (같은 단계의) 행정 구역',
#   'en_relation_label': 'shares border with',
#   'en_relation_description': 'countries or administrative subdivisions, of equal level, that this item borders, either by land or water. A single common point is enough.'},
#  'P106': {'relation_label': '직업',
#   'relation_description': '항목 주제인 인물의 직업',
#   'en_relation_label': 'occupation',
#   'en_relation_description': 'occupation of a person; see also "field of work" (Property:P101), "position held" (Property:P39)'},
#  'P27': {'relation_label': '국적',
#   'relation_description': '대상 인물의 국적',
#   'en_relation_label': 'country of citizenship',
#   'en_relation_description': 'the object is a country that recognizes the subject as its citizen'},
#  'P461': {'relation_label': '반대 개념',
#   'relation_description': '이 항목과 반대 관계의 항목',
#   'en_relation_label': 'opposite of',
#   'en_relation_description': 'item that is the opposite of this item'},
#  'P279': {'relation_label': '다음의 하위 개념임',
#   'relation_description': '항목 주제는 다음의 개념을 특징에 따라 다시 정의한 하위 개념임 (이 항목을 범주로 삼는 하위 항목 주제들의 상위 개념들에는 이 항목의 상위 개념도 포함되어 있어야 함)',
#   'en_relation_label': 'subclass of',
#   'en_relation_description': 'next higher class or type; all instances of these items are instances of those items; this item is a class (subset) of that item. Not to be confused with P31 (instance of)'},
#  'P495': {'relation_label': '처음 나온 나라',
#   'relation_description': '항목 주제가 처음 유래되거나 만들어진 국가',
#   'en_relation_label': 'country of origin',
#   'en_relation_description': 'country of origin of this item (creative work, food, phrase, product, etc.)'},
#  'P641': {'relation_label': '관련 스포츠 종목',
#   'relation_description': '항목 주제와 관련이 있는 스포츠 종목',
#   'en_relation_label': 'sport',
#   'en_relation_description': 'sport that the subject participates or participated in or is associated with'},
#  'P156': {'relation_label': '다음',
#   'relation_description': '여럿 가운데 시간적 또는 공간적으로 뒤에 오는 것',
#   'en_relation_label': 'followed by',
#   'en_relation_description': 'immediately following item in a series of which the subject is a part [if the subject has been replaced, e.g. political offices, use "replaced by" (P1366)]'},
#  'P155': {'relation_label': '이전',
#   'relation_description': '여럿 가운데 시간적 또는 공간적으로 앞에 오는 것',
#   'en_relation_label': 'follows',
#   'en_relation_description': 'immediately prior item in a series of which the subject is a part [if the subject has replaced the preceding item, e.g. political offices, use "replaces" (P1365)]'},
#  'P527': {'relation_label': '다음으로 이루어져 있음',
#   'relation_description': '항목 주제가 자신의 부분으로서 가지고 있는 것들',
#   'en_relation_label': 'has part',
#   'en_relation_description': 'part of this subject; inverse property of "part of" (P361). See also "has parts of the class" (P2670).'},
#  'P361': {'relation_label': '다음의 한 부분임',
#   'relation_description': '항목 주제는 다음의 일부분임',
#   'en_relation_label': 'part of',
#   'en_relation_description': 'object of which the subject is a part (if this subject is already part of object A which is a part of object B, then please only make the subject part of object A). Inverse property of "has part" (P527, see also "has parts of the class" (P2670)).'},
#  'P1376': {'relation_label': '다음 정부의 소재지임',
#   'relation_description': '항목 주제인 지역은 다음 정부의 수도임',
#   'en_relation_label': 'capital of',
#   'en_relation_description': 'country, state, department, canton or other administrative division of which the municipality is the governmental seat'},
#  'P36': {'relation_label': '정부 소재지',
#   'relation_description': '항목 주제인 국가·지역의 행정부가 있는 곳',
#   'en_relation_label': 'capital',
#   'en_relation_description': 'seat of government of a country, province, state or other type of administrative territorial entity'},
#  'P118': {'relation_label': '리그',
#   'relation_description': '팀이 출전한 리그',
#   'en_relation_label': 'league',
#   'en_relation_description': 'league in which team or player plays or has played in'},
#  'P1889': {'relation_label': '다음과는 확실히 다름',
#   'relation_description': '다음의 항목과는 분명 서로 다르지만 같은 의미인 것처럼 자주 혼동되는 항목',
#   'en_relation_label': 'different from',
#   'en_relation_description': 'item that is different from another item, with which it is often confused'},
#  'P31': {'relation_label': '다음 종류에 속함',
#   'relation_description': '항목 주제는 다음 종류에 속함 (해당 종류에 속하는 것 중 하나를 고르라고 했을 때 이 항목도 고를 수 있어야 함)',
#   'en_relation_label': 'instance of',
#   'en_relation_description': 'that class of which this subject is a particular example and member'},
#  'P175': {'relation_label': '연주자·가수',
#   'relation_description': '이 역할이나 음악 작품과 관련된 배우, 음악가, 밴드 또는 기타 공연자',
#   'en_relation_label': 'performer',
#   'en_relation_description': 'actor, musician, band or other performer associated with this role or musical work'},
#  'P463': {'relation_label': '다음 공동체의 구성원임',
#   'relation_description': '항목 주제가 소속되어 있는 공동체 (특정 직위에 소속된 경우는 P39를 사용하세요. 인종이나 사회적 그룹에 소속된 경우에도 사용하지 않습니다.)',
#   'en_relation_label': 'member of',
#   'en_relation_description': 'organization, club or musical group to which the subject belongs. Do not use for membership in ethnic or social groups, nor for holding a political position, such as a member of parliament (use P39 for that).'},
#  'P54': {'relation_label': '소속 팀',
#   'relation_description': '현재나 과거에 활동했던 스포츠 팀',
#   'en_relation_label': 'member of sports team',
#   'en_relation_description': 'sports teams or clubs that the subject represents or represented'},
#  'P138': {'relation_label': '명칭의 유래',
#   'relation_description': '항목 주제의 명칭은 다음 항목/사건에서 유래되었음',
#   'en_relation_label': 'named after',
#   'en_relation_description': 'entity or event that inspired the subject\'s name, or namesake (in at least one language). Qualifier "applies to name" (P5168) can be used to indicate which one'},
#  'P81': {'relation_label': '이 정거장을 거쳐가는 노선',
#   'relation_description': '항목 주제인 역·정류장을 거쳐 가는 철도·대중교통 노선',
#   'en_relation_label': 'connecting line',
#   'en_relation_description': 'railway line(s) subject is directly connected to'},
#  'P40': {'relation_label': '자녀',
#   'relation_description': '항목 주제인 인물의 자녀들',
#   'en_relation_label': 'child',
#   'en_relation_description': 'subject has object as child. Do not use for stepchildren'},
#  'P159': {'relation_label': '본부 위치',
#   'relation_description': '항목 주제인 기관·단체의 본부·본사가 있거나 있었던 곳',
#   'en_relation_label': 'headquarters location',
#   'en_relation_description': "city, where an organization's headquarters is or has been situated. Use P276 qualifier for specific building"},
#  'P136': {'relation_label': '장르',
#   'relation_description': '항목 주제인 작품의 장르(갈래) 또는 항목 주제인 팀이 추구하는 장르',
#   'en_relation_label': 'genre',
#   'en_relation_description': "creative work's genre or an artist's field of work (P101). Use main subject (P921) to relate creative works to their topic"},
#  'P171': {'relation_label': '다음의 하위 분류군임',
#   'relation_description': '항목 주제인 분류군의 바로 위의 분류군',
#   'en_relation_label': 'parent taxon',
#   'en_relation_description': 'closest parent taxon of the taxon in question'},
#  'P22': {'relation_label': '친아버지',
#   'relation_description': '항목 주제인 인물의 친부모 중 남성쪽 인물',
#   'en_relation_label': 'father',
#   'en_relation_description': 'male parent of the subject. For stepfather, use "stepparent" (P3448)'},
#  'P26': {'relation_label': '배우자',
#   'relation_description': '항목 주제인 인물의 배우자 (결혼하지 않은 채 같이 지내는 "동거인"에 대해선 P451을 사용하세요)',
#   'en_relation_label': 'spouse',
#   'en_relation_description': 'the subject has the object as their spouse (husband, wife, partner, etc.). Use "unmarried partner" (P451) for non-married companions'},
#  'P3373': {'relation_label': '친형제자매',
#   'relation_description': '항목 주제인 인물의 친형제자매 (의붓형제자매나 배우자의 형제 등은 "친척"(P1038)을 쓰세요)',
#   'en_relation_label': 'sibling',
#   'en_relation_description': 'the subject and the object have the same parents (brother, sister, etc.); use "relative" (P1038) for siblings-in-law (brother-in-law, sister-in-law, etc.) and step-siblings (step-brothers, step-sisters, etc.)'},
#  'P50': {'relation_label': '저자',
#   'relation_description': '항목 주제인 글을 쓴 사람',
#   'en_relation_label': 'author',
#   'en_relation_description': 'main creator(s) of a written work (use on works, not humans); use P2093 when Wikidata item is unknown or does not exist'},
#  'P30': {'relation_label': '대륙',
#   'relation_description': '주제가 속한 대륙. 남극에 위치한 것, 국가, 러시아 도시들같은 둘 이상의 대륙에 걸친 항목에 사용함.',
#   'en_relation_label': 'continent',
#   'en_relation_description': 'continent of which the subject is a part'},
#  'P1532': {'relation_label': '대표국가',
#   'relation_description': '주제 인물이 스포츠를 할 때의 국가',
#   'en_relation_label': 'country for sport',
#   'en_relation_description': 'country a person or a team represents when playing a sport'},
#  'P178': {'relation_label': '개발 주체',
#   'relation_description': '아이템을 주체적으로 개발한 단체 또는 인물',
#   'en_relation_label': 'developer',
#   'en_relation_description': 'organisation or person that developed the item'},
#  'P413': {'relation_label': '포지션',
#   'relation_description': '항목 주제인 선수가 맡은 포지션(위치)',
#   'en_relation_label': 'position played on team / speciality',
#   'en_relation_description': 'position or specialism of a player on a team'},
#  'P800': {'relation_label': '대표 작품',
#   'relation_description': '항목 주제가 제작/저술하거나 그 활동에 참가한 작품들',
#   'en_relation_label': 'notable work',
#   'en_relation_description': "notable scientific, artistic or literary work, or other work of significance among subject's works"},
#  'P1365': {'relation_label': '다음으로부터 이어짐',
#   'relation_description': '항목 주제는 다음으로부터 이어받았음',
#   'en_relation_label': 'replaces',
#   'en_relation_description': 'person, state or item replaced. Use "structure replaces" (P1398) for structures. Use "follows" (P155) if the previous item was not replaced or predecessor and successor are identical'},
#  'P276': {'relation_label': '위치',
#   'relation_description': '항목 주제인 물리적 대상이 있는 곳, 또는 사건이 일어나거나 행사가 열린 곳 (단 위치를 행정 구역으로 나타낼 때는 P131을, 지형의 특징으로 나타낼 떄는 P706을 대신 사용할 것)',
#   'en_relation_label': 'location',
#   'en_relation_description': 'location of the object, structure or event. In the case of an administrative entity as containing item use P131. For statistical entities use P8138. In the case of a geographic entity use P706. Use P7153 for locations associated with the object.'},
#  'P1366': {'relation_label': '다음으로 이어짐',
#   'relation_description': '특정 직장이나 직위, 그 외의 것에서 이전의 것을 대신해 교체된 대상(사람, 상태, 항목) 단, 교체된 것이 아니라 책의 권수처럼 단순히 다음을 가리키는 것이라면 P156을 사용함',
#   'en_relation_label': 'replaced by',
#   'en_relation_description': 'other person or item which continues the item by replacing it in its role. Use P156 (followed by) if the item is not replaced (e.g. books in a series), nor identical, but adds to the series without dropping the role of this item in that series'},
#  'P19': {'relation_label': '태어난 곳',
#   'relation_description': '항목 주제가 태어난 장소',
#   'en_relation_label': 'place of birth',
#   'en_relation_description': 'most specific known (e.g. city instead of country, or hospital instead of city) birth location of a person, animal or fictional character'},
#  'P449': {'relation_label': '다음에서 본방송을 함',
#   'relation_description': '항목 주제인 TV·라디오 프로그램이 본방송(처음 방송)되는 곳',
#   'en_relation_label': 'original broadcaster',
#   'en_relation_description': 'network(s) or service(s) that originally broadcasted a radio or television program'},
#  'P710': {'relation_label': '다음이 참여함',
#   'relation_description': '항목 주제의 사건에 참가했거나 참가한 개인 및 단체',
#   'en_relation_label': 'participant',
#   'en_relation_description': 'person, group of people or organization (object) that actively takes/took part in an event or process (subject).  Preferably qualify with "object has role" (P3831). Use P1923 for participants that are teams.'},
#  'P2936': {'relation_label': '다음 언어가 주로 사용됨',
#   'relation_description': '항목 주제인 장소나 사건에서 주로 사용된 언어',
#   'en_relation_label': 'language used',
#   'en_relation_description': 'language widely used (spoken or written) in this place or at this event'},
#  'P1001': {'relation_label': '관할 구역',
#   'relation_description': '항목 주제인 기관·법·조약 등의 영향력이 미치는 구역',
#   'en_relation_label': 'applies to jurisdiction',
#   'en_relation_description': 'the item (institution, law, public office, public register...) or statement belongs to or has power over or applies to the value (a territorial jurisdiction: a country, state, municipality, ...)'},
#  'P140': {'relation_label': '종교',
#   'relation_description': '주제 항목인 사람, 단체 또는 종교적 건물과 연관된 종교',
#   'en_relation_label': 'religion',
#   'en_relation_description': 'religion of a person, organization or religious building, or associated with this subject'},
#  'P206': {'relation_label': '다음 유역을 끼고 있음',
#   'relation_description': '항목 주제인 지역이 끼고 있는 유역(들)',
#   'en_relation_label': 'located in or next to body of water',
#   'en_relation_description': 'sea, lake, river or stream'},
#  'P1056': {'relation_label': '제품',
#   'relation_description': '정부기관, 업계, 업체, 절차 등에 의해 생성된 물질이나 제품',
#   'en_relation_label': 'product or material produced',
#   'en_relation_description': 'material or product produced by a government agency, business, industry, facility, or process'},
#  'P20': {'relation_label': '사망한 곳',
#   'relation_description': '항목 주제가 죽은 장소',
#   'en_relation_label': 'place of death',
#   'en_relation_description': 'most specific known (e.g. city instead of country, or hospital instead of city) death location of a person, animal or fictional character'},
#  'P6': {'relation_label': '행정부 수반',
#   'relation_description': '항목 주제인 행정부 또는 지자체의 수장',
#   'en_relation_label': 'head of government',
#   'en_relation_description': 'head of the executive power of this town, city, municipality, state, country, or other governmental body'},
#  'P123': {'relation_label': '발행 주체',
#   'relation_description': '도서, 정기간행물, 소프트웨어 등을 출판/발행/배급하는 개인 또는 단체',
#   'en_relation_label': 'publisher',
#   'en_relation_description': 'organization or person responsible for publishing books, periodicals, printed music, podcasts, games or software'},
#  'P1830': {'relation_label': '소유한 것',
#   'relation_description': '항목 주제가 소유한 것들',
#   'en_relation_label': 'owner of',
#   'en_relation_description': 'entities owned by the subject'},
#  'P127': {'relation_label': '소유자',
#   'relation_description': '항목 주제를 소유하고 있는 사람/단체',
#   'en_relation_label': 'owned by',
#   'en_relation_description': 'owner of the subject'},
#  'P1659': {'relation_label': '같이 보기',
#   'relation_description': '주제에 대한 추가적인 정보를 제공할 속성을 나타내기 위해 사용',
#   'en_relation_label': 'see also',
#   'en_relation_description': 'used to indicate another property that might provide additional information about the Wikidata-property'},
#  'P112': {'relation_label': '설립자',
#   'relation_description': '단체의 설립자',
#   'en_relation_label': 'founded by',
#   'en_relation_description': 'founder or co-founder of this organization, religion or place'},
#  'P101': {'relation_label': '전문 분야',
#   'relation_description': '물리학, 역사 같은 주요 활동 분야, 사람을 포함한 어떤 항목에도 사용될 수 있음 (물리학자, 역사가 같은 인물의 직업은 P106 참고)',
#   'en_relation_label': 'field of work',
#   'en_relation_description': 'specialization of a person or organization; see P106 for the occupation'},
#  'P3095': {'relation_label': '다음이 이것을 실천함',
#   'relation_description': '항목 주제인 학문/학파 또는 개념을 다음 종교/국가에서 실천함',
#   'en_relation_label': 'practiced by',
#   'en_relation_description': 'type of agents that study this subject or work in this profession'},
#  'P749': {'relation_label': '다음의 산하 기관임',
#   'relation_description': '항목 주제인 회사·기구·단체의 상부 회사·기구·단체',
#   'en_relation_label': 'parent organization',
#   'en_relation_description': 'parent organization of an organization, opposite of subsidiaries (P355)'},
#  'P1696': {'relation_label': '반대 속성',
#   'relation_description': '해당 속성의 반대 개념을 갖는 속성 (주체와 객체를 역순으로 연결)',
#   'en_relation_label': 'inverse property',
#   'en_relation_description': 'links a property to its inverse property (which relates the subject and object in reverse order)'},
#  'P137': {'relation_label': '운영 주체',
#   'relation_description': '항목 주제인 시설, 장비, 서비스 등을 운영하는 사람/단체',
#   'en_relation_label': 'operator',
#   'en_relation_description': 'person, profession, or organization that operates the equipment, facility, or service'},
#  'P2789': {'relation_label': '다음과 연결되어 있음',
#   'relation_description': '항목 주제인 도로·거리·광장 등과 연결되어 있는 대상',
#   'en_relation_label': 'connects with',
#   'en_relation_description': 'item with which the item is physically connected'},
#  'P706': {'relation_label': '다음 지형에 위치함',
#   'relation_description': '항목 주제가 있는 지형',
#   'en_relation_label': 'located in/on physical feature',
#   'en_relation_description': 'located on the specified (geo)physical feature. Should not be used when the value is only political/administrative (P131) or a mountain range (P4552).'},
#  'P3842': {'relation_label': '현재 다음 행정구역에 위치함',
#   'relation_description': '항목 주제가 위치한 곳의 오늘날 행정구역',
#   'en_relation_label': 'located in present-day administrative territorial entity',
#   'en_relation_description': 'the item was located in the territory of this present-day administrative unit; however the two did not at any point coexist in time'},
#  'P39': {'relation_label': '직위',
#   'relation_description': '주제의 인물이 현재나 과거에 맡았던 직위 또는 공직',
#   'en_relation_label': 'position held',
#   'en_relation_description': 'subject currently or formerly holds the object position or public office'},
#  'P425': {'relation_label': '직업의 분야',
#   'en_relation_label': 'field of this occupation',
#   'en_relation_description': 'activity corresponding to this occupation or profession (use only for occupations/professions - for people use Property:P101, for companies use P452)'},
#  'P1336': {'relation_label': '자신의 지역이라 주장하는 곳',
#   'relation_description': '항목 주제인 지역에 대해 영유권 또는 관할권을 주장하는 국가·지역·단체',
#   'en_relation_label': 'territory claimed by',
#   'en_relation_description': 'administrative divisions that claim control of a given area'},
#  'P108': {'relation_label': '고용한 곳',
#   'relation_description': '주제의 인물이 일하거나 일했던 기관/단체',
#   'en_relation_label': 'employer',
#   'en_relation_description': 'person or organization for which the subject works or worked'},
#  'P172': {'relation_label': '민족',
#   'en_relation_label': 'ethnic group',
#   'en_relation_description': "subject's ethnicity (consensus is that a VERY high standard of proof is needed for this field to be used. In general this means 1) the subject claims it themself, or 2) it is widely agreed on by scholars, or 3) is fictional and portrayed as such)"},
#  'P737': {'relation_label': '다음에게서 영향을 받음',
#   'relation_description': '이 속성값의 항목에 의하여 본문의 항목이 영향받음',
#   'en_relation_label': 'influenced by',
#   'en_relation_description': 'this person, idea, etc. is informed by that other person, idea, etc., e.g. “Heidegger was influenced by Aristotle”'},
#  'P176': {'relation_label': '제조사',
#   'relation_description': '이 물건을 제조/제작한 주요 회사',
#   'en_relation_label': 'manufacturer',
#   'en_relation_description': 'manufacturer or producer of this product'},
#  'P102': {'relation_label': '소속 정당',
#   'relation_description': '정치인 또는 당원이 소속되어 있는 당',
#   'en_relation_label': 'member of political party',
#   'en_relation_description': 'the political party of which this politician is or has been a member or otherwise affiliated'},
#  'P35': {'relation_label': '국가 원수',
#   'relation_description': '항목 주제인 나라에서 최고로 높은 직위에 있는 사람',
#   'en_relation_label': 'head of state',
#   'en_relation_description': 'official with the highest formal authority in a country/state'},
#  'P3730': {'relation_label': '바로 윗 계급',
#   'relation_description': '항목 주제인 계급의 바로 위에 있는 계급',
#   'en_relation_label': 'next higher rank',
#   'en_relation_description': 'higher rank or level in a ranked hierarchy like sport league, military ranks. If there are several possible, list each one and qualify with "criterion used" (P1013), avoid using ranks and date qualifiers. For sports leagues/taxa, use specific properties instead.'},
#  'P1687': {'relation_label': '위키데이터 속성',
#   'relation_description': '이 항목에 관한 주요 위키데이터 속성',
#   'en_relation_label': 'Wikidata property',
#   'en_relation_description': 'main Wikidata property for this item'},
#  'P945': {'relation_label': '따르는 대상',
#   'relation_description': '사람 혹은 조직이 섬기는 국가나 세력',
#   'en_relation_label': 'allegiance',
#   'en_relation_description': 'country (or other power) that the person or organization serves'},
#  'P264': {'relation_label': '음반 레이블',
#   'relation_description': '음악 레코딩과 뮤직비디오의 마케팅을 위한 브랜드나 상표',
#   'en_relation_label': 'record label',
#   'en_relation_description': 'brand and trademark associated with the marketing of subject music recordings and music videos'},
#  'P161': {'relation_label': '출연한 배우',
#   'relation_description': '이 속성을 사용할 때는 "맡은 배역"(P453)을 한정자로 같이 넣어주세요. 또한 음성으로만 출연한 경우 이 속성 대신 "출연한 성우"(P725)를 사용해주세요.',
#   'en_relation_label': 'cast member',
#   'en_relation_description': 'actor in the subject production [use "character role" (P453) and/or "name of the character role" (P4633) as qualifiers] [use "voice actor" (P725) for voice-only role]'},
#  'P69': {'relation_label': '다녔던 학교',
#   'relation_description': '항목 주제인 인물이 교육받은 곳',
#   'en_relation_label': 'educated at',
#   'en_relation_description': 'educational institution attended by subject'},
#  'P190': {'relation_label': '자매 결연 도시',
#   'relation_description': '항목 주제인 도시와 자매결연 또는 우호교류 협약을 맺은 도시',
#   'en_relation_label': 'twinned administrative body',
#   'en_relation_description': 'twin towns, sister cities, twinned municipalities and other localities that have a partnership or cooperative agreement, either legally or informally acknowledged by their governments'},
#  'P355': {'relation_label': '산하 기관',
#   'relation_description': '항목 주제인 기관·기업·단체 산하의 기관·기업·단체',
#   'en_relation_label': 'subsidiary',
#   'en_relation_description': 'subsidiary of a company or organization; generally a fully owned separate corporation. Compare with "business division" (P199). Opposite of parent organization (P749).'},
#  'P2341': {'relation_label': 'P2341',
#   'en_relation_label': 'indigenous to',
#   'en_relation_description': 'place that a language, folk dance, cooking style, food, species or other cultural expression is found (or was originally found)'},
#  'P664': {'relation_label': '주최자',
#   'en_relation_label': 'organizer',
#   'en_relation_description': 'person or institution organizing an event'},
#  'P407': {'relation_label': '저작물·명칭의 언어',
#   'relation_description': 'P407. 항목 주제인, 영상물이 아닌 저작물이나 이름에서 주로 사용한 언어 (영상물의 원어를 나타낼 땐 P364를, 인물이 구사하는 언어를 나타낼 땐 P103과 P1412를 사용하세요)',
#   'en_relation_label': 'language of work or name',
#   'en_relation_description': 'language associated with this creative work (such as books, shows, songs, or websites) or a name (for persons use "native language" (P103) and "languages spoken, written or signed" (P1412))'},
#  'P793': {'relation_label': '특기할 만한 관련 사건',
#   'relation_description': '항목 주제에게 있었던 사건들 중 중요하거나 주목할 만한 사건',
#   'en_relation_label': 'significant event',
#   'en_relation_description': 'significant or notable events associated with the subject'},
#  'P840': {'relation_label': '공간적 배경',
#   'relation_description': '이 작품의 사건이 전개된 공간적 배경',
#   'en_relation_label': 'narrative location',
#   'en_relation_description': 'the narrative of the work is set in this location'},
#  'P1441': {'relation_label': '다음 작품에 나옴',
#   'relation_description': '항목 주제인 캐릭터나 개체가 나오는 작품',
#   'en_relation_label': 'present in work',
#   'en_relation_description': 'this (fictional or fictionalized) entity or person appears in that work as part of the narration (use P2860 for works citing other works, P361/P1433 for works being part of other works, P1343 for entities described in non-fictional accounts)'},
#  'P607': {'relation_label': '참전한 전쟁',
#   'relation_description': '인물이나 주제가 참여한 전투, 전쟁, 교전',
#   'en_relation_label': 'conflict',
#   'en_relation_description': 'battles, wars or other military engagements in which the person or item participated'},
#  'P197': {'relation_label': '인접 역',
#   'relation_description': '같은 선로를 공유하는 다음, 이전 역',
#   'en_relation_label': 'adjacent station',
#   'en_relation_description': 'the stations next to this station, sharing the same line(s)'},
#  'P205': {'relation_label': '이 유역을 끼고 있는 국가',
#   'relation_description': '항목 주제의 하천/호수/바다의 유역(수역)을 끼고 있는 나라들',
#   'en_relation_label': 'basin country',
#   'en_relation_description': 'country that have drainage to/from or border the body of water'},
#  'P162': {'relation_label': '제작자',
#   'relation_description': '영화나 음악 작품의 제작자(들)',
#   'en_relation_label': 'producer',
#   'en_relation_description': 'person(s) who produced the film, musical work, theatrical production, etc. (for film, this does not include executive producers, associate producers, etc.) [for production company, use P272, video games - use P178]'},
#  'P807': {'relation_label': '다음에서 떨어져 나온 것임',
#   'relation_description': '이 값이 가리키는 항목으로부터 갈라져 나와 시작되거나 설립됨',
#   'en_relation_label': 'separated from',
#   'en_relation_description': 'subject was founded or started by separating from identified object'},
#  'P1269': {'relation_label': '상위 주제',
#   'relation_description': '다음 주제의 특정 부분을 현재 항목에서 다루고 있음',
#   'en_relation_label': 'facet of',
#   'en_relation_description': 'topic of which this item is an aspect, item that offers a broader perspective on the same topic'},
#  'P170': {'relation_label': '창작자',
#   'relation_description': '항목 주제인 창작물 등을 만든 사람',
#   'en_relation_label': 'creator',
#   'en_relation_description': 'maker of this creative work or other object (where no more specific property exists)'},
#  'P97': {'relation_label': '작위',
#   'en_relation_label': 'noble title',
#   'en_relation_description': 'titles held by the person'},
#  'P750': {'relation_label': '다음이 유통을 맡음',
#   'relation_description': '항목 주제인 저작물을 배포/배급/유통하는 곳',
#   'en_relation_label': 'distributed by',
#   'en_relation_description': 'distributor of a creative work; distributor for a record label; news agency; film distributor'},
#  'P551': {'relation_label': '거주지',
#   'relation_description': '항목 주제인 인물이 거주하는 곳, 또는 거주하던 곳',
#   'en_relation_label': 'residence',
#   'en_relation_description': 'the place where the person is or has been, resident'}}

# %%
label_list = list(relid2label.values())
label_list[:5]
# Out:
# ['다음 나라의 것임(country)',
#  "다음 행정구역에 위치함, 항목 주제가 위치한 행정 구역 (행정 구역이 아닌 값을 쓰고 싶거나, 사건이 일어난 장소를 쓰고 싶다면 '위치'(P276) 속성을 대신 쓰세요)(located in the administrative territorial entity)",
#  '수교국, 항목 주제인 나라와 수교한 나라들(diplomatic relation)',
#  '하위 행정구역, 항목 주제인 행정 구역이 관할하는 하위 행정 구역(contains administrative territorial entity)',
#  '다음과 경계를 맞닿음, 국경이나 경계를 접하는 국가나 (같은 단계의) 행정 구역(shares border with)']

# %%
for relid in rel_dict:
    if relid not in relid2label:
        print(rel_dict[relid])
# Out:
# {'relation_label': '직업의 분야', 'en_relation_label': 'field of this occupation', 'en_relation_description': 'activity corresponding to this occupation or profession (use only for occupations/professions - for people use Property:P101, for companies use P452)'}
# {'relation_label': '다음에게서 영향을 받음', 'relation_description': '이 속성값의 항목에 의하여 본문의 항목이 영향받음', 'en_relation_label': 'influenced by', 'en_relation_description': 'this person, idea, etc. is informed by that other person, idea, etc., e.g. “Heidegger was influenced by Aristotle”'}
# {'relation_label': '위키데이터 속성', 'relation_description': '이 항목에 관한 주요 위키데이터 속성', 'en_relation_label': 'Wikidata property', 'en_relation_description': 'main Wikidata property for this item'}
# {'relation_label': '자매 결연 도시', 'relation_description': '항목 주제인 도시와 자매결연 또는 우호교류 협약을 맺은 도시', 'en_relation_label': 'twinned administrative body', 'en_relation_description': 'twin towns, sister cities, twinned municipalities and other localities that have a partnership or cooperative agreement, either legally or informally acknowledged by their governments'}
# {'relation_label': '주최자', 'en_relation_label': 'organizer', 'en_relation_description': 'person or institution organizing an event'}
# {'relation_label': '공간적 배경', 'relation_description': '이 작품의 사건이 전개된 공간적 배경', 'en_relation_label': 'narrative location', 'en_relation_description': 'the narrative of the work is set in this location'}
# {'relation_label': '작위', 'en_relation_label': 'noble title', 'en_relation_description': 'titles held by the person'}

# %%
relid2label
# Out:
# {'P17': '다음 나라의 것임(country)',
#  'P131': '다음 행정구역에 위치함(located in the administrative territorial entity)',
#  'P530': '수교국(diplomatic relation)',
#  'P150': '하위 행정구역(contains administrative territorial entity)',
#  'P47': '다음과 경계를 맞닿음(shares border with)',
#  'P106': '직업(occupation)',
#  'P27': '국적(country of citizenship)',
#  'P461': '반대 개념(opposite of)',
#  'P279': '다음의 하위 개념임(subclass of)',
#  'P495': '처음 나온 나라(country of origin)',
#  'P641': '관련 스포츠 종목(sport)',
#  'P156': '다음(followed by)',
#  'P155': '이전(follows)',
#  'P527': '다음으로 이루어져 있음(has part)',
#  'P361': '다음의 한 부분임(part of)',
#  'P1376': '다음 정부의 소재지임(capital of)',
#  'P36': '정부 소재지(capital)',
#  'P118': '리그(league)',
#  'P1889': '다음과는 확실히 다름(different from)',
#  'P31': '다음 종류에 속함(instance of)',
#  'P175': '연주자·가수(performer)',
#  'P463': '다음 공동체의 구성원임(member of)',
#  'P54': '소속 팀(member of sports team)',
#  'P138': '명칭의 유래(named after)',
#  'P81': '이 정거장을 거쳐가는 노선(connecting line)',
#  'P40': '자녀(child)',
#  'P159': '본부 위치(headquarters location)',
#  'P136': '장르(genre)',
#  'P171': '다음의 하위 분류군임(parent taxon)',
#  'P22': '친아버지(father)',
#  'P26': '배우자(spouse)',
#  'P3373': '친형제자매(sibling)',
#  'P50': '저자(author)',
#  'P30': '대륙(continent)',
#  'P1532': '대표국가(country for sport)',
#  'P178': '개발 주체(developer)',
#  'P413': '포지션(position played on team / speciality)',
#  'P800': '대표 작품(notable work)',
#  'P1365': '다음으로부터 이어짐(replaces)',
#  'P276': '위치(location)',
#  'P1366': '다음으로 이어짐(replaced by)',
#  'P19': '태어난 곳(place of birth)',
#  'P449': '다음에서 본방송을 함(original broadcaster)',
#  'P710': '다음이 참여함(participant)',
#  'P2936': '다음 언어가 주로 사용됨(language used)',
#  'P1001': '관할 구역(applies to jurisdiction)',
#  'P140': '종교(religion)',
#  'P206': '다음 유역을 끼고 있음(located in or next to body of water)',
#  'P1056': '제품(product or material produced)',
#  'P20': '사망한 곳(place of death)',
#  'P6': '행정부 수반(head of government)',
#  'P123': '발행 주체(publisher)',
#  'P1830': '소유한 것(owner of)',
#  'P127': '소유자(owned by)',
#  'P1659': '같이 보기(see also)',
#  'P112': '설립자(founded by)',
#  'P101': '전문 분야(field of work)',
#  'P3095': '다음이 이것을 실천함(practiced by)',
#  'P749': '다음의 산하 기관임(parent organization)',
#  'P1696': '반대 속성(inverse property)',
#  'P137': '운영 주체(operator)',
#  'P2789': '다음과 연결되어 있음(connects with)',
#  'P706': '다음 지형에 위치함(located in/on physical feature)',
#  'P3842': '현재 다음 행정구역에 위치함(located in present-day administrative territorial entity)',
#  'P39': '직위(position held)',
#  'P425': '직업의 분야(field of this occupation)',
#  'P1336': '자신의 지역이라 주장하는 곳(territory claimed by)',
#  'P108': '고용한 곳(employer)',
#  'P172': '민족(ethnic group)',
#  'P737': '다음에게서 영향을 받음(influenced by)',
#  'P176': '제조사(manufacturer)',
#  'P102': '소속 정당(member of political party)',
#  'P35': '국가 원수(head of state)',
#  'P3730': '바로 윗 계급(next higher rank)',
#  'P1687': '위키데이터 속성(Wikidata property)',
#  'P945': '따르는 대상(allegiance)',
#  'P264': '음반 레이블(record label)',
#  'P161': '출연한 배우(cast member)',
#  'P69': '다녔던 학교(educated at)',
#  'P190': '자매 결연 도시(twinned administrative body)',
#  'P355': '산하 기관(subsidiary)',
#  'P2341': 'P2341(indigenous to)',
#  'P664': '주최자(organizer)',
#  'P407': '저작물·명칭의 언어(language of work or name)',
#  'P793': '특기할 만한 관련 사건(significant event)',
#  'P840': '공간적 배경(narrative location)',
#  'P1441': '다음 작품에 나옴(present in work)',
#  'P607': '참전한 전쟁(conflict)',
#  'P197': '인접 역(adjacent station)',
#  'P205': '이 유역을 끼고 있는 국가(basin country)',
#  'P162': '제작자(producer)',
#  'P807': '다음에서 떨어져 나온 것임(separated from)',
#  'P1269': '상위 주제(facet of)',
#  'P170': '창작자(creator)',
#  'P97': '작위(noble title)',
#  'P750': '다음이 유통을 맡음(distributed by)',
#  'P551': '거주지(residence)'}

# %%
relid2label['P17'] = '다음 국가의 것임(country)'
relid2label
# Out:
# {'P17': '다음 국가의 것임(country)',
#  'P131': '다음 행정구역에 위치함(located in the administrative territorial entity)',
#  'P530': '수교국(diplomatic relation)',
#  'P150': '하위 행정구역(contains administrative territorial entity)',
#  'P47': '다음과 경계를 맞닿음(shares border with)',
#  'P106': '직업(occupation)',
#  'P27': '국적(country of citizenship)',
#  'P461': '반대 개념(opposite of)',
#  'P279': '다음의 하위 개념임(subclass of)',
#  'P495': '처음 나온 나라(country of origin)',
#  'P641': '관련 스포츠 종목(sport)',
#  'P156': '다음(followed by)',
#  'P155': '이전(follows)',
#  'P527': '다음으로 이루어져 있음(has part)',
#  'P361': '다음의 한 부분임(part of)',
#  'P1376': '다음 정부의 소재지임(capital of)',
#  'P36': '정부 소재지(capital)',
#  'P118': '리그(league)',
#  'P1889': '다음과는 확실히 다름(different from)',
#  'P31': '다음 종류에 속함(instance of)',
#  'P175': '연주자·가수(performer)',
#  'P463': '다음 공동체의 구성원임(member of)',
#  'P54': '소속 팀(member of sports team)',
#  'P138': '명칭의 유래(named after)',
#  'P81': '이 정거장을 거쳐가는 노선(connecting line)',
#  'P40': '자녀(child)',
#  'P159': '본부 위치(headquarters location)',
#  'P136': '장르(genre)',
#  'P171': '다음의 하위 분류군임(parent taxon)',
#  'P22': '친아버지(father)',
#  'P26': '배우자(spouse)',
#  'P3373': '친형제자매(sibling)',
#  'P50': '저자(author)',
#  'P30': '대륙(continent)',
#  'P1532': '대표국가(country for sport)',
#  'P178': '개발 주체(developer)',
#  'P413': '포지션(position played on team / speciality)',
#  'P800': '대표 작품(notable work)',
#  'P1365': '다음으로부터 이어짐(replaces)',
#  'P276': '위치(location)',
#  'P1366': '다음으로 이어짐(replaced by)',
#  'P19': '태어난 곳(place of birth)',
#  'P449': '다음에서 본방송을 함(original broadcaster)',
#  'P710': '다음이 참여함(participant)',
#  'P2936': '다음 언어가 주로 사용됨(language used)',
#  'P1001': '관할 구역(applies to jurisdiction)',
#  'P140': '종교(religion)',
#  'P206': '다음 유역을 끼고 있음(located in or next to body of water)',
#  'P1056': '제품(product or material produced)',
#  'P20': '사망한 곳(place of death)',
#  'P6': '행정부 수반(head of government)',
#  'P123': '발행 주체(publisher)',
#  'P1830': '소유한 것(owner of)',
#  'P127': '소유자(owned by)',
#  'P1659': '같이 보기(see also)',
#  'P112': '설립자(founded by)',
#  'P101': '전문 분야(field of work)',
#  'P3095': '다음이 이것을 실천함(practiced by)',
#  'P749': '다음의 산하 기관임(parent organization)',
#  'P1696': '반대 속성(inverse property)',
#  'P137': '운영 주체(operator)',
#  'P2789': '다음과 연결되어 있음(connects with)',
#  'P706': '다음 지형에 위치함(located in/on physical feature)',
#  'P3842': '현재 다음 행정구역에 위치함(located in present-day administrative territorial entity)',
#  'P39': '직위(position held)',
#  'P425': '직업의 분야(field of this occupation)',
#  'P1336': '자신의 지역이라 주장하는 곳(territory claimed by)',
#  'P108': '고용한 곳(employer)',
#  'P172': '민족(ethnic group)',
#  'P737': '다음에게서 영향을 받음(influenced by)',
#  'P176': '제조사(manufacturer)',
#  'P102': '소속 정당(member of political party)',
#  'P35': '국가 원수(head of state)',
#  'P3730': '바로 윗 계급(next higher rank)',
#  'P1687': '위키데이터 속성(Wikidata property)',
#  'P945': '따르는 대상(allegiance)',
#  'P264': '음반 레이블(record label)',
#  'P161': '출연한 배우(cast member)',
#  'P69': '다녔던 학교(educated at)',
#  'P190': '자매 결연 도시(twinned administrative body)',
#  'P355': '산하 기관(subsidiary)',
#  'P2341': 'P2341(indigenous to)',
#  'P664': '주최자(organizer)',
#  'P407': '저작물·명칭의 언어(language of work or name)',
#  'P793': '특기할 만한 관련 사건(significant event)',
#  'P840': '공간적 배경(narrative location)',
#  'P1441': '다음 작품에 나옴(present in work)',
#  'P607': '참전한 전쟁(conflict)',
#  'P197': '인접 역(adjacent station)',
#  'P205': '이 유역을 끼고 있는 국가(basin country)',
#  'P162': '제작자(producer)',
#  'P807': '다음에서 떨어져 나온 것임(separated from)',
#  'P1269': '상위 주제(facet of)',
#  'P170': '창작자(creator)',
#  'P97': '작위(noble title)',
#  'P750': '다음이 유통을 맡음(distributed by)',
#  'P551': '거주지(residence)'}

# %%
relid2label['P131'] = '다음 행정구역에 위치함(located in)'
relid2label['P530'] = '수교국(diplomatic relation)'
relid2label['P150'] = '하위 행정구역'
relid2label['P47'] = '경계를 접하고 있음(shares border with)'
relid2label['P106'] = '직업(occupation)'
relid2label['P27'] = '국적(country of citizenship)'
relid2label['P279'] = '하위 개념(subclass of)'
relid2label['P495'] = '해당 개체가 처음 유래되거나 만들어진 국가(country of origin)'

# %%
relid2label['P641'] = '관련 스포츠 종목(related sports)'
relid2label['P156'] = '시간적 또는 공간적으로 뒤에 오는 것(followed by)'
relid2label['P155'] = '시간적 또는 공간적으로 앞에 오는 것(follows)'
relid2label['P527'] = '해당 개체가 다음으로 이루어져 있음(has part)'
relid2label['P361'] = '해당 개체가 다음의 일부분임(part of)'
relid2label['P1376'] = '해당 지역이 다음의 수도임(capital of)'

# %%
relid2label['P36'] = '해당 국가의 수도가 다음 지역임(capital)'
relid2label['P118'] = '다음 리그에 출전함(league)'
relid2label['P1889'] = '다음과 다르지만 같은 의미인 것처럼 혼동되는 항목(different from)'
relid2label['P31'] = '다음 종류에 속함(instance of)'
relid2label['P54'] = '해당 개체의 현재 또는 과거의 소속 팀(member of sports team)'

# %%
relid2label['P138'] = '해당 개체의 명칭은 다음에서 유래되었음(named after)'
relid2label['P81'] = '해당 정거장을 거쳐가는 노선(connecting line)'
relid2label['P40'] = '해당 개체의 자녀(child)'
relid2label['P159'] = '해당 기관·단체의 본부·본사가 있거나 있었던 곳(headquarters location)'
relid2label['P136'] = '해당 개체의 장르(genre)'

# %%
relid2label['P171'] = '해당 개체가 다음의 하위 분류군임(parent taxon)'
relid2label['P22'] = '해당 개체의 친아버지(father)'
relid2label['P26'] = '해당 개체의 배우자(spouse)'
relid2label['P3373'] = '해당 개체의 친형제자매(sibling)'
relid2label['P50'] = '해당 개체의 저자(author)'
relid2label['P30'] = '해당 개체가 속한 대륙(continent)'

# %%
relid2label['P1532'] = '해당 인물이 대표하는 국가(country for sport)'
relid2label['P178'] = '해당 개체를 개발한 주체(developer)'
relid2label['P413'] = '해당 선수가 맡은 포지션(position played on team / speciality)'
relid2label['P800'] = '대표 작품(notable work)'
relid2label['P1365'] = '해당 개체는 다음으로부터 이어짐(replaces)'

# %%
relid2label['P276'] = '해당 개체의 위치(location)'
relid2label['P1366'] = '해당 개체는 다음으로 이어짐(replaced by)'
relid2label['P449'] = '해당 개체가 다음에서 본방송을 함(original broadcaster)'
relid2label['P710'] = '해당 사건에 다음이 참여함(participant)'
relid2label['P2936'] = '해당 장소나 사건에서 다음 언어가 주로 사용됨(language used)'
relid2label['P1001'] = '해당 개체가 영향력을 미치는 관할 구역(applies to jurisdiction)'
relid2label['P140'] = '해당 개체와 연관된 종교(religion)'

# %%
relid2label['P206'] = '해당 지역이 끼고 있는 유역(located in or next to body of water)'
relid2label['P1056'] = '해당 개체의 제품(product or material produced)'
relid2label['P6'] = '해당 행정부 또는 지자체의 수장(head of government)'
relid2label['P123'] = '해당 개체의 발행 주체(publisher)'
relid2label['P1830'] = '해당 개체가 소유한 것(owner of)'
relid2label['P127'] = '해당 개체의 소유자(owned by)'

# %%
relid2label['P1659'] = '해당 개체와 같이 등장하는 개념(see also)'
relid2label['P112'] = '해당 개체의 설립자(founded by)'
relid2label['P749'] = '해당 개체가 다음의 산하 기관임(parent organization)'
relid2label['P137'] = '해당 개체의 운영 주체(operator)'
relid2label['P2789'] = '해당 개체가 다음과 연결되어 있음(connects with)'
relid2label['P706'] = '해당 개체가 위치한 지형(located in/on physical feature)'
relid2label['P39'] = '해당 인물의 현재 또는 과거의 직위(position held)'

# %%
relid2label['P1336'] = '해당 지역에 대해 영유권 또는 관할권을 주장하는 국가·지역·단체(territory claimed by)'
relid2label['P108'] = '해당 인물을 고용한 곳(employer)'
relid2label['P172'] = '다음은 해당 개체의 민족에 속함(ethnic group)'
relid2label['P176'] = '해당 개체의 제조사(manufacturer)'
relid2label['P102'] = '해당 인물의 소속 정당(member of political party)'
relid2label['P35'] = '해당 국가의 원수(head of state)'
relid2label['P3730'] = '해당 개체의 바로 윗 계급(next higher rank)'

# %%
relid2label['P945'] = '해당 개체가 섬기는 국가나 세력(allegiance)'
relid2label['P264'] = '해당 개체의 음반 레이블(record label)'
relid2label['P161'] = '해당 작품에 출연한 배우(cast member)'
relid2label['P69'] = '해당 인물의 학교(educated at)'
relid2label['P355'] = '해당 개체의 산하 기관(subsidiary)'
relid2label['P2341'] = '해당 개체가 다음 대상의 고유의 것임(indigenous to)'

# %%
relid2label['P407'] = '해당 저작물이나 명칭에서 사용한 언어(language of work or name)'
relid2label['P793'] = '해당 개체에게 있었던 주목할 만한 사건(significant event)'
relid2label['P1441'] = '해당 개체가 다음 작품에 등장함(present in work)'
relid2label['P607'] = '해당 개체가 참전한 전쟁(conflict)'
relid2label['P197'] = '해당 역과 인접한 역(adjacent station)'
relid2label['P205'] = '해당 유역을 끼고 있는 국가(basin country)'
relid2label['P162'] = '해당 작품의 제작자(producer)'
relid2label['P807'] = '해당 개체가 다음으로부터 갈라져 나와 시작된 것임(separated from)'
relid2label['P1269'] = '해당 주제의 상위 주제(facet of)'

# %%
relid2label['P170'] = '해당 개체의 창작자(creator)'
relid2label['P750'] = '해당 개체의 유통을 다음이 맡음(distributed by)'
relid2label['P551'] = '해당 인물의 거주지(residence)'

# %%
relid2label
# Out:
# {'P17': '다음 국가의 것임(country)',
#  'P131': '다음 행정구역에 위치함(located in)',
#  'P530': '수교국(diplomatic relation)',
#  'P150': '하위 행정구역',
#  'P47': '경계를 접하고 있음(shares border with)',
#  'P106': '직업(occupation)',
#  'P27': '국적(country of citizenship)',
#  'P461': '반대 개념(opposite of)',
#  'P279': '하위 개념(subclass of)',
#  'P495': '해당 개체가 처음 유래되거나 만들어진 국가(country of origin)',
#  'P641': '관련 스포츠 종목(related sports)',
#  'P156': '시간적 또는 공간적으로 뒤에 오는 것(followed by)',
#  'P155': '시간적 또는 공간적으로 앞에 오는 것(follows)',
#  'P527': '해당 개체가 다음으로 이루어져 있음(has part)',
#  'P361': '해당 개체가 다음의 일부분임(part of)',
#  'P1376': '해당 지역이 다음의 수도임(capital of)',
#  'P36': '해당 국가의 수도가 다음 지역임(capital)',
#  'P118': '다음 리그에 출전함(league)',
#  'P1889': '다음과 다르지만 같은 의미인 것처럼 혼동되는 항목(different from)',
#  'P31': '다음 종류에 속함(instance of)',
#  'P175': '연주자·가수(performer)',
#  'P463': '다음 공동체의 구성원임(member of)',
#  'P54': '해당 개체의 현재 또는 과거의 소속 팀(member of sports team)',
#  'P138': '해당 개체의 명칭은 다음에서 유래되었음(named after)',
#  'P81': '해당 정거장을 거쳐가는 노선(connecting line)',
#  'P40': '해당 개체의 자녀(child)',
#  'P159': '해당 기관·단체의 본부·본사가 있거나 있었던 곳(headquarters location)',
#  'P136': '해당 개체의 장르(genre)',
#  'P171': '해당 개체가 다음의 하위 분류군임(parent taxon)',
#  'P22': '해당 개체의 친아버지(father)',
#  'P26': '해당 개체의 배우자(spouse)',
#  'P3373': '해당 개체의 친형제자매(sibling)',
#  'P50': '해당 개체의 저자(author)',
#  'P30': '해당 개체가 속한 대륙(continent)',
#  'P1532': '해당 인물이 대표하는 국가(country for sport)',
#  'P178': '해당 개체를 개발한 주체(developer)',
#  'P413': '해당 선수가 맡은 포지션(position played on team / speciality)',
#  'P800': '대표 작품(notable work)',
#  'P1365': '해당 개체는 다음으로부터 이어짐(replaces)',
#  'P276': '해당 개체의 위치(location)',
#  'P1366': '해당 개체는 다음으로 이어짐(replaced by)',
#  'P19': '태어난 곳(place of birth)',
#  'P449': '해당 개체가 다음에서 본방송을 함(original broadcaster)',
#  'P710': '해당 사건에 다음이 참여함(participant)',
#  'P2936': '해당 장소나 사건에서 다음 언어가 주로 사용됨(language used)',
#  'P1001': '해당 개체가 영향력을 미치는 관할 구역(applies to jurisdiction)',
#  'P140': '해당 개체와 연관된 종교(religion)',
#  'P206': '해당 지역이 끼고 있는 유역(located in or next to body of water)',
#  'P1056': '해당 개체의 제품(product or material produced)',
#  'P20': '사망한 곳(place of death)',
#  'P6': '해당 행정부 또는 지자체의 수장(head of government)',
#  'P123': '해당 개체의 발행 주체(publisher)',
#  'P1830': '해당 개체가 소유한 것(owner of)',
#  'P127': '해당 개체의 소유자(owned by)',
#  'P1659': '해당 개체와 같이 등장하는 개념(see also)',
#  'P112': '해당 개체의 설립자(founded by)',
#  'P101': '전문 분야(field of work)',
#  'P3095': '다음이 이것을 실천함(practiced by)',
#  'P749': '해당 개체가 다음의 산하 기관임(parent organization)',
#  'P1696': '반대 속성(inverse property)',
#  'P137': '해당 개체의 운영 주체(operator)',
#  'P2789': '해당 개체가 다음과 연결되어 있음(connects with)',
#  'P706': '해당 개체가 위치한 지형(located in/on physical feature)',
#  'P3842': '현재 다음 행정구역에 위치함(located in present-day administrative territorial entity)',
#  'P39': '해당 인물의 현재 또는 과거의 직위(position held)',
#  'P425': '직업의 분야(field of this occupation)',
#  'P1336': '해당 지역에 대해 영유권 또는 관할권을 주장하는 국가·지역·단체(territory claimed by)',
#  'P108': '해당 인물을 고용한 곳(employer)',
#  'P172': '다음은 해당 개체의 민족에 속함(ethnic group)',
#  'P737': '다음에게서 영향을 받음(influenced by)',
#  'P176': '해당 개체의 제조사(manufacturer)',
#  'P102': '해당 인물의 소속 정당(member of political party)',
#  'P35': '해당 국가의 원수(head of state)',
#  'P3730': '해당 개체의 바로 윗 계급(next higher rank)',
#  'P1687': '위키데이터 속성(Wikidata property)',
#  'P945': '해당 개체가 섬기는 국가나 세력(allegiance)',
#  'P264': '해당 개체의 음반 레이블(record label)',
#  'P161': '해당 작품에 출연한 배우(cast member)',
#  'P69': '해당 인물의 학교(educated at)',
#  'P190': '자매 결연 도시(twinned administrative body)',
#  'P355': '해당 개체의 산하 기관(subsidiary)',
#  'P2341': '해당 개체가 다음 대상의 고유의 것임(indigenous to)',
#  'P664': '주최자(organizer)',
#  'P407': '해당 저작물이나 명칭에서 사용한 언어(language of work or name)',
#  'P793': '해당 개체에게 있었던 주목할 만한 사건(significant event)',
#  'P840': '공간적 배경(narrative location)',
#  'P1441': '해당 개체가 다음 작품에 등장함(present in work)',
#  'P607': '해당 개체가 참전한 전쟁(conflict)',
#  'P197': '해당 역과 인접한 역(adjacent station)',
#  'P205': '해당 유역을 끼고 있는 국가(basin country)',
#  'P162': '해당 작품의 제작자(producer)',
#  'P807': '해당 개체가 다음으로부터 갈라져 나와 시작된 것임(separated from)',
#  'P1269': '해당 주제의 상위 주제(facet of)',
#  'P170': '해당 개체의 창작자(creator)',
#  'P97': '작위(noble title)',
#  'P750': '해당 개체의 유통을 다음이 맡음(distributed by)',
#  'P551': '해당 인물의 거주지(residence)'}

# %%
len(relid2label)
# Out:
# 97

# %% [markdown]
# ## json 파일로 저장

# %%
import json

with open('../data/relation/relid2label.json', 'w', encoding='utf-8') as f:
    json.dump(relid2label, f, indent=4)

# %%
with open('../data/relation/relid2label.json', 'r') as f:
    jsn_data = json.load(f)
    
jsn_data
# Out:
# {'P17': '다음 국가의 것임(country)',
#  'P131': '다음 행정구역에 위치함(located in)',
#  'P530': '수교국(diplomatic relation)',
#  'P150': '하위 행정구역',
#  'P47': '경계를 접하고 있음(shares border with)',
#  'P106': '직업(occupation)',
#  'P27': '국적(country of citizenship)',
#  'P461': '반대 개념(opposite of)',
#  'P279': '하위 개념(subclass of)',
#  'P495': '해당 개체가 처음 유래되거나 만들어진 국가(country of origin)',
#  'P641': '관련 스포츠 종목(related sports)',
#  'P156': '시간적 또는 공간적으로 뒤에 오는 것(followed by)',
#  'P155': '시간적 또는 공간적으로 앞에 오는 것(follows)',
#  'P527': '해당 개체가 다음으로 이루어져 있음(has part)',
#  'P361': '해당 개체가 다음의 일부분임(part of)',
#  'P1376': '해당 지역이 다음의 수도임(capital of)',
#  'P36': '해당 국가의 수도가 다음 지역임(capital)',
#  'P118': '다음 리그에 출전함(league)',
#  'P1889': '다음과 다르지만 같은 의미인 것처럼 혼동되는 항목(different from)',
#  'P31': '다음 종류에 속함(instance of)',
#  'P175': '연주자·가수(performer)',
#  'P463': '다음 공동체의 구성원임(member of)',
#  'P54': '해당 개체의 현재 또는 과거의 소속 팀(member of sports team)',
#  'P138': '해당 개체의 명칭은 다음에서 유래되었음(named after)',
#  'P81': '해당 정거장을 거쳐가는 노선(connecting line)',
#  'P40': '해당 개체의 자녀(child)',
#  'P159': '해당 기관·단체의 본부·본사가 있거나 있었던 곳(headquarters location)',
#  'P136': '해당 개체의 장르(genre)',
#  'P171': '해당 개체가 다음의 하위 분류군임(parent taxon)',
#  'P22': '해당 개체의 친아버지(father)',
#  'P26': '해당 개체의 배우자(spouse)',
#  'P3373': '해당 개체의 친형제자매(sibling)',
#  'P50': '해당 개체의 저자(author)',
#  'P30': '해당 개체가 속한 대륙(continent)',
#  'P1532': '해당 인물이 대표하는 국가(country for sport)',
#  'P178': '해당 개체를 개발한 주체(developer)',
#  'P413': '해당 선수가 맡은 포지션(position played on team / speciality)',
#  'P800': '대표 작품(notable work)',
#  'P1365': '해당 개체는 다음으로부터 이어짐(replaces)',
#  'P276': '해당 개체의 위치(location)',
#  'P1366': '해당 개체는 다음으로 이어짐(replaced by)',
#  'P19': '태어난 곳(place of birth)',
#  'P449': '해당 개체가 다음에서 본방송을 함(original broadcaster)',
#  'P710': '해당 사건에 다음이 참여함(participant)',
#  'P2936': '해당 장소나 사건에서 다음 언어가 주로 사용됨(language used)',
#  'P1001': '해당 개체가 영향력을 미치는 관할 구역(applies to jurisdiction)',
#  'P140': '해당 개체와 연관된 종교(religion)',
#  'P206': '해당 지역이 끼고 있는 유역(located in or next to body of water)',
#  'P1056': '해당 개체의 제품(product or material produced)',
#  'P20': '사망한 곳(place of death)',
#  'P6': '해당 행정부 또는 지자체의 수장(head of government)',
#  'P123': '해당 개체의 발행 주체(publisher)',
#  'P1830': '해당 개체가 소유한 것(owner of)',
#  'P127': '해당 개체의 소유자(owned by)',
#  'P1659': '해당 개체와 같이 등장하는 개념(see also)',
#  'P112': '해당 개체의 설립자(founded by)',
#  'P101': '전문 분야(field of work)',
#  'P3095': '다음이 이것을 실천함(practiced by)',
#  'P749': '해당 개체가 다음의 산하 기관임(parent organization)',
#  'P1696': '반대 속성(inverse property)',
#  'P137': '해당 개체의 운영 주체(operator)',
#  'P2789': '해당 개체가 다음과 연결되어 있음(connects with)',
#  'P706': '해당 개체가 위치한 지형(located in/on physical feature)',
#  'P3842': '현재 다음 행정구역에 위치함(located in present-day administrative territorial entity)',
#  'P39': '해당 인물의 현재 또는 과거의 직위(position held)',
#  'P425': '직업의 분야(field of this occupation)',
#  'P1336': '해당 지역에 대해 영유권 또는 관할권을 주장하는 국가·지역·단체(territory claimed by)',
#  'P108': '해당 인물을 고용한 곳(employer)',
#  'P172': '다음은 해당 개체의 민족에 속함(ethnic group)',
#  'P737': '다음에게서 영향을 받음(influenced by)',
#  'P176': '해당 개체의 제조사(manufacturer)',
#  'P102': '해당 인물의 소속 정당(member of political party)',
#  'P35': '해당 국가의 원수(head of state)',
#  'P3730': '해당 개체의 바로 윗 계급(next higher rank)',
#  'P1687': '위키데이터 속성(Wikidata property)',
#  'P945': '해당 개체가 섬기는 국가나 세력(allegiance)',
#  'P264': '해당 개체의 음반 레이블(record label)',
#  'P161': '해당 작품에 출연한 배우(cast member)',
#  'P69': '해당 인물의 학교(educated at)',
#  'P190': '자매 결연 도시(twinned administrative body)',
#  'P355': '해당 개체의 산하 기관(subsidiary)',
#  'P2341': '해당 개체가 다음 대상의 고유의 것임(indigenous to)',
#  'P664': '주최자(organizer)',
#  'P407': '해당 저작물이나 명칭에서 사용한 언어(language of work or name)',
#  'P793': '해당 개체에게 있었던 주목할 만한 사건(significant event)',
#  'P840': '공간적 배경(narrative location)',
#  'P1441': '해당 개체가 다음 작품에 등장함(present in work)',
#  'P607': '해당 개체가 참전한 전쟁(conflict)',
#  'P197': '해당 역과 인접한 역(adjacent station)',
#  'P205': '해당 유역을 끼고 있는 국가(basin country)',
#  'P162': '해당 작품의 제작자(producer)',
#  'P807': '해당 개체가 다음으로부터 갈라져 나와 시작된 것임(separated from)',
#  'P1269': '해당 주제의 상위 주제(facet of)',
#  'P170': '해당 개체의 창작자(creator)',
#  'P97': '작위(noble title)',
#  'P750': '해당 개체의 유통을 다음이 맡음(distributed by)',
#  'P551': '해당 인물의 거주지(residence)'}

# %%
import json
import requests

url = 'https://raw.githubusercontent.com/datawhales/Korean_RE/main/data/relation/relid2label.json'
r = requests.get(url)
json.loads(r.text)
# Out:
# {'P17': '다음 국가의 것임(country)',
#  'P131': '다음 행정구역에 위치함(located in)',
#  'P530': '수교국(diplomatic relation)',
#  'P150': '하위 행정구역',
#  'P47': '경계를 접하고 있음(shares border with)',
#  'P106': '직업(occupation)',
#  'P27': '국적(country of citizenship)',
#  'P461': '반대 개념(opposite of)',
#  'P279': '하위 개념(subclass of)',
#  'P495': '해당 개체가 처음 유래되거나 만들어진 국가(country of origin)',
#  'P641': '관련 스포츠 종목(related sports)',
#  'P156': '시간적 또는 공간적으로 뒤에 오는 것(followed by)',
#  'P155': '시간적 또는 공간적으로 앞에 오는 것(follows)',
#  'P527': '해당 개체가 다음으로 이루어져 있음(has part)',
#  'P361': '해당 개체가 다음의 일부분임(part of)',
#  'P1376': '해당 지역이 다음의 수도임(capital of)',
#  'P36': '해당 국가의 수도가 다음 지역임(capital)',
#  'P118': '다음 리그에 출전함(league)',
#  'P1889': '다음과 다르지만 같은 의미인 것처럼 혼동되는 항목(different from)',
#  'P31': '다음 종류에 속함(instance of)',
#  'P175': '연주자·가수(performer)',
#  'P463': '다음 공동체의 구성원임(member of)',
#  'P54': '해당 개체의 현재 또는 과거의 소속 팀(member of sports team)',
#  'P138': '해당 개체의 명칭은 다음에서 유래되었음(named after)',
#  'P81': '해당 정거장을 거쳐가는 노선(connecting line)',
#  'P40': '해당 개체의 자녀(child)',
#  'P159': '해당 기관·단체의 본부·본사가 있거나 있었던 곳(headquarters location)',
#  'P136': '해당 개체의 장르(genre)',
#  'P171': '해당 개체가 다음의 하위 분류군임(parent taxon)',
#  'P22': '해당 개체의 친아버지(father)',
#  'P26': '해당 개체의 배우자(spouse)',
#  'P3373': '해당 개체의 친형제자매(sibling)',
#  'P50': '해당 개체의 저자(author)',
#  'P30': '해당 개체가 속한 대륙(continent)',
#  'P1532': '해당 인물이 대표하는 국가(country for sport)',
#  'P178': '해당 개체를 개발한 주체(developer)',
#  'P413': '해당 선수가 맡은 포지션(position played on team / speciality)',
#  'P800': '대표 작품(notable work)',
#  'P1365': '해당 개체는 다음으로부터 이어짐(replaces)',
#  'P276': '해당 개체의 위치(location)',
#  'P1366': '해당 개체는 다음으로 이어짐(replaced by)',
#  'P19': '태어난 곳(place of birth)',
#  'P449': '해당 개체가 다음에서 본방송을 함(original broadcaster)',
#  'P710': '해당 사건에 다음이 참여함(participant)',
#  'P2936': '해당 장소나 사건에서 다음 언어가 주로 사용됨(language used)',
#  'P1001': '해당 개체가 영향력을 미치는 관할 구역(applies to jurisdiction)',
#  'P140': '해당 개체와 연관된 종교(religion)',
#  'P206': '해당 지역이 끼고 있는 유역(located in or next to body of water)',
#  'P1056': '해당 개체의 제품(product or material produced)',
#  'P20': '사망한 곳(place of death)',
#  'P6': '해당 행정부 또는 지자체의 수장(head of government)',
#  'P123': '해당 개체의 발행 주체(publisher)',
#  'P1830': '해당 개체가 소유한 것(owner of)',
#  'P127': '해당 개체의 소유자(owned by)',
#  'P1659': '해당 개체와 같이 등장하는 개념(see also)',
#  'P112': '해당 개체의 설립자(founded by)',
#  'P101': '전문 분야(field of work)',
#  'P3095': '다음이 이것을 실천함(practiced by)',
#  'P749': '해당 개체가 다음의 산하 기관임(parent organization)',
#  'P1696': '반대 속성(inverse property)',
#  'P137': '해당 개체의 운영 주체(operator)',
#  'P2789': '해당 개체가 다음과 연결되어 있음(connects with)',
#  'P706': '해당 개체가 위치한 지형(located in/on physical feature)',
#  'P3842': '현재 다음 행정구역에 위치함(located in present-day administrative territorial entity)',
#  'P39': '해당 인물의 현재 또는 과거의 직위(position held)',
#  'P425': '직업의 분야(field of this occupation)',
#  'P1336': '해당 지역에 대해 영유권 또는 관할권을 주장하는 국가·지역·단체(territory claimed by)',
#  'P108': '해당 인물을 고용한 곳(employer)',
#  'P172': '다음은 해당 개체의 민족에 속함(ethnic group)',
#  'P737': '다음에게서 영향을 받음(influenced by)',
#  'P176': '해당 개체의 제조사(manufacturer)',
#  'P102': '해당 인물의 소속 정당(member of political party)',
#  'P35': '해당 국가의 원수(head of state)',
#  'P3730': '해당 개체의 바로 윗 계급(next higher rank)',
#  'P1687': '위키데이터 속성(Wikidata property)',
#  'P945': '해당 개체가 섬기는 국가나 세력(allegiance)',
#  'P264': '해당 개체의 음반 레이블(record label)',
#  'P161': '해당 작품에 출연한 배우(cast member)',
#  'P69': '해당 인물의 학교(educated at)',
#  'P190': '자매 결연 도시(twinned administrative body)',
#  'P355': '해당 개체의 산하 기관(subsidiary)',
#  'P2341': '해당 개체가 다음 대상의 고유의 것임(indigenous to)',
#  'P664': '주최자(organizer)',
#  'P407': '해당 저작물이나 명칭에서 사용한 언어(language of work or name)',
#  'P793': '해당 개체에게 있었던 주목할 만한 사건(significant event)',
#  'P840': '공간적 배경(narrative location)',
#  'P1441': '해당 개체가 다음 작품에 등장함(present in work)',
#  'P607': '해당 개체가 참전한 전쟁(conflict)',
#  'P197': '해당 역과 인접한 역(adjacent station)',
#  'P205': '해당 유역을 끼고 있는 국가(basin country)',
#  'P162': '해당 작품의 제작자(producer)',
#  'P807': '해당 개체가 다음으로부터 갈라져 나와 시작된 것임(separated from)',
#  'P1269': '해당 주제의 상위 주제(facet of)',
#  'P170': '해당 개체의 창작자(creator)',
#  'P97': '작위(noble title)',
#  'P750': '해당 개체의 유통을 다음이 맡음(distributed by)',
#  'P551': '해당 인물의 거주지(residence)'}
